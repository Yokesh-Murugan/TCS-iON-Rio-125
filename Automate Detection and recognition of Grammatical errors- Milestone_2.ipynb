# %%
# !pip install spacy
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.10/dist-packages (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy) (1.10.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy) (2.1.3)

# %%
import spacy
nlp = spacy.load("en_core_web_sm")

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
document = open('gdrive/My Drive/Colab Notebooks/text.txt').read()
document = nlp(document)
dir(document)
print(document[0])
# Out:
# Hi

# %%
list(document.sents)
# Out:
# [Hi Friends, I am Yokesh, completed Bachelors degree in Engineering with 8.46 CGPA.,
#  Currently I am doing internship in TCS RIO-125 with the project Automate detection and recognition of Grammatical Errors.]

# %%
all_tags = {w.pos: w.pos_ for w in document}

for word in list(document.sents)[0]:
  print(word, word.tag_)
# Out:
# Hi UH
# Friends NNS
# , ,
# I PRP
# am VBP
# Yokesh NNP
# , ,
# completed VBD
# Bachelors NNPS
# degree NN
# in IN
# Engineering NNP
# with IN
# 8.46 CD
# CGPA NNP
# . .

# %%
[chunk.text for chunk in document.noun_chunks]
# Out:
# ['I',
#  'Yokesh',
#  ', completed Bachelors degree',
#  'Engineering',
#  '8.46 CGPA',
#  'I',
#  'internship',
#  'TCS RIO-125',
#  'the project Automate detection',
#  'recognition',
#  'Grammatical Errors']

# %%
from spacy import displacy
displacy.render(document, style='dep')
displacy.render(document, style='ent')
# Out:
# '<div class="entities" style="line-height: 2.5; direction: ltr">Hi Friends, I am Yokesh, completed Bachelors degree in \n<mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    Engineering\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>\n</mark>\n with \n<mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    8.46\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>\n</mark>\n CGPA. Currently I am doing internship in \n<mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    TCS\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>\n</mark>\n RIO-125 with the project \n<mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    Automate\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>\n</mark>\n detection and recognition of \n<mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">\n    Grammatical Errors\n    <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>\n</mark>\n.</div>'

# %%
#define some parameters
noisy_pos_tags = ["PROP"]
min_token_length = 2

#Function to check if the token is a noise or not
def isNoise(token):
  is_noise = False
  if token.pos_ in noisy_pos_tags:
    is_noise = True
  elif token.is_stop == True:
    is_noise = True
  elif len(str(token)) <= min_token_length:
    is_noise = True
  return is_noise
def cleanup(token, lower = True):
  if lower:
    token = token.lower()
  return token.strip()

#top unigrams used in the reviews
from collections import Counter
cleaned_list = [cleanup(str(word)) for word in document if not isNoise(word)]
Counter(cleaned_list) .most_common(5)

# Entity Detection
print("\nEntity Detection...\n")
label = set([w.label_ for w in document.ents])
for i in label:
  entities = [cleanup(str(e), lower=False) for e in document.ents if i==e.label_]
  entities = list(set(entities))
  print(i, entities)

#Displaying tokens
for token in document:
  print (token.text, token.tag_, token.head.text, token.dep_)
#  Displaying Noun Phrases
print("\nDisplaying Noun Phrases")
for np in document.noun_chunks:
  print(np.text, np.root.dep_, np.root.head.text)
# Out:
# Entity Detection...
#
# GPE ['Engineering', 'Automate']
# ORG ['Grammatical Errors', 'TCS']
# CARDINAL ['8.46']
# Hi UH am intj
# Friends NNS Hi npadvmod
# , , am punct
# I PRP am nsubj
# am VBP am ROOT
# Yokesh NNP am attr
# , , degree punct
# completed VBD degree amod
# Bachelors NNPS degree compound
# degree NN am attr
# in IN degree prep
# Engineering NNP in pobj
# with IN degree prep
# 8.46 CD CGPA nummod
# CGPA NNP with pobj
# . . am punct
# Currently RB doing advmod
# I PRP doing nsubj
# am VBP doing aux
# doing VBG doing ROOT
# internship NN doing dobj
# in IN internship prep
# TCS NNP RIO-125 compound
# RIO-125 NNP in pobj
# with IN doing prep
# the DT detection det
# project NN detection compound
# Automate NNP detection compound
# detection NN with pobj
# and CC detection cc
# recognition NN detection conj
# of IN detection prep
# Grammatical JJ Errors amod
# Errors NNS of pobj
# . . doing punct
#
# Displaying Noun Phrases
# I nsubj am
# Yokesh attr am
# , completed Bachelors degree attr am
# Engineering pobj in
# 8.46 CGPA pobj with
# I nsubj doing
# internship dobj doing
# TCS RIO-125 pobj in
# the project Automate detection pobj with
# recognition conj detection
# Grammatical Errors pobj of

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as sklearn_stop_words
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score
from sklearn.base import TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.svm import LinearSVC

import string
punctuations = string.punctuation
# !python3 -m spacy download en
spacy.load('en_core_web_sm')
from spacy.lang.en import English
parser = English()

#Custom transformer using spacy
class predictors(TransformerMixin):
  def transform(self, X, **transform_params):
    return [clean_text(text) for text in X]
  def fit(self, X, y=None, **fit_params):
    return self
  def get_params(self, deep=True):
    return {}

#Basic Utility function to clean the text

def clean_text(text):
  return text.strip().lower()

def spacy_tokenizer(sentence):
  tokens = nlp(sentence)
  tokens = [tok.lemma_.lower().strip() if tok.lemma_ != "-PRON-" else tok.lower_ for tok in tokens]
  tokens = [tok for tok in tokens if (tok not in sklearn_stop_words and tok not in punctuations)]
  return tokens

#create vectorizer object to generate feature vectors, we will use custom spacy tokenizer
vectorizer = CountVectorizer(tokenizer = spacy_tokenizer, ngram_range=(1,1))
classifier = LinearSVC()

#create the pipeline to clean, tokenize, vectorize and classify
pipe = Pipeline([("cleaner", predictors()),
                 ('vectorizer', vectorizer),
                 ('classifier', classifier)])
# Out:
# 2023-07-03 07:26:12.157002: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.5.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.5.0/en_core_web_sm-3.5.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 45.0 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.6.0,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.5.0) (3.5.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.4)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.0.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.7)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.0.8)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.4.6)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.8)
# Requirement already satisfied: typer<0.8.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (6.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.65.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.22.4)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.27.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.10.9)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (23.1)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<1.11.0,>=1.7.4->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (4.6.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (3.4)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.7.9)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (0.0.4)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.8.0,>=0.3.0->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.6.0,>=3.5.0->en-core-web-sm==3.5.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
import pandas as pd
import numpy as np

df_train = pd.read_csv("gdrive/My Drive/Colab Notebooks/All_train_data.csv")

# %%
df_train.head()
# Out:
#                                                input  labels
# 0    I am reading score of Mahler is Symphony No . .       0
# 1  I am not interested in cars or electric applia...       1
# 2         This is my homework for my English class .       0
# 3  In comparison , Canada is catches increased an...       0
# 4  Fortunately , my older sister is friend is a d...       1

# %%
df_train.loc[df_train['labels']==0, 'labels']='neg'

# %%
df_train.loc[df_train['labels']==1, 'labels']='pos'

# %%
df_train
# Out:
#                                                    input labels
# 0        I am reading score of Mahler is Symphony No . .    neg
# 1      I am not interested in cars or electric applia...    pos
# 2             This is my homework for my English class .    neg
# 3      In comparison , Canada is catches increased an...    neg
# 4      Fortunately , my older sister is friend is a d...    pos
# ...                                                  ...    ...
# 29993  Actually , I started college this April even t...    pos
# 29994  I am sure we all get more sophisticated as we ...    pos
# 29995  I am worried about my English lessons and the ...    pos
# 29996          It is okay to change the meaning though .    neg
# 29997                         Can anyone answer for me ?    pos
#
# [29998 rows x 2 columns]

# %%
train=[(df_train.iloc[i][0],df_train.iloc[i][1]) for i in range(len(df_train))]

# %%
train
# Out:
# [('I am reading score of Mahler is Symphony No . .', 'neg'),
#  ('I am not interested in cars or electric appliances .', 'pos'),
#  ('This is my homework for my English class .', 'neg'),
#  ('In comparison , Canada is catches increased and decreased at steadier rate , although similarly to US .',
#   'neg'),
#  ('Fortunately , my older sister is friend is a dentist .', 'pos'),
#  ('Also , some recycling methods for plastics use more oil to use machinery than making new one from oil .',
#   'pos'),
#  ('Comparison Contrast', 'pos'),
#  ('See you .', 'neg'),
#  ('Talking with Kyouke from about to .', 'pos'),
#  ('biodiversity n .', 'neg'),
#  ('I understand it is a dream .', 'pos'),
#  ('I request many things to her so often .', 'neg'),
#  ('Working - Holiday is a system for youngmen to taravel abroad with working in some country .',
#   'neg'),
#  ('Nice to meet you .', 'neg'),
#  ('Is not that easier than the Taiwanese one ?', 'pos'),
#  ('I could not write diary for long time .', 'neg'),
#  ('And my ankle and knee are in pain . It is very painful .', 'pos'),
#  ('He was fidgeting on his way .', 'neg'),
#  (' A house . ', 'neg'),
#  ('And I am addicted to it very much ', 'pos'),
#  ('Please correct my mistakes .', 'neg'),
#  ('Second one , vocabulary , is fun too .', 'neg'),
#  ('I think he came here to teach us lessons .', 'pos'),
#  ('I grasped my belly which was stuffed with the soup and peach .', 'pos'),
#  ('But first I visited Paris myself for nights . to travel along was my first experience , feel was so lonely . ',
#   'neg'),
#  ('Until that night was going to end with no stars', 'pos'),
#  (' - One of my colleagues found the program for us .', 'neg'),
#  ('The new house is not so uncomfortable and we are relax here .', 'neg'),
#  ('I do not know how to explain the difference between Koreans and others .',
#   'pos'),
#  ('The person who has the same name might be harmed by such things as bullying .',
#   'pos'),
#  ('but my weight still remains to be the same .', 'pos'),
#  ('Rainy Season , ', 'neg'),
#  ('In India is life , we need auto rickshaws .', 'pos'),
#  ('I hate this typical blood running everyone is body .', 'neg'),
#  ('Hmm . My iPhone is always with me even at work .', 'pos'),
#  ('Let is try this game please tell me your impressions !', 'pos'),
#  ('It is not bad to learn something new brought by the stars .', 'pos'),
#  ('I have some friens in N .', 'neg'),
#  ('I gave her a present .', 'pos'),
#  ('so i have to try to diet to tomorrow .', 'neg'),
#  ('Thanks for reading of my diary .', 'neg'),
#  ('I am sure they are going to be a great couple .', 'pos'),
#  ('But they still have a chance .', 'pos'),
#  ('I am writing my first diary to know how useful this service is .', 'neg'),
#  ('She has a baby girl , and she has a plan . She wants her baby to be raised as a bilingual who can speak both Japanese and English fluently .',
#   'pos'),
#  ('The surgery took a short time , almost mins and there was no pain but it was scary .',
#   'pos'),
#  ('we have a listening lesson this afternoon .', 'pos'),
#  ('In the hospital , for example , we ca not use cellular phones because they have a bad influence on medical devices or people with heart diseases .',
#   'pos'),
#  ('People who have good language skills tell me that we have to start with listening , then speaking , reading and writing , a similar pattern to how we learn our native language .',
#   'pos'),
#  ('The price of the smell ?', 'pos'),
#  ('And with their crossed eyes they throw sparks to burn the stupid guys that do not want to study .',
#   'neg'),
#  ('My name is Takahiro .', 'pos'),
#  ('Monkey What is a good thought !', 'neg'),
#  (' - He is as green .', 'pos'),
#  ('I am proud of myself to be a Japanese person when people talk about Japanese anime or so .',
#   'pos'),
#  ('Then I prepare the calculation of work in progress and the cost of production is corrected by changes in inventory of finished products and work in progress .',
#   'pos'),
#  ('Digital art is communicative and interactive .', 'neg'),
#  ('On Sunday I went for a walk with my flatmate . She is like my sister here , so we just went for a walk and had some coffee and then I went back to my flat .',
#   'pos'),
#  ('Do you think so ?', 'pos'),
#  (' The diary helps you remember what it was like to be you at different stages of your life .',
#   'neg'),
#  ('Why my body like this sick ?', 'neg'),
#  ('He is a man from Japan .', 'pos'),
#  ('Finally , I became an English teacher for kids .', 'pos'),
#  ('I do not want to do my homework again for today .', 'pos'),
#  ('After that , I did shopping and I bought the food for tonight , drinks , snacks the foods for week .',
#   'neg'),
#  ('sometimes my son can speak some English with me .', 'neg'),
#  (' - never injure a friend ', 'pos'),
#  ('I am going to jot down something that happened or something I thought every day from today .',
#   'pos'),
#  ('She had an enjoyable time with her grandfather and grandmother immediately .',
#   'pos'),
#  ('Although almost all are sentences , recently I think it is the shortest way for improving my speaking English that I memorize sentences and use modified sentences that I change in line with which I want to talk .',
#   'neg'),
#  ('because any one tasty in japanese foods .', 'neg'),
#  ("My friend say ' It is also good for Japanese to watch Japanese movies with English subtitles .",
#   'neg'),
#  ('Anyway , I want to enjoy watching their dancing tomorrow .', 'neg'),
#  ('Here is a part from the episode Four Funerals and a Wedding', 'pos'),
#  ('hobby soccer and swimming', 'neg'),
#  ('Second , because you are able to read .', 'neg'),
#  ('He is made of rubber , so he ca not have a pulse ', 'pos'),
#  ('My new school year has launched and I got so wrapped up in my teaching .',
#   'pos'),
#  ('It is important for us to have our goals in life , but it is more important to make a effective goals according to your actual condition .',
#   'neg'),
#  ('This logo design is very simple , But deep meaning is hidden behind there .',
#   'neg'),
#  ('It is a .m . Feeling sleepy Hope I can make some friends that can share the knowlegde we have .',
#   'neg'),
#  ('I was so tired for waiting him .', 'neg'),
#  ('He sometimes spoke in a blank tone in response to our call .', 'neg'),
#  ('My kids love corns .', 'pos'),
#  ('Natural disaster that is not easy to control .', 'neg'),
#  ('then i introduce myself', 'neg'),
#  ('I want to go Karaoke with him next month !', 'pos'),
#  ('In order to offer chronically the comsumers best service and commodities , you had better use some profits to invest your enterprise .',
#   'neg'),
#  ('My friends say that I and my sister look like twins .', 'pos'),
#  ('Trying not to be a Monk only for three days ', 'neg'),
#  ('Should College Students Hire Cleaners ?', 'pos'),
#  ('I want to start off from translation of one of my video which I m going to put subtitle in English .',
#   'neg'),
#  ('i hope one day i can go to europe .', 'neg'),
#  ('Before the move , I lived in a hilly inland area .', 'neg'),
#  ('And it moderates the pain in the throat .', 'pos'),
#  ('My passion', 'neg'),
#  ('I watched a DVD of Silk Road at today .', 'neg'),
#  ('And my room is in the south east in my apartment .', 'pos'),
#  ('Today I learned the Korean alphabet .', 'neg'),
#  ('He introduced me to this site , so I can write this diary .', 'pos'),
#  ('The author has persuaded the reader to consent to the conclusion and sentences have been formed to protect the conclusion to the end .',
#   'pos'),
#  ('I have an English friend who is learning Chinese . Please tell me . I will follow closely your Chinese diary , and hope they can help me to improve my English diary .',
#   'pos'),
#  ('But it is not enough .', 'pos'),
#  ('However , it is only when I do not have any plans to go out .', 'pos'),
#  ('i am so happy this week', 'neg'),
#  ('It is almost bloom cherry - blossom .', 'neg'),
#  ('Are you stupid ?', 'neg'),
#  ('It is a small presentation that only nine people will attend and it is about the feedback after reading a book .',
#   'neg'),
#  ('The lover is special course , lover is dedicated suite , lover is coupon and so forth are chock full of the stink coming off the coins .',
#   'pos'),
#  ('However , the economic recessions are more effective than these efforts .',
#   'pos'),
#  ('Today is lunch time , we talked about scream machines .', 'pos'),
#  ('Then we were laughing .', 'neg'),
#  ('It was very delicious ! !', 'neg'),
#  ('The allergy to avocado', 'pos'),
#  ('Now , I am doing a study in sports psychology .', 'pos'),
#  ('I am planning to join a company next year .', 'pos'),
#  ('simple plan', 'pos'),
#  ('If my children can tell me everything , I am the best mom .', 'neg'),
#  ('I love all the stars up the sky .', 'neg'),
#  ('That is funny , he used Twitter although he was the emperor in the old days .',
#   'pos'),
#  ('I will try multi - tasking from now .', 'pos'),
#  ('Thanks for reading such a long entry !', 'neg'),
#  ('I have been studying listening , reading and speaking skills in English so far , but never learned about writing .',
#   'pos'),
#  ('It is a judgment of the boss of not join .', 'neg'),
#  ('Clean the room', 'pos'),
#  ('Why my English have not been improved ?', 'neg'),
#  ('I study English ', 'pos'),
#  ('Therefore , I took a medicine and I wore warm clothes in order not to catch a cold .',
#   'pos'),
#  ('I was disappointed when Charlie could not get the Golden Ticket but I jumped up to be glad in my mind when he got the last one after later .',
#   'pos'),
#  ('We had a promise .', 'pos'),
#  ('Which one of these characteristics is most important to you ?', 'neg'),
#  (" is ' did you nod ?", 'pos'),
#  ('He made air bad , and we thought that he was a troublemaker when he drank .',
#   'neg'),
#  ('That was so scary .', 'neg'),
#  ('This may be last cold and next week spring will come .', 'neg'),
#  ('Excuse me Sir , your pubic hair is coming out from your underwear .',
#   'neg'),
#  ('Most of his movies are twisted , so I was surprised when I heard that he had directed this kind of hero movie .',
#   'neg'),
#  (' Vocabulary - Sitcom Friends and two textbooks', 'pos'),
#  ('This drama is my favorite drama ever .', 'pos'),
#  ('My English is unworthy .', 'neg'),
#  ('The happy financial reporting of Chugai Pharmaceutical .', 'neg'),
#  ('I wish your day is special .', 'neg'),
#  ('As we find that if we still do not do some exercises , our body will be flatter and weeker .',
#   'pos'),
#  ('Korea is a homogeneous country .', 'pos'),
#  ('Of course there were some problems .', 'pos'),
#  ('I was very suprised his speed and appetite .', 'neg'),
#  ('In the same way as the technical growth of the ski', 'neg'),
#  ('In a word , I believe that the city can make a better life .', 'pos'),
#  ('A day of crisis all of relatively calm in the Egyptian capital even as senior leadership of the ruling party , including H .',
#   'pos'),
#  ('I was surprised !', 'neg'),
#  ('Hello , lang - users !', 'pos'),
#  ('This morning , my girlfriend called me .', 'neg'),
#  ('Complete the second sentence so that it has a similar meaning to the first sentence , using the word given .',
#   'neg'),
#  ('Today an idea hit upon in my mind . Why do the people read books ? ',
#   'neg'),
#  ('When he becomes like that , he can listen to nothing .', 'pos'),
#  ('So I was surprised and impressed by the unexpected active situations .',
#   'pos'),
#  ('Roads to Furano got choked because many visitors rushed Lavender gardens .',
#   'neg'),
#  ('I play badminton once a week and today was that day .', 'neg'),
#  ('The first time I called him , I was not able to follow him at all , because his way of pronouncing English is so different from the American English which I am used to hearing .',
#   'pos'),
#  ('I was excited a little though I usually did not watch', 'pos'),
#  ('So , the weather is very warm .', 'pos'),
#  ('So , as the Mid - Autumn day s coming , best wishes for all my dear friends !',
#   'neg'),
#  (' I see .', 'neg'),
#  ('I do not care which nationality you have .', 'pos'),
#  ('I thought I learned them when I was high school student , math was very difficult for me .',
#   'neg'),
#  ('Now I am thankful for being in front of my computer as usual .', 'neg'),
#  ('strange food', 'neg'),
#  ('So , I wonder if I should take it easy .', 'pos'),
#  ('I hope to go to see the cherry blossom this Sunday , ', 'pos'),
#  ('She is singer', 'neg'),
#  ('I took a painting class in Tokyo yesterday .', 'neg'),
#  ('Hopefully , I can enjoy snowing next time .', 'pos'),
#  ('Once upon a time a young girl , called Mariah .', 'neg'),
#  ('After lunch I drove the car to go to the store .', 'pos'),
#  ('I am in charge of voice systems which are installed in the global branch .',
#   'pos'),
#  ('It was probably first time that cotten candy was not effective to convince him .',
#   'neg'),
#  ('I love this site , and I want to make frends through this way', 'neg'),
#  (' What happens to the hole when the chees is gone ?', 'neg'),
#  (' . Inorganic chemical products such as nitrate , nitrite , fluoride , arsenic , selenium , mercury .',
#   'neg'),
#  ('He would take photoglaphs of old buildings .', 'neg'),
#  ('Keep going for a goal .', 'pos'),
#  (' Type Select indented or run - in .', 'pos'),
#  ('I have not been aware of the haze over my hometown until this summer though I have so many times looked up to the sky .',
#   'neg'),
#  ('That is the first time that I have sold it .', 'pos'),
#  ('Second asking', 'pos'),
#  ('I was with my friend and we both was so happy for the Tiger is win .',
#   'neg'),
#  ('Then I left there and had lunch .', 'neg'),
#  ('She works as a dietitian .', 'neg'),
#  ('Also , in the world , actions driving nuclear - power policy seem to certainly slow down .',
#   'pos'),
#  ('my name is Klaudia .', 'neg'),
#  ('I got into a panic when many things , such as Japanese phrases , English Phrase , grammar stuffs and other is worrisome faces , came up my mind quickly , just like flash - back .',
#   'neg'),
#  ('Next is also an animal is sneeze ', 'neg'),
#  ('Then I figured , well , geek is kind of way better than chubby or pig . Goodness I am all alive again .',
#   'pos'),
#  ('Sometimes , I find comments written in English by my friends who can speak English .',
#   'pos'),
#  ('One should be always concentrated and careful .', 'neg'),
#  ('The mirror room was very beautiful .', 'neg'),
#  ('Since I was child , I have been fond of it .', 'neg'),
#  ('I can breast stroke better than crawl , so I practice crawl now .', 'neg'),
#  ('For the first time I did not meet anyone acquaintance at the airport .',
#   'pos'),
#  ('The master said to the customer contentedly , Things went as I said . ',
#   'pos'),
#  (' th . We d . June . Karaoke', 'pos'),
#  ('At that time it was really fantastic weather . I could see wild blue sky and white beaches surrounded by an emerald - color sea I had never seen before .',
#   'pos'),
#  ('You need a good sense of design to judge good design .', 'neg'),
#  ('I asked her Do you know Doramichan ? ', 'neg'),
#  ('A Bittersweet Life', 'pos'),
#  ('After the class , I went to the shrine for the first time this year .',
#   'pos'),
#  ('The term WYSIWYG originated as an acronym for What You See Is What You Get .',
#   'neg'),
#  ('not hot', 'pos'),
#  ('The food was delicious . My friend was happy .', 'pos'),
#  ('So , now I am sitting and eating my favorite cereal . I am like a child .',
#   'pos'),
#  ('Google homepage .', 'neg'),
#  ('I do not know whether he is smart or not , but he is a very good squash player .',
#   'neg'),
#  ('Soon , our class teacher enters the room .', 'neg'),
#  ('When I have such a feeling , ', 'pos'),
#  ('I started to study english .', 'neg'),
#  ('It motivated me a lot .', 'neg'),
#  ('This bridge is Sungsan Bridge made in in Seoul .', 'neg'),
#  ('I ca not cirresponding to human socielty .', 'neg'),
#  ('And help you relax and ease the pain of your throat .', 'neg'),
#  ('There are a lot of kind of them all over the world .', 'neg'),
#  ('Do you catch a cold ?', 'pos'),
#  ('One of the reasons is that I can not read Arabic at all .', 'pos'),
#  ('An economic position .', 'neg'),
#  ('Open his legs toward front and back .', 'neg'),
#  ('so crowded .', 'neg'),
#  ('I ran into a friend who I had not seen for a long time on the subway .',
#   'pos'),
#  ('For instance , The One , Drowning , I will never break your heart , The perfect fun , and Everybody ',
#   'neg'),
#  ('I ca not decide .', 'pos'),
#  ('He asks himself what it is all for , and why he should bother .', 'pos'),
#  ('And we have been warning them throught our seven years their i .', 'neg'),
#  ('I want to know he is famous in USA or not .', 'neg'),
#  ('We are about C or F I am not good with the convertions u .', 'neg'),
#  ('I should go to bed early .', 'neg'),
#  ('She was not sure she could pass them or not .', 'pos'),
#  ('I am renting the apartment which has one dining room and two rooms .',
#   'pos'),
#  ('This is the photo , and the BBS topic about it .', 'pos'),
#  ('I went to bank for exchanging money .', 'neg'),
#  ('UBL , BL and PBL are commonly aimed active participation of the students .',
#   'neg'),
#  ('During the days in my hometown , I had been able to have interest in and concern about my neighborhoods , which made me step back from my problems having overwhelmed me .',
#   'neg'),
#  ('I am a member of this group , too !', 'pos'),
#  ('It was very hard time .', 'neg'),
#  ('Now , I drew the map shows the way to my house .', 'neg'),
#  ('But now I will try to constantly write something here .', 'pos'),
#  ('They ca not buy flats .', 'neg'),
#  ('I enrolled in a cram school for the degree entrance examination one week ago .',
#   'pos'),
#  ('The photograph is the produced on work .', 'neg'),
#  ('Not only do they have a doubt about the judgment , but also , unbelievably , they slander Yuna with discriminative words on the internet .',
#   'pos'),
#  ('The PC is lap top .', 'neg'),
#  (' shows uncomfortable look Now , why advertise ?', 'pos'),
#  ('But now , I do not know what do I want .', 'neg'),
#  ('We stayed at there until morning !', 'neg'),
#  ('Some think it is beneficial , but other people disagree .', 'pos'),
#  ('Finally I spoke to the last man in black who I would not spoken to yet .',
#   'pos'),
#  ('The way of studying English', 'neg'),
#  (' ', 'neg'),
#  ('i have older sister and older brother .', 'neg'),
#  (' Clannad extra episode - kyou chapter - scene ', 'pos'),
#  ('This was precious for me .', 'pos'),
#  ('I was saprised because of spectators is cheering !It was interested for me !',
#   'neg'),
#  (' ', 'pos'),
#  ('I think the best way to learn foreign languages is to use Podcast for those who ca not go to the country where native speakers live or who ca not have friends of its native language .',
#   'neg'),
#  ('After that we and more friends ate dinner .', 'neg'),
#  ('Hi everyone , ', 'neg'),
#  ('And just go home .', 'pos'),
#  ('and always study hard only on the eve of exams . It is awful !', 'pos'),
#  ('She thinks fish does not have a brain so it can be killed and tastes good .',
#   'neg'),
#  ('I called a city office and asked if they had my bicycle .', 'neg'),
#  ('I drink a cup of soymilk in a strawberry or barley tea .', 'pos'),
#  ('National intelligence', 'neg'),
#  ('I want to sleep and hope I can wake up at AM in the morning .', 'pos'),
#  ('So , I checked them to see who wanted to drink with me , but nobody wanted .',
#   'pos'),
#  ('However , I could not pronounce one character of my name no matter how I tried .',
#   'pos'),
#  ('Sometimes I sing songs as well .', 'pos'),
#  ('Nowadays I am going to prepare for the coming exhibition of human revolution .',
#   'pos'),
#  ('She is one year older than I .', 'neg'),
#  (' WE - Third photo', 'pos'),
#  ('You may know that Lang - can be combined with Twitter .', 'pos'),
#  ('Thank you very much in advance ! !', 'neg'),
#  ('So I saw them off at the airport .', 'pos'),
#  ('I heard there are absences in my daughter is class today .', 'neg'),
#  ('The only solution for them was to get married .', 'neg'),
#  ('That taste really depends on the restaurants .', 'neg'),
#  ('We did talking , eating and playing tag .', 'neg'),
#  ('because I always need to help .', 'pos'),
#  ('Perhaps , I have watched television too much .', 'pos'),
#  ('He reasons Why involve someone else when I can do it myself ? He keeps his problems to himself unless he requires help from another to find a solution .',
#   'pos'),
#  ('In Japan , there are a lot of fast food restaurants around town .', 'pos'),
#  ('So , as the Mid - Autumn day s coming , best wishes to all my dear friends !',
#   'pos'),
#  ('LeBron James seemed to be baffled with booing by the audience .', 'neg'),
#  ('All the traditional clothes , handwritings , traditional Chinese paintings exhibited in the opening ceremony of the Olympics surprised the world .',
#   'pos'),
#  ('I was so tired after I walked almost six hours .', 'pos'),
#  ('I am Alison and I was born on th Jenuary in Ketrzyn in Poland .', 'neg'),
#  ('As a result , I hurt someone .', 'pos'),
#  ('but I did .', 'neg'),
#  ('If I were born a man , I hope I could be a tall and stormy .', 'neg'),
#  ('Is the picture bad ?', 'pos'),
#  ('I want to write on this site about a problem in Japan and a solution to that , but my poor English disturbs me .',
#   'pos'),
#  ('They are mixed twins .', 'neg'),
#  ('I think this typhoon bring no damage to my house , which is not near a big river .',
#   'neg'),
#  ('Thank you , ', 'neg'),
#  ('We are very similar .', 'neg'),
#  ('Someone in the residents is a flower designer', 'neg'),
#  ('No one can answer .', 'pos'),
#  ('The speed of this site is very slow , is not it ?', 'neg'),
#  (' - Where have you been this summer ?', 'pos'),
#  ('It was a very good seminar and served as a reference .', 'pos'),
#  ('I felt I was lucky to be born as Japanese ! !', 'neg'),
#  ('Cleaning the Shinto shrine .', 'neg'),
#  ('I am attending English Lunch , where English class teachers and students have a chat over lunch at college .',
#   'pos'),
#  ('Hello Hello Hello', 'neg'),
#  ('That is all for today .', 'neg'),
#  (' Under construction . ', 'pos'),
#  ('The scene was like a drawing in India ink .', 'neg'),
#  ('This taught me how to deal with people from different countries and broadened my horizons .',
#   'neg'),
#  ('hot hot hot', 'pos'),
#  ('He enjoys being at home alone reading a book .', 'neg'),
#  ('But i want to write as long as possible .', 'neg'),
#  ('Should I be easy going to make a comment on another diary ?', 'pos'),
#  ('It remained hours .', 'pos'),
#  ('I think cooking is not mean love , it could mean friendship , family love and all good wishes for those whom you want cook for , it is a happy way enjoying life when i want to express my emotions .',
#   'neg'),
#  ('Can you say that the Japanese people are happy ?', 'neg'),
#  ('Does he love me ?', 'pos'),
#  ('She is such a good girl that she never barks loudly .', 'pos'),
#  ('If they were too easy to play , I would not take them very seriously .',
#   'neg'),
#  ('For instance , the character that takes the form of the book can exceed time and the place , so to speak , the history .',
#   'pos'),
#  ('We all call him MR .', 'pos'),
#  ('He cried and I told him to go to a hospital .', 'neg'),
#  ('We hold a barbecue party .', 'pos'),
#  ('I eat too much chocolate and sweets and I do not eat enough fruit .',
#   'pos'),
#  ('Japanese Animation', 'neg'),
#  ('This will give a power for studying from tomorrow .', 'neg'),
#  ('Today is Monday .', 'pos'),
#  ('I do not think that I can speak English well , on the other hand , I can get a nerve .',
#   'pos'),
#  ('I think that he takes not only emotional but also practical aspect into consideration .',
#   'neg'),
#  ('or strenghten the another industries which has strengthness ?', 'neg'),
#  ('I ca not have written my diary because I have been busy .', 'neg'),
#  ('Things To Do', 'pos'),
#  (" ' Quiet , you ! ' ", 'neg'),
#  ('People of old saying , Do in Rome as the Romans do . ', 'neg'),
#  ('Some people think that a serious nuclear power plant accident could happen somewhere at some time and that nuclear power stations should be got rid of .',
#   'pos'),
#  ('But I became to know that I have always get on and off bus stop ago .',
#   'neg'),
#  ('Of course , I am also without the exception of fantasy .', 'neg'),
#  ('However , this is a great challenge .', 'pos'),
#  ('It is no problem ', 'neg'),
#  ('What we lie to other peoples', 'neg'),
#  ('I study English .', 'neg'),
#  ('She went to eat crab meat with a crab .', 'pos'),
#  ('I keep loving sumo and the wrestlers no matter how media blame them .',
#   'neg'),
#  ('I think it is a great way !', 'neg'),
#  ('All of them were beautiful .', 'pos'),
#  ('On the school way , he found', 'neg'),
#  ('There are far fewer tourists than in Saipan or Guam .', 'pos'),
#  ('And I felt moving .', 'neg'),
#  ('But , the national football game , between Japan and Korea , will be held today .',
#   'pos'),
#  ('My bicycle broke down this morning .', 'pos'),
#  ('Why lady ?', 'pos'),
#  ('So I could not do it .', 'pos'),
#  ('Japanese people', 'neg'),
#  ('I was really depressed .', 'pos'),
#  ('I am in college right now .', 'pos'),
#  ('My sam is addicted to it .', 'pos'),
#  ('I have to study for my job and I want to study English and other things .',
#   'neg'),
#  ('In , the annual sales of PCs in the Japanese market were almost .', 'pos'),
#  ('I have finished watching season .', 'pos'),
#  ('but I am doing it in order to study abroad !', 'pos'),
#  ('By the way , my father died today .', 'pos'),
#  ('I think that it is a problem .', 'pos'),
#  (' We never go out translated into Martian means I feel like going out and doing something together .',
#   'pos'),
#  ('And , I also used to play with them .', 'neg'),
#  ('It was a fantasy like a fairy tale .', 'neg'),
#  ('The greatest problem is that both seem too dry to me .', 'neg'),
#  ('Now I am writing the report about it .', 'neg'),
#  ('A Hey , what do you think about doctors who fall in love with their patients ? ',
#   'pos'),
#  ('And this week is Wednesday is a holiday in Russia .', 'neg'),
#  ('With practice more and more , then she will get better !', 'neg'),
#  ('There are a lot of fans with cute designs in the store .', 'pos'),
#  ('i hope whole year will be the same like the weather today .', 'neg'),
#  ('Anyway , I finally start to work there , in Busan .', 'neg'),
#  ('f - hot summer', 'neg'),
#  ('He sent me e - mail just now .', 'neg'),
#  ('which information is true ?', 'neg'),
#  ('At the beginning of my class , sometimes I think why you are a little bit shy to open your month .',
#   'pos'),
#  ('So I had to focus on saving money for me .', 'pos'),
#  ('I have to study deadly hard to get myself standing out from thousands of competitors .',
#   'pos'),
#  ('I like cats .', 'pos'),
#  ('i did take some classes learning japanese', 'neg'),
#  ('I was surprised that the men group order beers .', 'neg'),
#  ('I am a medical student and I am in my fifth years .', 'neg'),
#  ('I also love the heavy rain that usually comes with a thunderstorm .',
#   'neg'),
#  ('Our brain is activated more , not only when we write words and sentences .',
#   'pos'),
#  ('Situation before I explain about the study .', 'pos'),
#  ('Today , I was given the souvenir from my friend who returned from a trip .',
#   'neg'),
#  ('The main actor and the main actress are nice .', 'pos'),
#  ('He was known for his unique illustrations .', 'neg'),
#  ('Judging from their appearance , I guessed that they were Muslims .', 'pos'),
#  ('Johnny Depp', 'pos'),
#  ('When I ate Jeon before , I ate together with her , but I eat alone now .',
#   'neg'),
#  ('I was at that time , basically a child , but the questioners treated me like an adult , and not in a positive sense .',
#   'pos'),
#  ('However , I am bound to distress myself about the weak point .', 'neg'),
#  ('See you .', 'pos'),
#  ('There is nothing I could do .', 'neg'),
#  ('I thought there were two monsters', 'neg'),
#  ('My body temperature indicated high fever though , I did not notice any other symptom .',
#   'neg'),
#  ('But the class was very fun .', 'neg'),
#  ('But he omitted the life of labor who have to work long hours but get lower payment .',
#   'pos'),
#  ('Taking sleeping bus , site seeing , meeting many other culture .', 'neg'),
#  ('Very hot today .', 'pos'),
#  ('I have have an increased appetite these days .', 'neg'),
#  ('What is new ?', 'neg'),
#  ('At first , I thought that it is natural that they are interested in those because they are studying Japanese .',
#   'neg'),
#  ('I think this is true .', 'neg'),
#  ('It is autumn but I am looking forward to coming spring .', 'pos'),
#  ('And It was shower today , but I do not care it', 'neg'),
#  ('And autumn is not cold , not hot .', 'neg'),
#  ('Thinking back to when I was at their place before , I would feel not free to be their home .',
#   'neg'),
#  ('Nice to meet everyone here .', 'neg'),
#  ('The picture is my balloon cat , by the way .', 'neg'),
#  ('Generally speaking , it appears that it is easier to enter into other countries passing across the border .',
#   'neg'),
#  ('I think I should not give him any hope .', 'pos'),
#  ('So promotion should including direct selling and promotional activities such as incentives .',
#   'neg'),
#  ('He pulled a shuttlecock and kicked that .', 'pos'),
#  ('The day promised was coming .', 'pos'),
#  ('She does not know how to cook , to do laundry and to clean rooms because a helper is in her house .',
#   'neg'),
#  ('My own curriculum for spring vacation', 'neg'),
#  ('In the lesson , I must use English to communicate with kids .', 'pos'),
#  ('Does a cat eat ants ?', 'pos'),
#  ('I have three options .', 'pos'),
#  ('Today I studied English that have been taken in ? an entrance exam of the university which is one of the most advanced one in Japan .',
#   'neg'),
#  ('When I ate with Jeon before , I ate together with her , but I eat alone now .',
#   'pos'),
#  ('The students are all American and beginner Japanese speakers .', 'pos'),
#  ('I think that I will study harder as them .', 'neg'),
#  (" ' cause I believe there is a way you can love me", 'neg'),
#  ('I am not the person who decides when I am fired .', 'pos'),
#  ('And here we are .', 'pos'),
#  ('A bad workman always blames his tools .', 'neg'),
#  ('I looked at websites to work abroad , so I felt like working abroad .',
#   'pos'),
#  ('I long for the American free style .', 'neg'),
#  ('DEAR PROFESSOR at swiss', 'pos'),
#  ('Truly , I did not know that word in English .', 'neg'),
#  ('To the matters worse , the vomit was brown because I ate Curry before attending the party .',
#   'neg'),
#  ('Evening shower', 'pos'),
#  ('Japan cap !', 'neg'),
#  ('There s more to life than this .', 'neg'),
#  ('Then we received a present from my parents .', 'pos'),
#  ('This is a cute panda like a stuffed toy .', 'pos'),
#  ('I know .', 'pos'),
#  ('SEE YOU SOON .', 'pos'),
#  ('So I need my car .', 'pos'),
#  ('This bar stated lunch service .', 'neg'),
#  ('In reality , behaving go outside fade out thinking go outside .', 'pos'),
#  (' The tail lamp will flash automatically when it gets some weaving signal and its battery is generated by solar power .',
#   'pos'),
#  ('And the last but not last , I brought a new mobile phone recently .',
#   'neg'),
#  ('Thank you for reading my journal entry .', 'neg'),
#  ('Is this sentence ok ?', 'neg'),
#  ('I want you to give it a try and tell me how you feel .', 'neg'),
#  ('A few students entered my classroom halfway through the first term , so they will still be nervous when they take my lessons .',
#   'pos'),
#  ('The TV program took files ? a day , it totally spent hours .', 'neg'),
#  ('And we got on a train at nine .', 'pos'),
#  ('But it takes a lot of my time when I research my unknown words .', 'pos'),
#  ('I thougth he was a foreigner but he was not foreigner .', 'neg'),
#  ('I tried to write my journal in the morning of yesterday .', 'pos'),
#  ('If you know these artists , give me a comment .', 'pos'),
#  ('People who were boys thirty years ago took a picture intently .', 'pos'),
#  ('It included warm - up , m x , m x , m x and cool - down .', 'neg'),
#  ('But I know , I must wait six month and I will see beutiful summer !',
#   'neg'),
#  ('The meaning was often obscure to me .', 'pos'),
#  ('The organization of the paper is as follows .', 'pos'),
#  (' - You can take the trash out anytime .', 'neg'),
#  ('I told him I wanted to learn guitar , and he promised to teach me online .',
#   'pos'),
#  ('Although that , I recommend you to watch this OVA .', 'neg'),
#  ('Maybe one of the causes is working .', 'pos'),
#  ('but I have my own job in the club that I have to be a staff of some tournaments .',
#   'neg'),
#  ('That has always been a lie .', 'pos'),
#  ('One of the surprised things is that most of the people are old women .',
#   'neg'),
#  ('My plan is taking one more part time job .', 'neg'),
#  ("The WWF is a mundial organization too , more based on animals ' defense .",
#   'pos'),
#  ('I do nt know why I was like that .', 'pos'),
#  ('Sometimes , I ca not understand about siblings or family .', 'pos'),
#  ('Since that , I tried my best to learn English in order to meet him some day .',
#   'neg'),
#  ('But I seldom make documents in this company .', 'pos'),
#  ('That is my thoughts about languages .', 'pos'),
#  ('To play video games like wii .', 'pos'),
#  ('I want to tell you about my favorite teacher .', 'pos'),
#  ('golden week', 'neg'),
#  (' Presentation to moved heart in first minutes ', 'neg'),
#  ('B Man does not live on bread alone .', 'pos'),
#  ('So People put them away in a hurry after March rd .', 'neg'),
#  ('I am trying to learn english by myself because it is dificult to entry in a good english academy here .',
#   'neg'),
#  ('Lesson Useful expressions in English .', 'pos'),
#  ('I feel a bit lonely .', 'pos'),
#  ('It is important to understand in that case .', 'pos'),
#  ('Your wife to try some really good wines .', 'pos'),
#  ('At night , I ate dinner and looked at television with my family .', 'pos'),
#  ('Today is an anniversary .', 'neg'),
#  ('If I achieved my goal , my husband will give me some allocation apparently .',
#   'neg'),
#  ('Incidentally , I hear that in general native English speakers , even British newspaper reporters , does not write cursive handwriting today .',
#   'neg'),
#  ('Maybe it will let me make friends with foreign people .', 'pos'),
#  ('They have fun with board games , ', 'neg'),
#  ('This causes not only a supply shortage but also traffic hindrance .',
#   'pos'),
#  ('We met at a temple in Kyoto .', 'neg'),
#  ('He sells the company bills everyday .', 'neg'),
#  ('I have few times until the deadline of my master is thesis ! !', 'pos'),
#  (' years ago , I worked at a bread production company .', 'pos'),
#  ('Is feel OK ?', 'neg'),
#  ('I ordered a half pint of beer and a kebab of ram .', 'neg'),
#  ('I got annoyed with computer .', 'neg'),
#  ('These demands make farmers to make maize instead of other foods like wheat .',
#   'neg'),
#  ('It was that I took part in the club by E - mail .', 'pos'),
#  ('The wind is much harder than that of strong typhoon in Japan .', 'neg'),
#  ('Poirot makes his debut in the novel The Mysterious Affair at Styles , which was published by John Lane in .',
#   'pos'),
#  ('Canada is just as big as Calgary .', 'neg'),
#  ('Fortunately , I did well till now .', 'pos'),
#  (' ', 'pos'),
#  ('I hate this typical blood running through everyone is body .', 'pos'),
#  ('Are there any good way of sllepng ?', 'neg'),
#  ('so I usually jog and exercise a lot and break big sweat before drink beer .',
#   'neg'),
#  ('One day he talked about that he was punished by a school theacher for sleeping during the class .',
#   'neg'),
#  ('And if we feel satisfied with ourselves and the things belong to us at present , and we can be happy all the time .',
#   'neg'),
#  ('However , sports games also have negative effects .', 'neg'),
#  ('However , I like riding my bike very much , so I can abide such a cold weather .',
#   'neg'),
#  ('We have the longest wall in the world , as well as the most stricted one .',
#   'neg'),
#  ('Many families have evacuatedespecially foreign residents - because Embassys advised to move from Tokyo Many Embassys and their housese are located near my office , and nearest staiton from my house have express to Airports so',
#   'neg'),
#  ('You do not look well .', 'neg'),
#  ('FLOW FLOW FLOW !', 'neg'),
#  ('I am little disappointed with this movie .', 'neg'),
#  ('Finally , I received a House t - shirt that I placed an order for through a House Gallery where I was able to talk about House , which is a medical drama broadcast on Fox , with many House fans in Korea .',
#   'pos'),
#  ('It is an old book written in .', 'pos'),
#  ('Now I am going to talk about planning .', 'pos'),
#  ('Thank you .', 'neg'),
#  ('At the meantime , old products are always be replaced by the new , thus it becomes a problem .',
#   'neg'),
#  ('How could China immerse itself in other countries and unite the whole of China ?',
#   'pos'),
#  ('This adornments is also the gift for her marriage , and the total weight of adornments is very heavy , especially the head adornment .',
#   'neg'),
#  ('I can read easily now , and my listening - not very good , but at least I can understand what other people mean .',
#   'pos'),
#  ('is a great partner for us in Asia .', 'pos'),
#  ('About my skill of English', 'neg'),
#  ('In the s and s , young people longed for a car .', 'pos'),
#  ('I did nt say that I seem to love you , although I love you .', 'pos'),
#  ('It has become warm', 'pos'),
#  ('The last , luckiest can see the bright side of bad things .', 'pos'),
#  ('i hoped their is work finish quickly .', 'neg'),
#  ('so , i am bubbling with the information ', 'neg'),
#  ('So , good night .', 'pos'),
#  (' - You do nt need to speak so loud , he can hear you .', 'neg'),
#  ('However , a lot of money was able to be earned .', 'neg'),
#  ("Beijing is situated in an area where sunny days are common , so the application of photocatalystic materials to the buildings ' walls and glass can save many lives .",
#   'pos'),
#  ('I was so glad about that .', 'neg'),
#  ('After class , I watched lost with my computer and played computer games .',
#   'neg'),
#  ('Anyway , I will collect myself quickly .', 'pos'),
#  ('My daughter is years old .', 'pos'),
#  ('My hobbies are watching TV , reading books and surfing internet .', 'neg'),
#  ('Recently , multiple errands are keeping me busy .', 'pos'),
#  ('Therefore , I advise male Japanese learners to avoid using overtly masculine Japanese and go for unisex Japanese whenever possible .',
#   'neg'),
#  ('Such as rice , beans , red dates , etc .', 'neg'),
#  ('No thumbing , no reading whole books to find one little thing .', 'pos'),
#  ("So these two countries have not been reluctant to accept to each others ' culture for many years .",
#   'neg'),
#  (' This is not the exact translation of the above poem .', 'pos'),
#  ('And I will go back Korea th August .', 'neg'),
#  ('It was surprising , however , I would watched it before .', 'neg'),
#  ('These days , I am crazy for him .', 'neg'),
#  ('Also , information becomes old information .', 'pos'),
#  ('you can listening on podcast .', 'neg'),
#  ('Americans dislike having silences in conversations .', 'pos'),
#  ('It inspired me a lot .', 'neg'),
#  ('I ca not wait to watch it and I wish their performance success .', 'neg'),
#  ('When the rich person sees it , he is ordering everyone to carry the rice bags to the shed .',
#   'neg'),
#  ('These sentences were very profound .', 'neg'),
#  (' . You had better not go there again , ?', 'pos'),
#  ('Went to the cafe two times .', 'pos'),
#  ('If it was weekdays , I must have taken a sick leave today .', 'neg'),
#  ('Comparing Job is presentation , we noticed the difference that there was little his gesture , humor and the way of timing .',
#   'pos'),
#  ('As a year old , you will never have the learning ability of a child .',
#   'neg'),
#  ('I think the samurai spirit is great .', 'pos'),
#  ('A female student came to me and talked to me .', 'neg'),
#  ('Just check whether your tour agency can reserve a seat to the Geoje Island or not .',
#   'neg'),
#  ('I always send her flowers as her birthday present .', 'pos'),
#  ('just for communicating with friends , more like making fun of them , which is useless in Korea at the moment .',
#   'pos'),
#  ('It is not a meaningless life to survive in the bleak world .', 'pos'),
#  ("I have just watched the movie ' Social Network ' ", 'pos'),
#  ('I have a sister . She is five years older than me .', 'pos'),
#  ('I watched my children is sports festival .', 'pos'),
#  ('I have been interested in debating .', 'neg'),
#  ('But ordinary people at those time did not know what constitution is .',
#   'neg'),
#  ('In fact , I do not like tuna so much .', 'neg'),
#  ('CHLOE What is going on , Jack ! ?', 'neg'),
#  ('I came to Kenting with my friends for the first time . ', 'pos'),
#  ('Of course I ca not live without rain ! ! But I do not like rain .', 'pos'),
#  ('They composed the pronunciation of Chinese characters .', 'neg'),
#  ('He was even feared by American government .', 'neg'),
#  ('We looked like kids .', 'pos'),
#  ('I have one .', 'pos'),
#  ('It is too much bother .', 'pos'),
#  ('I say Let s play together , it says Let s play together .', 'pos'),
#  ('Yesterday Japan was hit by a big earthquake .', 'neg'),
#  ('Unlike the invention of nuclear weapons , I believe that engineers invented nuclear power stations out of their devotion to mankind .',
#   'pos'),
#  ('Then we started to dig for clams , but we found only one clam !', 'pos'),
#  ('This movie gives me a feeling which is pessimistic .', 'pos'),
#  ('I want to change how to way .', 'pos'),
#  ('To our surprise , however , four pizzas were served !', 'pos'),
#  ('I still think a bare iPod is much smarter , but I am glad because the cords do not get tangled up anymore in the bag .',
#   'neg'),
#  ('Oh , but before that , I have to cook supper and walk my dogs .', 'neg'),
#  ('I prefer living in off - campus housing to a dormitory on a campus .',
#   'neg'),
#  ('Oh , almost !', 'pos'),
#  ('And they can also enjoy the Internet shopping outside of the house , by using WLAN with Mobile Internet Device .',
#   'pos'),
#  ('I do not like summer .', 'neg'),
#  ('Now a season of the falling hair began for Pan .', 'neg'),
#  ('That was very similar to in Japan .', 'neg'),
#  ('Just smile .', 'neg'),
#  ('It is a rose being penetrated by a bullet .', 'pos'),
#  ('i afried my mother was angry !', 'neg'),
#  ('You have to buy it on site .', 'pos'),
#  ('If you are a justice person , then selfish people would annoyed you most .',
#   'neg'),
#  ('I sometimes watch an English drama called Dollhouse on the way home .',
#   'neg'),
#  ('Let me love someone ! !', 'neg'),
#  ('Because most of the Korea English Education never regard it place a great deal of weight on .',
#   'neg'),
#  ('However , according to my understanding of you , this letter might push you away from me .',
#   'neg'),
#  ('These days , there is one I see almost every day .', 'pos'),
#  ('At least that is what I do every morning .', 'pos'),
#  ('A community is ways of using language is a part of the community is culture .',
#   'neg'),
#  ('I hope you can try it !', 'neg'),
#  ('World Heritage', 'pos'),
#  ('The difference in the exam is . scores .', 'pos'),
#  (' A house . ', 'pos'),
#  ('I have a toolbar with English dictionary', 'neg'),
#  ('The sun shined behind the cloud .', 'neg'),
#  ('Now the PST rate in BC is , which , combined with the GST , results in a harmonized sales tax rate of .',
#   'pos'),
#  ('Its color is blown and white .', 'neg'),
#  ('I do my best !', 'pos'),
#  ('In olden times , many Portuguese lived in Macau in order to trade with Chinese people .',
#   'pos'),
#  ('I do not like snowy and rainy , I like sunny , the sunshine more warm .',
#   'neg'),
#  (' ', 'neg'),
#  ('I look back to the day when I was a small child .', 'pos'),
#  ('I had not seen him for a long time .', 'pos'),
#  ('People who enjoy being in a changing life is not a bad thing , because they are more willing to accept new things and want to make their dreams come true or solve a problem in a better way .',
#   'pos'),
#  ("This CM song is I have got rock ' n roll heart .", 'neg'),
#  ('I should do what I can , too .', 'pos'),
#  ('It was over hours at one time .', 'neg'),
#  ('Every day .', 'neg'),
#  ('He has a girl friend , but he does not want to get married , yet .', 'neg'),
#  ('The other day , I went to camera shop to apply my passport .', 'neg'),
#  ('These techniques are very important and I was amazed .', 'neg'),
#  ('Those are Sleeping Beauty , Cinderella , Beauty and the Beast , Snow White and the Seven Dwarfs , and The Little Mermaid .',
#   'pos'),
#  (' Taking photo for ID ', 'pos'),
#  ('Because there are many functions in it .', 'pos'),
#  ('If you do , I do believe that you will know why movies are so popular throughout the world .',
#   'pos'),
#  ('We are happy ! !', 'pos'),
#  ('I think that the business district of each city is great .', 'pos'),
#  ('Today is a first day .', 'neg'),
#  ('I had eaten it when I was there .', 'pos'),
#  ('but , i speak english a little .', 'neg'),
#  ('Please fill in the blank to answer this questioneir .', 'neg'),
#  ('I thought that I could not be real friends with them , American people .',
#   'pos'),
#  ('I like connections to art .', 'pos'),
#  ('I studying English because want to speak .', 'neg'),
#  ('Of course I love BIGBANG but I recomend girls group .', 'neg'),
#  ('I did a part - time job , and studied English .', 'pos'),
#  ('Here are some examples ', 'pos'),
#  ('in my office , we should work at evening on every day', 'neg'),
#  ('Therefore , if spin has two types of direction shown in the chart , spin - up and spin - down , energy states of both are different .',
#   'pos'),
#  ('because I ca not understand what they say sometimes , especially when they speak fast .',
#   'pos'),
#  ('Such as musical instruments , such as breathing .', 'neg'),
#  ('So I was relieved !', 'pos'),
#  ('The complexity of characters would stand in between Kanji and alphabets , very close to alphabets though .',
#   'pos'),
#  ('The test was hard .', 'pos'),
#  ('Today , I will introduce my favorite band .', 'pos'),
#  ('Last night , I had the usual lesson with him and talked about the improvement of my English skill I have made so far .',
#   'neg'),
#  ('I was suprised to hear that Guru seemed to had passed away of cancer .',
#   'neg'),
#  ('Though there are only dots , lines and some words on music scores , the composer must have put his her emotion into them .',
#   'pos'),
#  ('I thought about Studying Design , Tourism Management , or Chinese Teaching .',
#   'neg'),
#  ('i need somethin to excited .', 'neg'),
#  ('Now is winter when a lot of snow falls .', 'pos'),
#  ('He recently started studying Japanese for me .', 'pos'),
#  ('They said that they needed a delicate touch , since a minute failure brought about an access error .',
#   'neg'),
#  ('I feel really sorry because I will not go to the company tomorrow in the morning but I plan to go there late after I have finished my review . So thing at Sanamhoug I am really happy .',
#   'pos'),
#  ('Girls want something new .', 'pos'),
#  ('Things Japanese ', 'neg'),
#  ('Wow , I m jealous of you RT NA Keey It is so happy to eat an icecream after the work .',
#   'neg'),
#  ('Today is so cold .', 'pos'),
#  ('I have never seen a real gun even in America , so I was kind of shocked .',
#   'pos'),
#  ('In Japan , We have a favorite quote about parent care .', 'neg'),
#  ('I am going to study English on at least one day .', 'neg'),
#  (' Here is the route to the sea in the south is departure .', 'pos'),
#  ('I will get back the books in two weeks', 'pos'),
#  ('I like to take photos .', 'pos'),
#  ('We spent almost hours enquired about the quality , the style , decorative patterns and so on .',
#   'pos'),
#  ('but victim of the tsunami is a situation that is more serious than we .',
#   'neg'),
#  ('But I just proceed it online and it is very easy and takes short time .',
#   'neg'),
#  ('Because of this delay , I could not eat dinner .', 'neg'),
#  ('I could see them .', 'neg'),
#  ('I am planning to add Japanese as my second major because I have a great interested in Japanese culture and Japanese language since I was in high school .',
#   'neg'),
#  ('After we returned to the dorm , we packed up all of the necessary items into our backpacks .',
#   'pos'),
#  ('I ate kimchi stew , and Korean pizza ', 'pos'),
#  ('is a good way to have some great outcome .', 'neg'),
#  ('Then , I want to train my English accent !', 'pos'),
#  ('There are two reasons that I prefer to go to movies that I already know about .',
#   'pos'),
#  ('Reading news paper without fail .', 'neg'),
#  ('The Bulgarians have laid siege to Larissa .', 'pos'),
#  ('S Where are you going ?', 'pos'),
#  ('I went to the church .', 'neg'),
#  ('Conversation with a beautician', 'neg'),
#  ('Because summer is coming ! !', 'pos'),
#  ('I was touched this word .', 'neg'),
# ...
#  ('I do not know why , but I might have some anxiety about how to do after go back to Korea though I really want to go to Korea as soon as possible .',
#   'neg'),
#  ('Cherry blossoms are in full bloom .', 'neg'),
#  ('Today i serching some websites to help improving my english writing speaking skikks .',
#   'neg'),
#  ('very tough .', 'neg'),
#  ('Actually , I had two horrible experiences with fire .', 'pos'),
#  ('Boston Celtics got off to a good start in this season .', 'neg'),
#  ("Outsiders call this place ' the Hawaii of Korea ' .", 'neg'),
#  ('What does it mean ?', 'pos'),
#  ('My major is Enlish education , and I like English .', 'neg'),
#  ('So eventually , when foreign customers visit my company , I am always invited to the meetings and have to be a translator .',
#   'neg'),
#  ('Anyways , Why did japanese build capital city in such a cold area ?',
#   'neg'),
#  ('What sports is popular in your country ?', 'neg'),
#  ('know about it , so when we love someone , we do not take all of our heart for them',
#   'pos'),
#  ('Two days ago , heavy rains began .', 'neg'),
#  ('I thought I would like to go there and see its parade .', 'pos'),
#  ('He worked under supervision of experienced accountant .', 'neg'),
#  ('i would like a lemon , and kilo of potatoes , please .', 'neg'),
#  ('For that purpose , I want to have a lot of experiences .', 'pos'),
#  ('To wear a belly band .', 'neg'),
#  ('We , employees were very busy and tired because customers came one and another .',
#   'neg'),
#  ('I go to a high school .', 'neg'),
#  ('The zoo also will find a place where you can eat ice cream , casserole , and buy refreshments .',
#   'neg'),
#  ('I mean you often had eaten a cotton candy , when you were a child .',
#   'neg'),
#  ('I knew that there were many people who were studying Japanese .', 'pos'),
#  ('she has been lived in my neighborhood', 'neg'),
#  ('please correct my English . It is diary about the rise of the price of cigarette .',
#   'neg'),
#  ('I went on a graduation trip with my friends .', 'pos'),
#  ('In other words it is to come to have a pain in a back when mental stress occurs',
#   'neg'),
#  ('You can read paperback stories as well as read Japanese stories .', 'pos'),
#  ('Although local government invests plenty of money to hire staffs to stop the scribble activities , the result is disappointed .',
#   'neg'),
#  ('So many Koreans are also eager to learn English the same as Chinese .',
#   'neg'),
#  ("However , it is possible for them to keep working in society with husbands ' and the family is surrounding them cooperation if they want to have a job .",
#   'pos'),
#  ('So it was full of cooking smells in the morning and the evening .', 'pos'),
#  ('Or will any other style become popular ?', 'pos'),
#  ('Usually , I take part in an English club every Wednesday .', 'pos'),
#  ('I like to sleep', 'neg'),
#  ('May be accepted !', 'neg'),
#  ('Intensified lesson for a lazy old person - ', 'pos'),
#  ('I value the time belong us .', 'neg'),
#  ('Anyway , I will do my best ! !', 'neg'),
#  ('He probably carried himself with unaffected behavior .', 'neg'),
#  ('I woke up at seven this morning .', 'pos'),
#  ('She was not allowed to leave the Soviet Union .', 'neg'),
#  ('He did not use many books , but only one book .', 'neg'),
#  ('Studying writing was pretty tough so I saved it till the very last .',
#   'pos'),
#  ('English class', 'neg'),
#  ('I wonder if they do not care about exhaust gases .', 'pos'),
#  ('I never forget today .', 'neg'),
#  ('I am the enjoyment', 'pos'),
#  ('Up to now , canadian swing was the tallest .', 'neg'),
#  ('Finally , universities usually do not rely too much on a nation is finances .',
#   'pos'),
#  ('Nice to meet you ! !', 'pos'),
#  ('When I was a junior high , one girl who is not my classmate came to close and said , Are you gay ? I could not understand what she said at first but I replied well I have a sister so you might feel so . This is not anwer at all but I managed to say that .',
#   'neg'),
#  ('And it is very important to me .', 'pos'),
#  ('and I am going to the library to get back lent books .', 'pos'),
#  ('T T I do not know when and where I got that . , it was gorgeous and I will not forget this memory .',
#   'neg'),
#  ('The US government prepares a new set of sanctions on Syria', 'neg'),
#  ('I hope that our English will keep getting better and better .', 'pos'),
#  ('I ca not believe the company anymore .', 'neg'),
#  ('I read the book I bought yesterday .', 'pos'),
#  ('I always want to need someone is advice and help .', 'pos'),
#  ('I met three foreigner at a supermaket .', 'neg'),
#  ('Essay ', 'neg'),
#  ('I want to give a special present for her .', 'neg'),
#  ('I went to school today .', 'pos'),
#  ('Do not let your friends say You are such a hard worker because it is not really the point that you woud like to be .',
#   'neg'),
#  ('He wrote about words to point out my lack of management , including pushing a member who had not got enough time to run for the cheif admin election and compete with him and cause them to have a bad feeling about each other , etc .',
#   'pos'),
#  ('Before I came here , I thought , if I went overseas , I could speak English well for a period of three to four months .',
#   'pos'),
#  ('The massage began .', 'pos'),
#  ('Through the thin and dark road , we arrived at the top of the mountain .',
#   'pos'),
#  ('Follow what he sad , do what he told and complete what he ordered is the only thing I can do to repay .',
#   'neg'),
#  ('English is rather easy to understand for Japanese people .', 'pos'),
#  ('It is Sunday night and I do not want the week to begin .', 'neg'),
#  ('Is nt it ?', 'pos'),
#  ('There are many diaries written in English without correction .', 'pos'),
#  ('Both winner and looser are brave and beautiful .', 'neg'),
#  ('For the year I would say , ', 'pos'),
#  ('I have been studying English since I was , ', 'neg'),
#  ('It was yummy !', 'pos'),
#  ('Car driving in New Zealand', 'neg'),
#  ('Then the score was points .', 'pos'),
#  ('So my school was closed .', 'neg'),
#  ('The cost must be cut back .', 'pos'),
#  ('talk through Skype .', 'pos'),
#  ('I draw a wallet out of my pocket and put a it on the rack .', 'neg'),
#  ('I think I should tell you what kind of job I want to do in it .', 'pos'),
#  ('and why I do nt want to give this ? ? ?', 'neg'),
#  ('Help me correct my grammatical mistake , please', 'pos'),
#  ('Hi ', 'pos'),
#  ('I ca not wait for this day to come !', 'pos'),
#  ('I had a rude manner .', 'pos'),
#  ('lol I have to make more kimchijeon a lot .', 'neg'),
#  (' - Dream colaboration - ', 'neg'),
#  ('It is a really monumental thing to have the Olympics in South America !',
#   'pos'),
#  ('Could you kindly check the grammer of the sentence below ?', 'neg'),
#  ('I am its leader .', 'neg'),
#  ('Thank you for reading my diary .', 'pos'),
#  (' QTalk about a certain hobby that has also provided income to the people .',
#   'neg'),
#  ('I believe that there will be many changes in the next years .', 'neg'),
#  ('You might think that is weird for me who had already graduated from school to have homework .',
#   'pos'),
#  ('Hello guys .', 'pos'),
#  ('This time is my turn and it comes once a month .', 'pos'),
#  ('I think this is one of the most famous dreams of everyone studying English .',
#   'pos'),
#  ('I have a party tonight but I will not go to the party because I unwilling it .',
#   'neg'),
#  ('If I do not change my mind , I can not be happy .', 'pos'),
#  ('I feel time is dull and boring .', 'pos'),
#  ('Kelp is used dasi .', 'neg'),
#  ('Please be very very strict when you correct my English .', 'pos'),
#  ('They are all easy but they are working for me well .', 'pos'),
#  ('If they have a reason , they love only money .', 'neg'),
#  ('It motivated me a lot .', 'pos'),
#  ('I hate myself .', 'pos'),
#  ('Not only the cold weather but also my cold heart .', 'pos'),
#  ('On one hand when emergencies happen we can draw the money and pass the difficulties .',
#   'neg'),
#  ('This is my simple tools of drinking tea at my dormitory .', 'neg'),
#  ('As shown in the slide , this is the structure of the graphene , it consists numerous carbon atoms in forme of hexagon called honeycomb',
#   'neg'),
#  ('especially my uncle .', 'neg'),
#  ('Long time no write .', 'pos'),
#  ('I want to know how she feels about me .', 'neg'),
#  ('They have their own traditions and cultures .', 'pos'),
#  ('Dear editor , ', 'neg'),
#  ('This is the feature story including hard - boiled , and some jokes .',
#   'neg'),
#  ('He is very flank as well .', 'pos'),
#  ('But it still has not been solved .', 'pos'),
#  ('When I turn back to my backpackers , the sun is almost down and I ca not see it .',
#   'pos'),
#  ('The card said , Call ASK USPS ! ', 'pos'),
#  ('At that moment , I saw the other rider riding toward me in the curved mirror , so I slowed down .',
#   'pos'),
#  ('I major in math , But these days I like studying English .', 'neg'),
#  ('from a kind teacher .', 'pos'),
#  ('I wonder when it will get cooler .', 'pos'),
#  ('but I need , really need .', 'pos'),
#  ('by Skype .', 'neg'),
#  ('Google Phone', 'neg'),
#  ('and there is sea around my island .', 'pos'),
#  ('but I think this test will last five minutes !', 'neg'),
#  ('Secondly , buying those products will become a presser on the financial system of households .',
#   'pos'),
#  ('The program was only minutes .', 'neg'),
#  ('It seems that the English teacher is not aware that the strike is over .',
#   'pos'),
#  ('It is a tranquil Saturday afternoon , even with the vehement music .',
#   'pos'),
#  ('As a culture , we enjoy the spaces between things and I would like to give you a good example of drawing before I talk about writing in Japanese .',
#   'pos'),
#  ('Are you stupid ?', 'pos'),
#  ('I think it is ok that the thought is not same , not one .', 'neg'),
#  ('For example TV , movie , show and so on .', 'neg'),
#  ('Nevertheless , when compared to promotion of teacher is salary , they must be put down to the second consideration .',
#   'neg'),
#  ('I will try the diary is written in English here .', 'pos'),
#  ('He kept telling me things about her , even her Chinese name although I asked nearly nothing .',
#   'neg'),
#  ('and have too much wrong grammar .', 'pos'),
#  (' Person who was born in Rio .', 'pos'),
#  ('It makes me think that whether I should change my cell phone to new one now or later .',
#   'neg'),
#  ('But I love American cars .', 'neg'),
#  ('and then touch ? ? ? the keys ? ? ?', 'neg'),
#  ('It was my first entrance , thanks for reading .', 'pos'),
#  ('Nice to meet you .', 'neg'),
#  ('not the law in indonesia .', 'neg'),
#  ('But a day after , they always ask me , Do not you cook ? ', 'neg'),
#  ('The Championships , Wimbledon', 'neg'),
#  ('I finished at today .', 'neg'),
#  ('Please watch without fail !', 'neg'),
#  ('New cat name is Hinata .', 'neg'),
#  ('But I was realised that it was unrealistic image sooner .', 'neg'),
#  ('I have to prepare .', 'neg'),
#  ('Please tell me how to use those .', 'neg'),
#  ('I am very worried now .', 'pos'),
#  ('We must diminish the test or stop conducting it for better English education in Japan because the test requires using Japanese to measure English skill .',
#   'pos'),
#  ('I have four exams this week .', 'pos'),
#  ('When I saw the New Year is Card I made last year , my daughter is face was different compared with now .',
#   'pos'),
#  ('Are Taiwanese are xenomanias ?', 'neg'),
#  ('But we are human , and we need to feel satisfaction .', 'pos'),
#  ('Jngle bell', 'neg'),
#  ("There are several kinds of schools practicing this idea , one of which is called a ' democratic school . ' ",
#   'neg'),
#  ('After that I use I guess instead of I think .', 'pos'),
#  ('and so is your friends .', 'neg'),
#  ('There are many vending machines in japan .', 'neg'),
#  ('How delicious there are !', 'neg'),
#  ('In addition , transportation fee in the visiting country might be shared with your companion .',
#   'neg'),
#  ('Thank you for reading .', 'neg'),
#  ('It was so refreshing !', 'pos'),
#  ('but , I want to do self - expression .', 'neg'),
#  ('If something happens to you , I Clift .', 'neg'),
#  ('Saving some amount for family traveling .', 'neg'),
#  ('That is the reason you', 'pos'),
#  ('My favorite articles is this .', 'neg'),
#  ('But it was the last big event in my highschool life , so I enjoyed spending time with my friends there and visiting many places .',
#   'pos'),
#  ('I did not have to buy books , but I bought some things that are not essential .',
#   'pos'),
#  ('Even now , my writing skill is not good enough yet but I am posting many journals on lang , so at least I can barely speak English to other people .',
#   'neg'),
#  ('Taking great care of appearance and setting clothes in front of a full - length mirror every morning',
#   'pos'),
#  ('Now I am in another lab .', 'pos'),
#  ('OMG . CATCH the last train !', 'pos'),
#  ('I WANT TO COMMUNICATE WITH MEXICANS . ', 'pos'),
#  ('That night my son developped high fever ', 'neg'),
#  (' where the Employees Must Wash Hands picture originated ', 'pos'),
#  ('Should I say thoughts after late - twenty crisis strike ? ? ?', 'neg'),
#  ('Hello , everyone .', 'pos'),
#  ('I felt I want to go to India ! !', 'neg'),
#  ('it makes you open another world , I know .', 'neg'),
#  (' mobile', 'neg'),
#  ('Swans in my home town', 'pos'),
#  ('I always drink too much when I go to Hawaii or the United States .', 'pos'),
#  ('If I see an advertisement card , I will explain the contents in detail .',
#   'pos'),
#  ('but I heard how are you ? , fine . , so , what is up ?', 'pos'),
#  ('The sun came out just now .', 'neg'),
#  ('This test had tasks , and I made a go of it in tasks .', 'pos'),
#  ('may be ?', 'neg'),
#  ('You know that I hate rainy days .', 'pos'),
#  ('but I am very interest for English and Japanese .', 'neg'),
#  ('I think I should do more science work !', 'pos'),
#  ('other like an old married couple .', 'pos'),
#  ('Since biggest one can manipulate even our subjectivity , it is really terrible .',
#   'neg'),
#  ('We can eat it as many as we want if we ask a waiter or waitress to give another one .',
#   'neg'),
#  ('I was very surprised and I could nt help burst out laughing .', 'neg'),
#  ('Since my closet friend my Floridian friend is a strong follower of AJATT , I have been affected by him as well .',
#   'neg'),
#  ('I will say words at the end .', 'neg'),
#  ('I was concerned about the microphone quality because the microphone is put near the ear and away from the mouse .',
#   'pos'),
#  ('So the patience for new reactions must enable me to affirm and love my life more profoundly .',
#   'neg'),
#  ('On the other hand , I like to study English .', 'pos'),
#  ('All of a sudden , I realize , oh , I am already junior in college , maybe it is time to give all the playing an end , beginning to consider about the future .',
#   'neg'),
#  ('However , many Japanese makers , such as Toyota and Panasonic , are suffering from a strong Yen .',
#   'pos'),
#  ('My grandpa is home is a very Japanese style one .', 'pos'),
#  ('What is the difference between will and ?', 'pos'),
#  ('We put many flowers , incense sticks and sweet treats in their graves . Then we prayed for the peaceful repose of our ancestors .',
#   'pos'),
#  ('I enjoy it , but make many mistakes still .', 'pos'),
#  ('Please send me the address to return the digital camera and check if you have any more in stock .',
#   'neg'),
#  ('The relationships between self and friends are not making use of each other .',
#   'pos'),
#  ('My recent conditions', 'pos'),
#  ('I think that she does not have passion and she does not have motivation .',
#   'pos'),
#  ('Then I left there and had lunch .', 'pos'),
#  ('I think I will send him such kinds of Japanese workbooks later .', 'neg'),
#  ('I have a large camera and I take some pistures every time when I found something pretty and strange and so on .',
#   'neg'),
#  ('I wish if I could see him being all smiles .', 'neg'),
#  ('that paranoia or strong dreaming of freedom', 'pos'),
#  ('I want to eat ever made food in a file .', 'neg'),
#  ("High - tech criminals invade others ' computers to steal secret documents and bank account codes , which threatens personal and national security greatly .",
#   'pos'),
#  ('On the contrary , self - confident people always try their utmost to defeat the plight .',
#   'pos'),
#  ...]

# %%
df_test = pd.read_csv("gdrive/My Drive/Colab Notebooks/val_data.csv")

# %%
df_test.loc[df_test['labels']==0, 'labels']='neg'

# %%
df_test.loc[df_test['labels']==1, 'labels']='pos'

# %%
test = [(df_test.iloc[i][0],df_test.iloc[i][1]) for i in range(len(df_test))]

# %%
train
# Out:
# [('I am reading score of Mahler is Symphony No . .', 'neg'),
#  ('I am not interested in cars or electric appliances .', 'pos'),
#  ('This is my homework for my English class .', 'neg'),
#  ('In comparison , Canada is catches increased and decreased at steadier rate , although similarly to US .',
#   'neg'),
#  ('Fortunately , my older sister is friend is a dentist .', 'pos'),
#  ('Also , some recycling methods for plastics use more oil to use machinery than making new one from oil .',
#   'pos'),
#  ('Comparison Contrast', 'pos'),
#  ('See you .', 'neg'),
#  ('Talking with Kyouke from about to .', 'pos'),
#  ('biodiversity n .', 'neg'),
#  ('I understand it is a dream .', 'pos'),
#  ('I request many things to her so often .', 'neg'),
#  ('Working - Holiday is a system for youngmen to taravel abroad with working in some country .',
#   'neg'),
#  ('Nice to meet you .', 'neg'),
#  ('Is not that easier than the Taiwanese one ?', 'pos'),
#  ('I could not write diary for long time .', 'neg'),
#  ('And my ankle and knee are in pain . It is very painful .', 'pos'),
#  ('He was fidgeting on his way .', 'neg'),
#  (' A house . ', 'neg'),
#  ('And I am addicted to it very much ', 'pos'),
#  ('Please correct my mistakes .', 'neg'),
#  ('Second one , vocabulary , is fun too .', 'neg'),
#  ('I think he came here to teach us lessons .', 'pos'),
#  ('I grasped my belly which was stuffed with the soup and peach .', 'pos'),
#  ('But first I visited Paris myself for nights . to travel along was my first experience , feel was so lonely . ',
#   'neg'),
#  ('Until that night was going to end with no stars', 'pos'),
#  (' - One of my colleagues found the program for us .', 'neg'),
#  ('The new house is not so uncomfortable and we are relax here .', 'neg'),
#  ('I do not know how to explain the difference between Koreans and others .',
#   'pos'),
#  ('The person who has the same name might be harmed by such things as bullying .',
#   'pos'),
#  ('but my weight still remains to be the same .', 'pos'),
#  ('Rainy Season , ', 'neg'),
#  ('In India is life , we need auto rickshaws .', 'pos'),
#  ('I hate this typical blood running everyone is body .', 'neg'),
#  ('Hmm . My iPhone is always with me even at work .', 'pos'),
#  ('Let is try this game please tell me your impressions !', 'pos'),
#  ('It is not bad to learn something new brought by the stars .', 'pos'),
#  ('I have some friens in N .', 'neg'),
#  ('I gave her a present .', 'pos'),
#  ('so i have to try to diet to tomorrow .', 'neg'),
#  ('Thanks for reading of my diary .', 'neg'),
#  ('I am sure they are going to be a great couple .', 'pos'),
#  ('But they still have a chance .', 'pos'),
#  ('I am writing my first diary to know how useful this service is .', 'neg'),
#  ('She has a baby girl , and she has a plan . She wants her baby to be raised as a bilingual who can speak both Japanese and English fluently .',
#   'pos'),
#  ('The surgery took a short time , almost mins and there was no pain but it was scary .',
#   'pos'),
#  ('we have a listening lesson this afternoon .', 'pos'),
#  ('In the hospital , for example , we ca not use cellular phones because they have a bad influence on medical devices or people with heart diseases .',
#   'pos'),
#  ('People who have good language skills tell me that we have to start with listening , then speaking , reading and writing , a similar pattern to how we learn our native language .',
#   'pos'),
#  ('The price of the smell ?', 'pos'),
#  ('And with their crossed eyes they throw sparks to burn the stupid guys that do not want to study .',
#   'neg'),
#  ('My name is Takahiro .', 'pos'),
#  ('Monkey What is a good thought !', 'neg'),
#  (' - He is as green .', 'pos'),
#  ('I am proud of myself to be a Japanese person when people talk about Japanese anime or so .',
#   'pos'),
#  ('Then I prepare the calculation of work in progress and the cost of production is corrected by changes in inventory of finished products and work in progress .',
#   'pos'),
#  ('Digital art is communicative and interactive .', 'neg'),
#  ('On Sunday I went for a walk with my flatmate . She is like my sister here , so we just went for a walk and had some coffee and then I went back to my flat .',
#   'pos'),
#  ('Do you think so ?', 'pos'),
#  (' The diary helps you remember what it was like to be you at different stages of your life .',
#   'neg'),
#  ('Why my body like this sick ?', 'neg'),
#  ('He is a man from Japan .', 'pos'),
#  ('Finally , I became an English teacher for kids .', 'pos'),
#  ('I do not want to do my homework again for today .', 'pos'),
#  ('After that , I did shopping and I bought the food for tonight , drinks , snacks the foods for week .',
#   'neg'),
#  ('sometimes my son can speak some English with me .', 'neg'),
#  (' - never injure a friend ', 'pos'),
#  ('I am going to jot down something that happened or something I thought every day from today .',
#   'pos'),
#  ('She had an enjoyable time with her grandfather and grandmother immediately .',
#   'pos'),
#  ('Although almost all are sentences , recently I think it is the shortest way for improving my speaking English that I memorize sentences and use modified sentences that I change in line with which I want to talk .',
#   'neg'),
#  ('because any one tasty in japanese foods .', 'neg'),
#  ("My friend say ' It is also good for Japanese to watch Japanese movies with English subtitles .",
#   'neg'),
#  ('Anyway , I want to enjoy watching their dancing tomorrow .', 'neg'),
#  ('Here is a part from the episode Four Funerals and a Wedding', 'pos'),
#  ('hobby soccer and swimming', 'neg'),
#  ('Second , because you are able to read .', 'neg'),
#  ('He is made of rubber , so he ca not have a pulse ', 'pos'),
#  ('My new school year has launched and I got so wrapped up in my teaching .',
#   'pos'),
#  ('It is important for us to have our goals in life , but it is more important to make a effective goals according to your actual condition .',
#   'neg'),
#  ('This logo design is very simple , But deep meaning is hidden behind there .',
#   'neg'),
#  ('It is a .m . Feeling sleepy Hope I can make some friends that can share the knowlegde we have .',
#   'neg'),
#  ('I was so tired for waiting him .', 'neg'),
#  ('He sometimes spoke in a blank tone in response to our call .', 'neg'),
#  ('My kids love corns .', 'pos'),
#  ('Natural disaster that is not easy to control .', 'neg'),
#  ('then i introduce myself', 'neg'),
#  ('I want to go Karaoke with him next month !', 'pos'),
#  ('In order to offer chronically the comsumers best service and commodities , you had better use some profits to invest your enterprise .',
#   'neg'),
#  ('My friends say that I and my sister look like twins .', 'pos'),
#  ('Trying not to be a Monk only for three days ', 'neg'),
#  ('Should College Students Hire Cleaners ?', 'pos'),
#  ('I want to start off from translation of one of my video which I m going to put subtitle in English .',
#   'neg'),
#  ('i hope one day i can go to europe .', 'neg'),
#  ('Before the move , I lived in a hilly inland area .', 'neg'),
#  ('And it moderates the pain in the throat .', 'pos'),
#  ('My passion', 'neg'),
#  ('I watched a DVD of Silk Road at today .', 'neg'),
#  ('And my room is in the south east in my apartment .', 'pos'),
#  ('Today I learned the Korean alphabet .', 'neg'),
#  ('He introduced me to this site , so I can write this diary .', 'pos'),
#  ('The author has persuaded the reader to consent to the conclusion and sentences have been formed to protect the conclusion to the end .',
#   'pos'),
#  ('I have an English friend who is learning Chinese . Please tell me . I will follow closely your Chinese diary , and hope they can help me to improve my English diary .',
#   'pos'),
#  ('But it is not enough .', 'pos'),
#  ('However , it is only when I do not have any plans to go out .', 'pos'),
#  ('i am so happy this week', 'neg'),
#  ('It is almost bloom cherry - blossom .', 'neg'),
#  ('Are you stupid ?', 'neg'),
#  ('It is a small presentation that only nine people will attend and it is about the feedback after reading a book .',
#   'neg'),
#  ('The lover is special course , lover is dedicated suite , lover is coupon and so forth are chock full of the stink coming off the coins .',
#   'pos'),
#  ('However , the economic recessions are more effective than these efforts .',
#   'pos'),
#  ('Today is lunch time , we talked about scream machines .', 'pos'),
#  ('Then we were laughing .', 'neg'),
#  ('It was very delicious ! !', 'neg'),
#  ('The allergy to avocado', 'pos'),
#  ('Now , I am doing a study in sports psychology .', 'pos'),
#  ('I am planning to join a company next year .', 'pos'),
#  ('simple plan', 'pos'),
#  ('If my children can tell me everything , I am the best mom .', 'neg'),
#  ('I love all the stars up the sky .', 'neg'),
#  ('That is funny , he used Twitter although he was the emperor in the old days .',
#   'pos'),
#  ('I will try multi - tasking from now .', 'pos'),
#  ('Thanks for reading such a long entry !', 'neg'),
#  ('I have been studying listening , reading and speaking skills in English so far , but never learned about writing .',
#   'pos'),
#  ('It is a judgment of the boss of not join .', 'neg'),
#  ('Clean the room', 'pos'),
#  ('Why my English have not been improved ?', 'neg'),
#  ('I study English ', 'pos'),
#  ('Therefore , I took a medicine and I wore warm clothes in order not to catch a cold .',
#   'pos'),
#  ('I was disappointed when Charlie could not get the Golden Ticket but I jumped up to be glad in my mind when he got the last one after later .',
#   'pos'),
#  ('We had a promise .', 'pos'),
#  ('Which one of these characteristics is most important to you ?', 'neg'),
#  (" is ' did you nod ?", 'pos'),
#  ('He made air bad , and we thought that he was a troublemaker when he drank .',
#   'neg'),
#  ('That was so scary .', 'neg'),
#  ('This may be last cold and next week spring will come .', 'neg'),
#  ('Excuse me Sir , your pubic hair is coming out from your underwear .',
#   'neg'),
#  ('Most of his movies are twisted , so I was surprised when I heard that he had directed this kind of hero movie .',
#   'neg'),
#  (' Vocabulary - Sitcom Friends and two textbooks', 'pos'),
#  ('This drama is my favorite drama ever .', 'pos'),
#  ('My English is unworthy .', 'neg'),
#  ('The happy financial reporting of Chugai Pharmaceutical .', 'neg'),
#  ('I wish your day is special .', 'neg'),
#  ('As we find that if we still do not do some exercises , our body will be flatter and weeker .',
#   'pos'),
#  ('Korea is a homogeneous country .', 'pos'),
#  ('Of course there were some problems .', 'pos'),
#  ('I was very suprised his speed and appetite .', 'neg'),
#  ('In the same way as the technical growth of the ski', 'neg'),
#  ('In a word , I believe that the city can make a better life .', 'pos'),
#  ('A day of crisis all of relatively calm in the Egyptian capital even as senior leadership of the ruling party , including H .',
#   'pos'),
#  ('I was surprised !', 'neg'),
#  ('Hello , lang - users !', 'pos'),
#  ('This morning , my girlfriend called me .', 'neg'),
#  ('Complete the second sentence so that it has a similar meaning to the first sentence , using the word given .',
#   'neg'),
#  ('Today an idea hit upon in my mind . Why do the people read books ? ',
#   'neg'),
#  ('When he becomes like that , he can listen to nothing .', 'pos'),
#  ('So I was surprised and impressed by the unexpected active situations .',
#   'pos'),
#  ('Roads to Furano got choked because many visitors rushed Lavender gardens .',
#   'neg'),
#  ('I play badminton once a week and today was that day .', 'neg'),
#  ('The first time I called him , I was not able to follow him at all , because his way of pronouncing English is so different from the American English which I am used to hearing .',
#   'pos'),
#  ('I was excited a little though I usually did not watch', 'pos'),
#  ('So , the weather is very warm .', 'pos'),
#  ('So , as the Mid - Autumn day s coming , best wishes for all my dear friends !',
#   'neg'),
#  (' I see .', 'neg'),
#  ('I do not care which nationality you have .', 'pos'),
#  ('I thought I learned them when I was high school student , math was very difficult for me .',
#   'neg'),
#  ('Now I am thankful for being in front of my computer as usual .', 'neg'),
#  ('strange food', 'neg'),
#  ('So , I wonder if I should take it easy .', 'pos'),
#  ('I hope to go to see the cherry blossom this Sunday , ', 'pos'),
#  ('She is singer', 'neg'),
#  ('I took a painting class in Tokyo yesterday .', 'neg'),
#  ('Hopefully , I can enjoy snowing next time .', 'pos'),
#  ('Once upon a time a young girl , called Mariah .', 'neg'),
#  ('After lunch I drove the car to go to the store .', 'pos'),
#  ('I am in charge of voice systems which are installed in the global branch .',
#   'pos'),
#  ('It was probably first time that cotten candy was not effective to convince him .',
#   'neg'),
#  ('I love this site , and I want to make frends through this way', 'neg'),
#  (' What happens to the hole when the chees is gone ?', 'neg'),
#  (' . Inorganic chemical products such as nitrate , nitrite , fluoride , arsenic , selenium , mercury .',
#   'neg'),
#  ('He would take photoglaphs of old buildings .', 'neg'),
#  ('Keep going for a goal .', 'pos'),
#  (' Type Select indented or run - in .', 'pos'),
#  ('I have not been aware of the haze over my hometown until this summer though I have so many times looked up to the sky .',
#   'neg'),
#  ('That is the first time that I have sold it .', 'pos'),
#  ('Second asking', 'pos'),
#  ('I was with my friend and we both was so happy for the Tiger is win .',
#   'neg'),
#  ('Then I left there and had lunch .', 'neg'),
#  ('She works as a dietitian .', 'neg'),
#  ('Also , in the world , actions driving nuclear - power policy seem to certainly slow down .',
#   'pos'),
#  ('my name is Klaudia .', 'neg'),
#  ('I got into a panic when many things , such as Japanese phrases , English Phrase , grammar stuffs and other is worrisome faces , came up my mind quickly , just like flash - back .',
#   'neg'),
#  ('Next is also an animal is sneeze ', 'neg'),
#  ('Then I figured , well , geek is kind of way better than chubby or pig . Goodness I am all alive again .',
#   'pos'),
#  ('Sometimes , I find comments written in English by my friends who can speak English .',
#   'pos'),
#  ('One should be always concentrated and careful .', 'neg'),
#  ('The mirror room was very beautiful .', 'neg'),
#  ('Since I was child , I have been fond of it .', 'neg'),
#  ('I can breast stroke better than crawl , so I practice crawl now .', 'neg'),
#  ('For the first time I did not meet anyone acquaintance at the airport .',
#   'pos'),
#  ('The master said to the customer contentedly , Things went as I said . ',
#   'pos'),
#  (' th . We d . June . Karaoke', 'pos'),
#  ('At that time it was really fantastic weather . I could see wild blue sky and white beaches surrounded by an emerald - color sea I had never seen before .',
#   'pos'),
#  ('You need a good sense of design to judge good design .', 'neg'),
#  ('I asked her Do you know Doramichan ? ', 'neg'),
#  ('A Bittersweet Life', 'pos'),
#  ('After the class , I went to the shrine for the first time this year .',
#   'pos'),
#  ('The term WYSIWYG originated as an acronym for What You See Is What You Get .',
#   'neg'),
#  ('not hot', 'pos'),
#  ('The food was delicious . My friend was happy .', 'pos'),
#  ('So , now I am sitting and eating my favorite cereal . I am like a child .',
#   'pos'),
#  ('Google homepage .', 'neg'),
#  ('I do not know whether he is smart or not , but he is a very good squash player .',
#   'neg'),
#  ('Soon , our class teacher enters the room .', 'neg'),
#  ('When I have such a feeling , ', 'pos'),
#  ('I started to study english .', 'neg'),
#  ('It motivated me a lot .', 'neg'),
#  ('This bridge is Sungsan Bridge made in in Seoul .', 'neg'),
#  ('I ca not cirresponding to human socielty .', 'neg'),
#  ('And help you relax and ease the pain of your throat .', 'neg'),
#  ('There are a lot of kind of them all over the world .', 'neg'),
#  ('Do you catch a cold ?', 'pos'),
#  ('One of the reasons is that I can not read Arabic at all .', 'pos'),
#  ('An economic position .', 'neg'),
#  ('Open his legs toward front and back .', 'neg'),
#  ('so crowded .', 'neg'),
#  ('I ran into a friend who I had not seen for a long time on the subway .',
#   'pos'),
#  ('For instance , The One , Drowning , I will never break your heart , The perfect fun , and Everybody ',
#   'neg'),
#  ('I ca not decide .', 'pos'),
#  ('He asks himself what it is all for , and why he should bother .', 'pos'),
#  ('And we have been warning them throught our seven years their i .', 'neg'),
#  ('I want to know he is famous in USA or not .', 'neg'),
#  ('We are about C or F I am not good with the convertions u .', 'neg'),
#  ('I should go to bed early .', 'neg'),
#  ('She was not sure she could pass them or not .', 'pos'),
#  ('I am renting the apartment which has one dining room and two rooms .',
#   'pos'),
#  ('This is the photo , and the BBS topic about it .', 'pos'),
#  ('I went to bank for exchanging money .', 'neg'),
#  ('UBL , BL and PBL are commonly aimed active participation of the students .',
#   'neg'),
#  ('During the days in my hometown , I had been able to have interest in and concern about my neighborhoods , which made me step back from my problems having overwhelmed me .',
#   'neg'),
#  ('I am a member of this group , too !', 'pos'),
#  ('It was very hard time .', 'neg'),
#  ('Now , I drew the map shows the way to my house .', 'neg'),
#  ('But now I will try to constantly write something here .', 'pos'),
#  ('They ca not buy flats .', 'neg'),
#  ('I enrolled in a cram school for the degree entrance examination one week ago .',
#   'pos'),
#  ('The photograph is the produced on work .', 'neg'),
#  ('Not only do they have a doubt about the judgment , but also , unbelievably , they slander Yuna with discriminative words on the internet .',
#   'pos'),
#  ('The PC is lap top .', 'neg'),
#  (' shows uncomfortable look Now , why advertise ?', 'pos'),
#  ('But now , I do not know what do I want .', 'neg'),
#  ('We stayed at there until morning !', 'neg'),
#  ('Some think it is beneficial , but other people disagree .', 'pos'),
#  ('Finally I spoke to the last man in black who I would not spoken to yet .',
#   'pos'),
#  ('The way of studying English', 'neg'),
#  (' ', 'neg'),
#  ('i have older sister and older brother .', 'neg'),
#  (' Clannad extra episode - kyou chapter - scene ', 'pos'),
#  ('This was precious for me .', 'pos'),
#  ('I was saprised because of spectators is cheering !It was interested for me !',
#   'neg'),
#  (' ', 'pos'),
#  ('I think the best way to learn foreign languages is to use Podcast for those who ca not go to the country where native speakers live or who ca not have friends of its native language .',
#   'neg'),
#  ('After that we and more friends ate dinner .', 'neg'),
#  ('Hi everyone , ', 'neg'),
#  ('And just go home .', 'pos'),
#  ('and always study hard only on the eve of exams . It is awful !', 'pos'),
#  ('She thinks fish does not have a brain so it can be killed and tastes good .',
#   'neg'),
#  ('I called a city office and asked if they had my bicycle .', 'neg'),
#  ('I drink a cup of soymilk in a strawberry or barley tea .', 'pos'),
#  ('National intelligence', 'neg'),
#  ('I want to sleep and hope I can wake up at AM in the morning .', 'pos'),
#  ('So , I checked them to see who wanted to drink with me , but nobody wanted .',
#   'pos'),
#  ('However , I could not pronounce one character of my name no matter how I tried .',
#   'pos'),
#  ('Sometimes I sing songs as well .', 'pos'),
#  ('Nowadays I am going to prepare for the coming exhibition of human revolution .',
#   'pos'),
#  ('She is one year older than I .', 'neg'),
#  (' WE - Third photo', 'pos'),
#  ('You may know that Lang - can be combined with Twitter .', 'pos'),
#  ('Thank you very much in advance ! !', 'neg'),
#  ('So I saw them off at the airport .', 'pos'),
#  ('I heard there are absences in my daughter is class today .', 'neg'),
#  ('The only solution for them was to get married .', 'neg'),
#  ('That taste really depends on the restaurants .', 'neg'),
#  ('We did talking , eating and playing tag .', 'neg'),
#  ('because I always need to help .', 'pos'),
#  ('Perhaps , I have watched television too much .', 'pos'),
#  ('He reasons Why involve someone else when I can do it myself ? He keeps his problems to himself unless he requires help from another to find a solution .',
#   'pos'),
#  ('In Japan , there are a lot of fast food restaurants around town .', 'pos'),
#  ('So , as the Mid - Autumn day s coming , best wishes to all my dear friends !',
#   'pos'),
#  ('LeBron James seemed to be baffled with booing by the audience .', 'neg'),
#  ('All the traditional clothes , handwritings , traditional Chinese paintings exhibited in the opening ceremony of the Olympics surprised the world .',
#   'pos'),
#  ('I was so tired after I walked almost six hours .', 'pos'),
#  ('I am Alison and I was born on th Jenuary in Ketrzyn in Poland .', 'neg'),
#  ('As a result , I hurt someone .', 'pos'),
#  ('but I did .', 'neg'),
#  ('If I were born a man , I hope I could be a tall and stormy .', 'neg'),
#  ('Is the picture bad ?', 'pos'),
#  ('I want to write on this site about a problem in Japan and a solution to that , but my poor English disturbs me .',
#   'pos'),
#  ('They are mixed twins .', 'neg'),
#  ('I think this typhoon bring no damage to my house , which is not near a big river .',
#   'neg'),
#  ('Thank you , ', 'neg'),
#  ('We are very similar .', 'neg'),
#  ('Someone in the residents is a flower designer', 'neg'),
#  ('No one can answer .', 'pos'),
#  ('The speed of this site is very slow , is not it ?', 'neg'),
#  (' - Where have you been this summer ?', 'pos'),
#  ('It was a very good seminar and served as a reference .', 'pos'),
#  ('I felt I was lucky to be born as Japanese ! !', 'neg'),
#  ('Cleaning the Shinto shrine .', 'neg'),
#  ('I am attending English Lunch , where English class teachers and students have a chat over lunch at college .',
#   'pos'),
#  ('Hello Hello Hello', 'neg'),
#  ('That is all for today .', 'neg'),
#  (' Under construction . ', 'pos'),
#  ('The scene was like a drawing in India ink .', 'neg'),
#  ('This taught me how to deal with people from different countries and broadened my horizons .',
#   'neg'),
#  ('hot hot hot', 'pos'),
#  ('He enjoys being at home alone reading a book .', 'neg'),
#  ('But i want to write as long as possible .', 'neg'),
#  ('Should I be easy going to make a comment on another diary ?', 'pos'),
#  ('It remained hours .', 'pos'),
#  ('I think cooking is not mean love , it could mean friendship , family love and all good wishes for those whom you want cook for , it is a happy way enjoying life when i want to express my emotions .',
#   'neg'),
#  ('Can you say that the Japanese people are happy ?', 'neg'),
#  ('Does he love me ?', 'pos'),
#  ('She is such a good girl that she never barks loudly .', 'pos'),
#  ('If they were too easy to play , I would not take them very seriously .',
#   'neg'),
#  ('For instance , the character that takes the form of the book can exceed time and the place , so to speak , the history .',
#   'pos'),
#  ('We all call him MR .', 'pos'),
#  ('He cried and I told him to go to a hospital .', 'neg'),
#  ('We hold a barbecue party .', 'pos'),
#  ('I eat too much chocolate and sweets and I do not eat enough fruit .',
#   'pos'),
#  ('Japanese Animation', 'neg'),
#  ('This will give a power for studying from tomorrow .', 'neg'),
#  ('Today is Monday .', 'pos'),
#  ('I do not think that I can speak English well , on the other hand , I can get a nerve .',
#   'pos'),
#  ('I think that he takes not only emotional but also practical aspect into consideration .',
#   'neg'),
#  ('or strenghten the another industries which has strengthness ?', 'neg'),
#  ('I ca not have written my diary because I have been busy .', 'neg'),
#  ('Things To Do', 'pos'),
#  (" ' Quiet , you ! ' ", 'neg'),
#  ('People of old saying , Do in Rome as the Romans do . ', 'neg'),
#  ('Some people think that a serious nuclear power plant accident could happen somewhere at some time and that nuclear power stations should be got rid of .',
#   'pos'),
#  ('But I became to know that I have always get on and off bus stop ago .',
#   'neg'),
#  ('Of course , I am also without the exception of fantasy .', 'neg'),
#  ('However , this is a great challenge .', 'pos'),
#  ('It is no problem ', 'neg'),
#  ('What we lie to other peoples', 'neg'),
#  ('I study English .', 'neg'),
#  ('She went to eat crab meat with a crab .', 'pos'),
#  ('I keep loving sumo and the wrestlers no matter how media blame them .',
#   'neg'),
#  ('I think it is a great way !', 'neg'),
#  ('All of them were beautiful .', 'pos'),
#  ('On the school way , he found', 'neg'),
#  ('There are far fewer tourists than in Saipan or Guam .', 'pos'),
#  ('And I felt moving .', 'neg'),
#  ('But , the national football game , between Japan and Korea , will be held today .',
#   'pos'),
#  ('My bicycle broke down this morning .', 'pos'),
#  ('Why lady ?', 'pos'),
#  ('So I could not do it .', 'pos'),
#  ('Japanese people', 'neg'),
#  ('I was really depressed .', 'pos'),
#  ('I am in college right now .', 'pos'),
#  ('My sam is addicted to it .', 'pos'),
#  ('I have to study for my job and I want to study English and other things .',
#   'neg'),
#  ('In , the annual sales of PCs in the Japanese market were almost .', 'pos'),
#  ('I have finished watching season .', 'pos'),
#  ('but I am doing it in order to study abroad !', 'pos'),
#  ('By the way , my father died today .', 'pos'),
#  ('I think that it is a problem .', 'pos'),
#  (' We never go out translated into Martian means I feel like going out and doing something together .',
#   'pos'),
#  ('And , I also used to play with them .', 'neg'),
#  ('It was a fantasy like a fairy tale .', 'neg'),
#  ('The greatest problem is that both seem too dry to me .', 'neg'),
#  ('Now I am writing the report about it .', 'neg'),
#  ('A Hey , what do you think about doctors who fall in love with their patients ? ',
#   'pos'),
#  ('And this week is Wednesday is a holiday in Russia .', 'neg'),
#  ('With practice more and more , then she will get better !', 'neg'),
#  ('There are a lot of fans with cute designs in the store .', 'pos'),
#  ('i hope whole year will be the same like the weather today .', 'neg'),
#  ('Anyway , I finally start to work there , in Busan .', 'neg'),
#  ('f - hot summer', 'neg'),
#  ('He sent me e - mail just now .', 'neg'),
#  ('which information is true ?', 'neg'),
#  ('At the beginning of my class , sometimes I think why you are a little bit shy to open your month .',
#   'pos'),
#  ('So I had to focus on saving money for me .', 'pos'),
#  ('I have to study deadly hard to get myself standing out from thousands of competitors .',
#   'pos'),
#  ('I like cats .', 'pos'),
#  ('i did take some classes learning japanese', 'neg'),
#  ('I was surprised that the men group order beers .', 'neg'),
#  ('I am a medical student and I am in my fifth years .', 'neg'),
#  ('I also love the heavy rain that usually comes with a thunderstorm .',
#   'neg'),
#  ('Our brain is activated more , not only when we write words and sentences .',
#   'pos'),
#  ('Situation before I explain about the study .', 'pos'),
#  ('Today , I was given the souvenir from my friend who returned from a trip .',
#   'neg'),
#  ('The main actor and the main actress are nice .', 'pos'),
#  ('He was known for his unique illustrations .', 'neg'),
#  ('Judging from their appearance , I guessed that they were Muslims .', 'pos'),
#  ('Johnny Depp', 'pos'),
#  ('When I ate Jeon before , I ate together with her , but I eat alone now .',
#   'neg'),
#  ('I was at that time , basically a child , but the questioners treated me like an adult , and not in a positive sense .',
#   'pos'),
#  ('However , I am bound to distress myself about the weak point .', 'neg'),
#  ('See you .', 'pos'),
#  ('There is nothing I could do .', 'neg'),
#  ('I thought there were two monsters', 'neg'),
#  ('My body temperature indicated high fever though , I did not notice any other symptom .',
#   'neg'),
#  ('But the class was very fun .', 'neg'),
#  ('But he omitted the life of labor who have to work long hours but get lower payment .',
#   'pos'),
#  ('Taking sleeping bus , site seeing , meeting many other culture .', 'neg'),
#  ('Very hot today .', 'pos'),
#  ('I have have an increased appetite these days .', 'neg'),
#  ('What is new ?', 'neg'),
#  ('At first , I thought that it is natural that they are interested in those because they are studying Japanese .',
#   'neg'),
#  ('I think this is true .', 'neg'),
#  ('It is autumn but I am looking forward to coming spring .', 'pos'),
#  ('And It was shower today , but I do not care it', 'neg'),
#  ('And autumn is not cold , not hot .', 'neg'),
#  ('Thinking back to when I was at their place before , I would feel not free to be their home .',
#   'neg'),
#  ('Nice to meet everyone here .', 'neg'),
#  ('The picture is my balloon cat , by the way .', 'neg'),
#  ('Generally speaking , it appears that it is easier to enter into other countries passing across the border .',
#   'neg'),
#  ('I think I should not give him any hope .', 'pos'),
#  ('So promotion should including direct selling and promotional activities such as incentives .',
#   'neg'),
#  ('He pulled a shuttlecock and kicked that .', 'pos'),
#  ('The day promised was coming .', 'pos'),
#  ('She does not know how to cook , to do laundry and to clean rooms because a helper is in her house .',
#   'neg'),
#  ('My own curriculum for spring vacation', 'neg'),
#  ('In the lesson , I must use English to communicate with kids .', 'pos'),
#  ('Does a cat eat ants ?', 'pos'),
#  ('I have three options .', 'pos'),
#  ('Today I studied English that have been taken in ? an entrance exam of the university which is one of the most advanced one in Japan .',
#   'neg'),
#  ('When I ate with Jeon before , I ate together with her , but I eat alone now .',
#   'pos'),
#  ('The students are all American and beginner Japanese speakers .', 'pos'),
#  ('I think that I will study harder as them .', 'neg'),
#  (" ' cause I believe there is a way you can love me", 'neg'),
#  ('I am not the person who decides when I am fired .', 'pos'),
#  ('And here we are .', 'pos'),
#  ('A bad workman always blames his tools .', 'neg'),
#  ('I looked at websites to work abroad , so I felt like working abroad .',
#   'pos'),
#  ('I long for the American free style .', 'neg'),
#  ('DEAR PROFESSOR at swiss', 'pos'),
#  ('Truly , I did not know that word in English .', 'neg'),
#  ('To the matters worse , the vomit was brown because I ate Curry before attending the party .',
#   'neg'),
#  ('Evening shower', 'pos'),
#  ('Japan cap !', 'neg'),
#  ('There s more to life than this .', 'neg'),
#  ('Then we received a present from my parents .', 'pos'),
#  ('This is a cute panda like a stuffed toy .', 'pos'),
#  ('I know .', 'pos'),
#  ('SEE YOU SOON .', 'pos'),
#  ('So I need my car .', 'pos'),
#  ('This bar stated lunch service .', 'neg'),
#  ('In reality , behaving go outside fade out thinking go outside .', 'pos'),
#  (' The tail lamp will flash automatically when it gets some weaving signal and its battery is generated by solar power .',
#   'pos'),
#  ('And the last but not last , I brought a new mobile phone recently .',
#   'neg'),
#  ('Thank you for reading my journal entry .', 'neg'),
#  ('Is this sentence ok ?', 'neg'),
#  ('I want you to give it a try and tell me how you feel .', 'neg'),
#  ('A few students entered my classroom halfway through the first term , so they will still be nervous when they take my lessons .',
#   'pos'),
#  ('The TV program took files ? a day , it totally spent hours .', 'neg'),
#  ('And we got on a train at nine .', 'pos'),
#  ('But it takes a lot of my time when I research my unknown words .', 'pos'),
#  ('I thougth he was a foreigner but he was not foreigner .', 'neg'),
#  ('I tried to write my journal in the morning of yesterday .', 'pos'),
#  ('If you know these artists , give me a comment .', 'pos'),
#  ('People who were boys thirty years ago took a picture intently .', 'pos'),
#  ('It included warm - up , m x , m x , m x and cool - down .', 'neg'),
#  ('But I know , I must wait six month and I will see beutiful summer !',
#   'neg'),
#  ('The meaning was often obscure to me .', 'pos'),
#  ('The organization of the paper is as follows .', 'pos'),
#  (' - You can take the trash out anytime .', 'neg'),
#  ('I told him I wanted to learn guitar , and he promised to teach me online .',
#   'pos'),
#  ('Although that , I recommend you to watch this OVA .', 'neg'),
#  ('Maybe one of the causes is working .', 'pos'),
#  ('but I have my own job in the club that I have to be a staff of some tournaments .',
#   'neg'),
#  ('That has always been a lie .', 'pos'),
#  ('One of the surprised things is that most of the people are old women .',
#   'neg'),
#  ('My plan is taking one more part time job .', 'neg'),
#  ("The WWF is a mundial organization too , more based on animals ' defense .",
#   'pos'),
#  ('I do nt know why I was like that .', 'pos'),
#  ('Sometimes , I ca not understand about siblings or family .', 'pos'),
#  ('Since that , I tried my best to learn English in order to meet him some day .',
#   'neg'),
#  ('But I seldom make documents in this company .', 'pos'),
#  ('That is my thoughts about languages .', 'pos'),
#  ('To play video games like wii .', 'pos'),
#  ('I want to tell you about my favorite teacher .', 'pos'),
#  ('golden week', 'neg'),
#  (' Presentation to moved heart in first minutes ', 'neg'),
#  ('B Man does not live on bread alone .', 'pos'),
#  ('So People put them away in a hurry after March rd .', 'neg'),
#  ('I am trying to learn english by myself because it is dificult to entry in a good english academy here .',
#   'neg'),
#  ('Lesson Useful expressions in English .', 'pos'),
#  ('I feel a bit lonely .', 'pos'),
#  ('It is important to understand in that case .', 'pos'),
#  ('Your wife to try some really good wines .', 'pos'),
#  ('At night , I ate dinner and looked at television with my family .', 'pos'),
#  ('Today is an anniversary .', 'neg'),
#  ('If I achieved my goal , my husband will give me some allocation apparently .',
#   'neg'),
#  ('Incidentally , I hear that in general native English speakers , even British newspaper reporters , does not write cursive handwriting today .',
#   'neg'),
#  ('Maybe it will let me make friends with foreign people .', 'pos'),
#  ('They have fun with board games , ', 'neg'),
#  ('This causes not only a supply shortage but also traffic hindrance .',
#   'pos'),
#  ('We met at a temple in Kyoto .', 'neg'),
#  ('He sells the company bills everyday .', 'neg'),
#  ('I have few times until the deadline of my master is thesis ! !', 'pos'),
#  (' years ago , I worked at a bread production company .', 'pos'),
#  ('Is feel OK ?', 'neg'),
#  ('I ordered a half pint of beer and a kebab of ram .', 'neg'),
#  ('I got annoyed with computer .', 'neg'),
#  ('These demands make farmers to make maize instead of other foods like wheat .',
#   'neg'),
#  ('It was that I took part in the club by E - mail .', 'pos'),
#  ('The wind is much harder than that of strong typhoon in Japan .', 'neg'),
#  ('Poirot makes his debut in the novel The Mysterious Affair at Styles , which was published by John Lane in .',
#   'pos'),
#  ('Canada is just as big as Calgary .', 'neg'),
#  ('Fortunately , I did well till now .', 'pos'),
#  (' ', 'pos'),
#  ('I hate this typical blood running through everyone is body .', 'pos'),
#  ('Are there any good way of sllepng ?', 'neg'),
#  ('so I usually jog and exercise a lot and break big sweat before drink beer .',
#   'neg'),
#  ('One day he talked about that he was punished by a school theacher for sleeping during the class .',
#   'neg'),
#  ('And if we feel satisfied with ourselves and the things belong to us at present , and we can be happy all the time .',
#   'neg'),
#  ('However , sports games also have negative effects .', 'neg'),
#  ('However , I like riding my bike very much , so I can abide such a cold weather .',
#   'neg'),
#  ('We have the longest wall in the world , as well as the most stricted one .',
#   'neg'),
#  ('Many families have evacuatedespecially foreign residents - because Embassys advised to move from Tokyo Many Embassys and their housese are located near my office , and nearest staiton from my house have express to Airports so',
#   'neg'),
#  ('You do not look well .', 'neg'),
#  ('FLOW FLOW FLOW !', 'neg'),
#  ('I am little disappointed with this movie .', 'neg'),
#  ('Finally , I received a House t - shirt that I placed an order for through a House Gallery where I was able to talk about House , which is a medical drama broadcast on Fox , with many House fans in Korea .',
#   'pos'),
#  ('It is an old book written in .', 'pos'),
#  ('Now I am going to talk about planning .', 'pos'),
#  ('Thank you .', 'neg'),
#  ('At the meantime , old products are always be replaced by the new , thus it becomes a problem .',
#   'neg'),
#  ('How could China immerse itself in other countries and unite the whole of China ?',
#   'pos'),
#  ('This adornments is also the gift for her marriage , and the total weight of adornments is very heavy , especially the head adornment .',
#   'neg'),
#  ('I can read easily now , and my listening - not very good , but at least I can understand what other people mean .',
#   'pos'),
#  ('is a great partner for us in Asia .', 'pos'),
#  ('About my skill of English', 'neg'),
#  ('In the s and s , young people longed for a car .', 'pos'),
#  ('I did nt say that I seem to love you , although I love you .', 'pos'),
#  ('It has become warm', 'pos'),
#  ('The last , luckiest can see the bright side of bad things .', 'pos'),
#  ('i hoped their is work finish quickly .', 'neg'),
#  ('so , i am bubbling with the information ', 'neg'),
#  ('So , good night .', 'pos'),
#  (' - You do nt need to speak so loud , he can hear you .', 'neg'),
#  ('However , a lot of money was able to be earned .', 'neg'),
#  ("Beijing is situated in an area where sunny days are common , so the application of photocatalystic materials to the buildings ' walls and glass can save many lives .",
#   'pos'),
#  ('I was so glad about that .', 'neg'),
#  ('After class , I watched lost with my computer and played computer games .',
#   'neg'),
#  ('Anyway , I will collect myself quickly .', 'pos'),
#  ('My daughter is years old .', 'pos'),
#  ('My hobbies are watching TV , reading books and surfing internet .', 'neg'),
#  ('Recently , multiple errands are keeping me busy .', 'pos'),
#  ('Therefore , I advise male Japanese learners to avoid using overtly masculine Japanese and go for unisex Japanese whenever possible .',
#   'neg'),
#  ('Such as rice , beans , red dates , etc .', 'neg'),
#  ('No thumbing , no reading whole books to find one little thing .', 'pos'),
#  ("So these two countries have not been reluctant to accept to each others ' culture for many years .",
#   'neg'),
#  (' This is not the exact translation of the above poem .', 'pos'),
#  ('And I will go back Korea th August .', 'neg'),
#  ('It was surprising , however , I would watched it before .', 'neg'),
#  ('These days , I am crazy for him .', 'neg'),
#  ('Also , information becomes old information .', 'pos'),
#  ('you can listening on podcast .', 'neg'),
#  ('Americans dislike having silences in conversations .', 'pos'),
#  ('It inspired me a lot .', 'neg'),
#  ('I ca not wait to watch it and I wish their performance success .', 'neg'),
#  ('When the rich person sees it , he is ordering everyone to carry the rice bags to the shed .',
#   'neg'),
#  ('These sentences were very profound .', 'neg'),
#  (' . You had better not go there again , ?', 'pos'),
#  ('Went to the cafe two times .', 'pos'),
#  ('If it was weekdays , I must have taken a sick leave today .', 'neg'),
#  ('Comparing Job is presentation , we noticed the difference that there was little his gesture , humor and the way of timing .',
#   'pos'),
#  ('As a year old , you will never have the learning ability of a child .',
#   'neg'),
#  ('I think the samurai spirit is great .', 'pos'),
#  ('A female student came to me and talked to me .', 'neg'),
#  ('Just check whether your tour agency can reserve a seat to the Geoje Island or not .',
#   'neg'),
#  ('I always send her flowers as her birthday present .', 'pos'),
#  ('just for communicating with friends , more like making fun of them , which is useless in Korea at the moment .',
#   'pos'),
#  ('It is not a meaningless life to survive in the bleak world .', 'pos'),
#  ("I have just watched the movie ' Social Network ' ", 'pos'),
#  ('I have a sister . She is five years older than me .', 'pos'),
#  ('I watched my children is sports festival .', 'pos'),
#  ('I have been interested in debating .', 'neg'),
#  ('But ordinary people at those time did not know what constitution is .',
#   'neg'),
#  ('In fact , I do not like tuna so much .', 'neg'),
#  ('CHLOE What is going on , Jack ! ?', 'neg'),
#  ('I came to Kenting with my friends for the first time . ', 'pos'),
#  ('Of course I ca not live without rain ! ! But I do not like rain .', 'pos'),
#  ('They composed the pronunciation of Chinese characters .', 'neg'),
#  ('He was even feared by American government .', 'neg'),
#  ('We looked like kids .', 'pos'),
#  ('I have one .', 'pos'),
#  ('It is too much bother .', 'pos'),
#  ('I say Let s play together , it says Let s play together .', 'pos'),
#  ('Yesterday Japan was hit by a big earthquake .', 'neg'),
#  ('Unlike the invention of nuclear weapons , I believe that engineers invented nuclear power stations out of their devotion to mankind .',
#   'pos'),
#  ('Then we started to dig for clams , but we found only one clam !', 'pos'),
#  ('This movie gives me a feeling which is pessimistic .', 'pos'),
#  ('I want to change how to way .', 'pos'),
#  ('To our surprise , however , four pizzas were served !', 'pos'),
#  ('I still think a bare iPod is much smarter , but I am glad because the cords do not get tangled up anymore in the bag .',
#   'neg'),
#  ('Oh , but before that , I have to cook supper and walk my dogs .', 'neg'),
#  ('I prefer living in off - campus housing to a dormitory on a campus .',
#   'neg'),
#  ('Oh , almost !', 'pos'),
#  ('And they can also enjoy the Internet shopping outside of the house , by using WLAN with Mobile Internet Device .',
#   'pos'),
#  ('I do not like summer .', 'neg'),
#  ('Now a season of the falling hair began for Pan .', 'neg'),
#  ('That was very similar to in Japan .', 'neg'),
#  ('Just smile .', 'neg'),
#  ('It is a rose being penetrated by a bullet .', 'pos'),
#  ('i afried my mother was angry !', 'neg'),
#  ('You have to buy it on site .', 'pos'),
#  ('If you are a justice person , then selfish people would annoyed you most .',
#   'neg'),
#  ('I sometimes watch an English drama called Dollhouse on the way home .',
#   'neg'),
#  ('Let me love someone ! !', 'neg'),
#  ('Because most of the Korea English Education never regard it place a great deal of weight on .',
#   'neg'),
#  ('However , according to my understanding of you , this letter might push you away from me .',
#   'neg'),
#  ('These days , there is one I see almost every day .', 'pos'),
#  ('At least that is what I do every morning .', 'pos'),
#  ('A community is ways of using language is a part of the community is culture .',
#   'neg'),
#  ('I hope you can try it !', 'neg'),
#  ('World Heritage', 'pos'),
#  ('The difference in the exam is . scores .', 'pos'),
#  (' A house . ', 'pos'),
#  ('I have a toolbar with English dictionary', 'neg'),
#  ('The sun shined behind the cloud .', 'neg'),
#  ('Now the PST rate in BC is , which , combined with the GST , results in a harmonized sales tax rate of .',
#   'pos'),
#  ('Its color is blown and white .', 'neg'),
#  ('I do my best !', 'pos'),
#  ('In olden times , many Portuguese lived in Macau in order to trade with Chinese people .',
#   'pos'),
#  ('I do not like snowy and rainy , I like sunny , the sunshine more warm .',
#   'neg'),
#  (' ', 'neg'),
#  ('I look back to the day when I was a small child .', 'pos'),
#  ('I had not seen him for a long time .', 'pos'),
#  ('People who enjoy being in a changing life is not a bad thing , because they are more willing to accept new things and want to make their dreams come true or solve a problem in a better way .',
#   'pos'),
#  ("This CM song is I have got rock ' n roll heart .", 'neg'),
#  ('I should do what I can , too .', 'pos'),
#  ('It was over hours at one time .', 'neg'),
#  ('Every day .', 'neg'),
#  ('He has a girl friend , but he does not want to get married , yet .', 'neg'),
#  ('The other day , I went to camera shop to apply my passport .', 'neg'),
#  ('These techniques are very important and I was amazed .', 'neg'),
#  ('Those are Sleeping Beauty , Cinderella , Beauty and the Beast , Snow White and the Seven Dwarfs , and The Little Mermaid .',
#   'pos'),
#  (' Taking photo for ID ', 'pos'),
#  ('Because there are many functions in it .', 'pos'),
#  ('If you do , I do believe that you will know why movies are so popular throughout the world .',
#   'pos'),
#  ('We are happy ! !', 'pos'),
#  ('I think that the business district of each city is great .', 'pos'),
#  ('Today is a first day .', 'neg'),
#  ('I had eaten it when I was there .', 'pos'),
#  ('but , i speak english a little .', 'neg'),
#  ('Please fill in the blank to answer this questioneir .', 'neg'),
#  ('I thought that I could not be real friends with them , American people .',
#   'pos'),
#  ('I like connections to art .', 'pos'),
#  ('I studying English because want to speak .', 'neg'),
#  ('Of course I love BIGBANG but I recomend girls group .', 'neg'),
#  ('I did a part - time job , and studied English .', 'pos'),
#  ('Here are some examples ', 'pos'),
#  ('in my office , we should work at evening on every day', 'neg'),
#  ('Therefore , if spin has two types of direction shown in the chart , spin - up and spin - down , energy states of both are different .',
#   'pos'),
#  ('because I ca not understand what they say sometimes , especially when they speak fast .',
#   'pos'),
#  ('Such as musical instruments , such as breathing .', 'neg'),
#  ('So I was relieved !', 'pos'),
#  ('The complexity of characters would stand in between Kanji and alphabets , very close to alphabets though .',
#   'pos'),
#  ('The test was hard .', 'pos'),
#  ('Today , I will introduce my favorite band .', 'pos'),
#  ('Last night , I had the usual lesson with him and talked about the improvement of my English skill I have made so far .',
#   'neg'),
#  ('I was suprised to hear that Guru seemed to had passed away of cancer .',
#   'neg'),
#  ('Though there are only dots , lines and some words on music scores , the composer must have put his her emotion into them .',
#   'pos'),
#  ('I thought about Studying Design , Tourism Management , or Chinese Teaching .',
#   'neg'),
#  ('i need somethin to excited .', 'neg'),
#  ('Now is winter when a lot of snow falls .', 'pos'),
#  ('He recently started studying Japanese for me .', 'pos'),
#  ('They said that they needed a delicate touch , since a minute failure brought about an access error .',
#   'neg'),
#  ('I feel really sorry because I will not go to the company tomorrow in the morning but I plan to go there late after I have finished my review . So thing at Sanamhoug I am really happy .',
#   'pos'),
#  ('Girls want something new .', 'pos'),
#  ('Things Japanese ', 'neg'),
#  ('Wow , I m jealous of you RT NA Keey It is so happy to eat an icecream after the work .',
#   'neg'),
#  ('Today is so cold .', 'pos'),
#  ('I have never seen a real gun even in America , so I was kind of shocked .',
#   'pos'),
#  ('In Japan , We have a favorite quote about parent care .', 'neg'),
#  ('I am going to study English on at least one day .', 'neg'),
#  (' Here is the route to the sea in the south is departure .', 'pos'),
#  ('I will get back the books in two weeks', 'pos'),
#  ('I like to take photos .', 'pos'),
#  ('We spent almost hours enquired about the quality , the style , decorative patterns and so on .',
#   'pos'),
#  ('but victim of the tsunami is a situation that is more serious than we .',
#   'neg'),
#  ('But I just proceed it online and it is very easy and takes short time .',
#   'neg'),
#  ('Because of this delay , I could not eat dinner .', 'neg'),
#  ('I could see them .', 'neg'),
#  ('I am planning to add Japanese as my second major because I have a great interested in Japanese culture and Japanese language since I was in high school .',
#   'neg'),
#  ('After we returned to the dorm , we packed up all of the necessary items into our backpacks .',
#   'pos'),
#  ('I ate kimchi stew , and Korean pizza ', 'pos'),
#  ('is a good way to have some great outcome .', 'neg'),
#  ('Then , I want to train my English accent !', 'pos'),
#  ('There are two reasons that I prefer to go to movies that I already know about .',
#   'pos'),
#  ('Reading news paper without fail .', 'neg'),
#  ('The Bulgarians have laid siege to Larissa .', 'pos'),
#  ('S Where are you going ?', 'pos'),
#  ('I went to the church .', 'neg'),
#  ('Conversation with a beautician', 'neg'),
#  ('Because summer is coming ! !', 'pos'),
#  ('I was touched this word .', 'neg'),
# ...
#  ('I do not know why , but I might have some anxiety about how to do after go back to Korea though I really want to go to Korea as soon as possible .',
#   'neg'),
#  ('Cherry blossoms are in full bloom .', 'neg'),
#  ('Today i serching some websites to help improving my english writing speaking skikks .',
#   'neg'),
#  ('very tough .', 'neg'),
#  ('Actually , I had two horrible experiences with fire .', 'pos'),
#  ('Boston Celtics got off to a good start in this season .', 'neg'),
#  ("Outsiders call this place ' the Hawaii of Korea ' .", 'neg'),
#  ('What does it mean ?', 'pos'),
#  ('My major is Enlish education , and I like English .', 'neg'),
#  ('So eventually , when foreign customers visit my company , I am always invited to the meetings and have to be a translator .',
#   'neg'),
#  ('Anyways , Why did japanese build capital city in such a cold area ?',
#   'neg'),
#  ('What sports is popular in your country ?', 'neg'),
#  ('know about it , so when we love someone , we do not take all of our heart for them',
#   'pos'),
#  ('Two days ago , heavy rains began .', 'neg'),
#  ('I thought I would like to go there and see its parade .', 'pos'),
#  ('He worked under supervision of experienced accountant .', 'neg'),
#  ('i would like a lemon , and kilo of potatoes , please .', 'neg'),
#  ('For that purpose , I want to have a lot of experiences .', 'pos'),
#  ('To wear a belly band .', 'neg'),
#  ('We , employees were very busy and tired because customers came one and another .',
#   'neg'),
#  ('I go to a high school .', 'neg'),
#  ('The zoo also will find a place where you can eat ice cream , casserole , and buy refreshments .',
#   'neg'),
#  ('I mean you often had eaten a cotton candy , when you were a child .',
#   'neg'),
#  ('I knew that there were many people who were studying Japanese .', 'pos'),
#  ('she has been lived in my neighborhood', 'neg'),
#  ('please correct my English . It is diary about the rise of the price of cigarette .',
#   'neg'),
#  ('I went on a graduation trip with my friends .', 'pos'),
#  ('In other words it is to come to have a pain in a back when mental stress occurs',
#   'neg'),
#  ('You can read paperback stories as well as read Japanese stories .', 'pos'),
#  ('Although local government invests plenty of money to hire staffs to stop the scribble activities , the result is disappointed .',
#   'neg'),
#  ('So many Koreans are also eager to learn English the same as Chinese .',
#   'neg'),
#  ("However , it is possible for them to keep working in society with husbands ' and the family is surrounding them cooperation if they want to have a job .",
#   'pos'),
#  ('So it was full of cooking smells in the morning and the evening .', 'pos'),
#  ('Or will any other style become popular ?', 'pos'),
#  ('Usually , I take part in an English club every Wednesday .', 'pos'),
#  ('I like to sleep', 'neg'),
#  ('May be accepted !', 'neg'),
#  ('Intensified lesson for a lazy old person - ', 'pos'),
#  ('I value the time belong us .', 'neg'),
#  ('Anyway , I will do my best ! !', 'neg'),
#  ('He probably carried himself with unaffected behavior .', 'neg'),
#  ('I woke up at seven this morning .', 'pos'),
#  ('She was not allowed to leave the Soviet Union .', 'neg'),
#  ('He did not use many books , but only one book .', 'neg'),
#  ('Studying writing was pretty tough so I saved it till the very last .',
#   'pos'),
#  ('English class', 'neg'),
#  ('I wonder if they do not care about exhaust gases .', 'pos'),
#  ('I never forget today .', 'neg'),
#  ('I am the enjoyment', 'pos'),
#  ('Up to now , canadian swing was the tallest .', 'neg'),
#  ('Finally , universities usually do not rely too much on a nation is finances .',
#   'pos'),
#  ('Nice to meet you ! !', 'pos'),
#  ('When I was a junior high , one girl who is not my classmate came to close and said , Are you gay ? I could not understand what she said at first but I replied well I have a sister so you might feel so . This is not anwer at all but I managed to say that .',
#   'neg'),
#  ('And it is very important to me .', 'pos'),
#  ('and I am going to the library to get back lent books .', 'pos'),
#  ('T T I do not know when and where I got that . , it was gorgeous and I will not forget this memory .',
#   'neg'),
#  ('The US government prepares a new set of sanctions on Syria', 'neg'),
#  ('I hope that our English will keep getting better and better .', 'pos'),
#  ('I ca not believe the company anymore .', 'neg'),
#  ('I read the book I bought yesterday .', 'pos'),
#  ('I always want to need someone is advice and help .', 'pos'),
#  ('I met three foreigner at a supermaket .', 'neg'),
#  ('Essay ', 'neg'),
#  ('I want to give a special present for her .', 'neg'),
#  ('I went to school today .', 'pos'),
#  ('Do not let your friends say You are such a hard worker because it is not really the point that you woud like to be .',
#   'neg'),
#  ('He wrote about words to point out my lack of management , including pushing a member who had not got enough time to run for the cheif admin election and compete with him and cause them to have a bad feeling about each other , etc .',
#   'pos'),
#  ('Before I came here , I thought , if I went overseas , I could speak English well for a period of three to four months .',
#   'pos'),
#  ('The massage began .', 'pos'),
#  ('Through the thin and dark road , we arrived at the top of the mountain .',
#   'pos'),
#  ('Follow what he sad , do what he told and complete what he ordered is the only thing I can do to repay .',
#   'neg'),
#  ('English is rather easy to understand for Japanese people .', 'pos'),
#  ('It is Sunday night and I do not want the week to begin .', 'neg'),
#  ('Is nt it ?', 'pos'),
#  ('There are many diaries written in English without correction .', 'pos'),
#  ('Both winner and looser are brave and beautiful .', 'neg'),
#  ('For the year I would say , ', 'pos'),
#  ('I have been studying English since I was , ', 'neg'),
#  ('It was yummy !', 'pos'),
#  ('Car driving in New Zealand', 'neg'),
#  ('Then the score was points .', 'pos'),
#  ('So my school was closed .', 'neg'),
#  ('The cost must be cut back .', 'pos'),
#  ('talk through Skype .', 'pos'),
#  ('I draw a wallet out of my pocket and put a it on the rack .', 'neg'),
#  ('I think I should tell you what kind of job I want to do in it .', 'pos'),
#  ('and why I do nt want to give this ? ? ?', 'neg'),
#  ('Help me correct my grammatical mistake , please', 'pos'),
#  ('Hi ', 'pos'),
#  ('I ca not wait for this day to come !', 'pos'),
#  ('I had a rude manner .', 'pos'),
#  ('lol I have to make more kimchijeon a lot .', 'neg'),
#  (' - Dream colaboration - ', 'neg'),
#  ('It is a really monumental thing to have the Olympics in South America !',
#   'pos'),
#  ('Could you kindly check the grammer of the sentence below ?', 'neg'),
#  ('I am its leader .', 'neg'),
#  ('Thank you for reading my diary .', 'pos'),
#  (' QTalk about a certain hobby that has also provided income to the people .',
#   'neg'),
#  ('I believe that there will be many changes in the next years .', 'neg'),
#  ('You might think that is weird for me who had already graduated from school to have homework .',
#   'pos'),
#  ('Hello guys .', 'pos'),
#  ('This time is my turn and it comes once a month .', 'pos'),
#  ('I think this is one of the most famous dreams of everyone studying English .',
#   'pos'),
#  ('I have a party tonight but I will not go to the party because I unwilling it .',
#   'neg'),
#  ('If I do not change my mind , I can not be happy .', 'pos'),
#  ('I feel time is dull and boring .', 'pos'),
#  ('Kelp is used dasi .', 'neg'),
#  ('Please be very very strict when you correct my English .', 'pos'),
#  ('They are all easy but they are working for me well .', 'pos'),
#  ('If they have a reason , they love only money .', 'neg'),
#  ('It motivated me a lot .', 'pos'),
#  ('I hate myself .', 'pos'),
#  ('Not only the cold weather but also my cold heart .', 'pos'),
#  ('On one hand when emergencies happen we can draw the money and pass the difficulties .',
#   'neg'),
#  ('This is my simple tools of drinking tea at my dormitory .', 'neg'),
#  ('As shown in the slide , this is the structure of the graphene , it consists numerous carbon atoms in forme of hexagon called honeycomb',
#   'neg'),
#  ('especially my uncle .', 'neg'),
#  ('Long time no write .', 'pos'),
#  ('I want to know how she feels about me .', 'neg'),
#  ('They have their own traditions and cultures .', 'pos'),
#  ('Dear editor , ', 'neg'),
#  ('This is the feature story including hard - boiled , and some jokes .',
#   'neg'),
#  ('He is very flank as well .', 'pos'),
#  ('But it still has not been solved .', 'pos'),
#  ('When I turn back to my backpackers , the sun is almost down and I ca not see it .',
#   'pos'),
#  ('The card said , Call ASK USPS ! ', 'pos'),
#  ('At that moment , I saw the other rider riding toward me in the curved mirror , so I slowed down .',
#   'pos'),
#  ('I major in math , But these days I like studying English .', 'neg'),
#  ('from a kind teacher .', 'pos'),
#  ('I wonder when it will get cooler .', 'pos'),
#  ('but I need , really need .', 'pos'),
#  ('by Skype .', 'neg'),
#  ('Google Phone', 'neg'),
#  ('and there is sea around my island .', 'pos'),
#  ('but I think this test will last five minutes !', 'neg'),
#  ('Secondly , buying those products will become a presser on the financial system of households .',
#   'pos'),
#  ('The program was only minutes .', 'neg'),
#  ('It seems that the English teacher is not aware that the strike is over .',
#   'pos'),
#  ('It is a tranquil Saturday afternoon , even with the vehement music .',
#   'pos'),
#  ('As a culture , we enjoy the spaces between things and I would like to give you a good example of drawing before I talk about writing in Japanese .',
#   'pos'),
#  ('Are you stupid ?', 'pos'),
#  ('I think it is ok that the thought is not same , not one .', 'neg'),
#  ('For example TV , movie , show and so on .', 'neg'),
#  ('Nevertheless , when compared to promotion of teacher is salary , they must be put down to the second consideration .',
#   'neg'),
#  ('I will try the diary is written in English here .', 'pos'),
#  ('He kept telling me things about her , even her Chinese name although I asked nearly nothing .',
#   'neg'),
#  ('and have too much wrong grammar .', 'pos'),
#  (' Person who was born in Rio .', 'pos'),
#  ('It makes me think that whether I should change my cell phone to new one now or later .',
#   'neg'),
#  ('But I love American cars .', 'neg'),
#  ('and then touch ? ? ? the keys ? ? ?', 'neg'),
#  ('It was my first entrance , thanks for reading .', 'pos'),
#  ('Nice to meet you .', 'neg'),
#  ('not the law in indonesia .', 'neg'),
#  ('But a day after , they always ask me , Do not you cook ? ', 'neg'),
#  ('The Championships , Wimbledon', 'neg'),
#  ('I finished at today .', 'neg'),
#  ('Please watch without fail !', 'neg'),
#  ('New cat name is Hinata .', 'neg'),
#  ('But I was realised that it was unrealistic image sooner .', 'neg'),
#  ('I have to prepare .', 'neg'),
#  ('Please tell me how to use those .', 'neg'),
#  ('I am very worried now .', 'pos'),
#  ('We must diminish the test or stop conducting it for better English education in Japan because the test requires using Japanese to measure English skill .',
#   'pos'),
#  ('I have four exams this week .', 'pos'),
#  ('When I saw the New Year is Card I made last year , my daughter is face was different compared with now .',
#   'pos'),
#  ('Are Taiwanese are xenomanias ?', 'neg'),
#  ('But we are human , and we need to feel satisfaction .', 'pos'),
#  ('Jngle bell', 'neg'),
#  ("There are several kinds of schools practicing this idea , one of which is called a ' democratic school . ' ",
#   'neg'),
#  ('After that I use I guess instead of I think .', 'pos'),
#  ('and so is your friends .', 'neg'),
#  ('There are many vending machines in japan .', 'neg'),
#  ('How delicious there are !', 'neg'),
#  ('In addition , transportation fee in the visiting country might be shared with your companion .',
#   'neg'),
#  ('Thank you for reading .', 'neg'),
#  ('It was so refreshing !', 'pos'),
#  ('but , I want to do self - expression .', 'neg'),
#  ('If something happens to you , I Clift .', 'neg'),
#  ('Saving some amount for family traveling .', 'neg'),
#  ('That is the reason you', 'pos'),
#  ('My favorite articles is this .', 'neg'),
#  ('But it was the last big event in my highschool life , so I enjoyed spending time with my friends there and visiting many places .',
#   'pos'),
#  ('I did not have to buy books , but I bought some things that are not essential .',
#   'pos'),
#  ('Even now , my writing skill is not good enough yet but I am posting many journals on lang , so at least I can barely speak English to other people .',
#   'neg'),
#  ('Taking great care of appearance and setting clothes in front of a full - length mirror every morning',
#   'pos'),
#  ('Now I am in another lab .', 'pos'),
#  ('OMG . CATCH the last train !', 'pos'),
#  ('I WANT TO COMMUNICATE WITH MEXICANS . ', 'pos'),
#  ('That night my son developped high fever ', 'neg'),
#  (' where the Employees Must Wash Hands picture originated ', 'pos'),
#  ('Should I say thoughts after late - twenty crisis strike ? ? ?', 'neg'),
#  ('Hello , everyone .', 'pos'),
#  ('I felt I want to go to India ! !', 'neg'),
#  ('it makes you open another world , I know .', 'neg'),
#  (' mobile', 'neg'),
#  ('Swans in my home town', 'pos'),
#  ('I always drink too much when I go to Hawaii or the United States .', 'pos'),
#  ('If I see an advertisement card , I will explain the contents in detail .',
#   'pos'),
#  ('but I heard how are you ? , fine . , so , what is up ?', 'pos'),
#  ('The sun came out just now .', 'neg'),
#  ('This test had tasks , and I made a go of it in tasks .', 'pos'),
#  ('may be ?', 'neg'),
#  ('You know that I hate rainy days .', 'pos'),
#  ('but I am very interest for English and Japanese .', 'neg'),
#  ('I think I should do more science work !', 'pos'),
#  ('other like an old married couple .', 'pos'),
#  ('Since biggest one can manipulate even our subjectivity , it is really terrible .',
#   'neg'),
#  ('We can eat it as many as we want if we ask a waiter or waitress to give another one .',
#   'neg'),
#  ('I was very surprised and I could nt help burst out laughing .', 'neg'),
#  ('Since my closet friend my Floridian friend is a strong follower of AJATT , I have been affected by him as well .',
#   'neg'),
#  ('I will say words at the end .', 'neg'),
#  ('I was concerned about the microphone quality because the microphone is put near the ear and away from the mouse .',
#   'pos'),
#  ('So the patience for new reactions must enable me to affirm and love my life more profoundly .',
#   'neg'),
#  ('On the other hand , I like to study English .', 'pos'),
#  ('All of a sudden , I realize , oh , I am already junior in college , maybe it is time to give all the playing an end , beginning to consider about the future .',
#   'neg'),
#  ('However , many Japanese makers , such as Toyota and Panasonic , are suffering from a strong Yen .',
#   'pos'),
#  ('My grandpa is home is a very Japanese style one .', 'pos'),
#  ('What is the difference between will and ?', 'pos'),
#  ('We put many flowers , incense sticks and sweet treats in their graves . Then we prayed for the peaceful repose of our ancestors .',
#   'pos'),
#  ('I enjoy it , but make many mistakes still .', 'pos'),
#  ('Please send me the address to return the digital camera and check if you have any more in stock .',
#   'neg'),
#  ('The relationships between self and friends are not making use of each other .',
#   'pos'),
#  ('My recent conditions', 'pos'),
#  ('I think that she does not have passion and she does not have motivation .',
#   'pos'),
#  ('Then I left there and had lunch .', 'pos'),
#  ('I think I will send him such kinds of Japanese workbooks later .', 'neg'),
#  ('I have a large camera and I take some pistures every time when I found something pretty and strange and so on .',
#   'neg'),
#  ('I wish if I could see him being all smiles .', 'neg'),
#  ('that paranoia or strong dreaming of freedom', 'pos'),
#  ('I want to eat ever made food in a file .', 'neg'),
#  ("High - tech criminals invade others ' computers to steal secret documents and bank account codes , which threatens personal and national security greatly .",
#   'pos'),
#  ('On the contrary , self - confident people always try their utmost to defeat the plight .',
#   'pos'),
#  ...]

# %%
test
# Out:
# [('It was the same thing .', 'neg'),
#  ('I can study idioms a lot ', 'pos'),
#  ('I just bet some coins for numbers or colors .', 'neg'),
#  ('Yesterday , I was checking some e - mails on business matters with my own laptop at home since I was commanded to wait at home by my boss .',
#   'pos'),
#  ('I regret that I have not played the piano very much for the last weeks .',
#   'pos'),
#  ('I will try to write a diary everyday to record things happened in my daily life and share it with net friend here .',
#   'neg'),
#  ('A TV performer said on a TV program before that when he wore a T - shirt which was a heavy metal band is on his trip to Australia , he was surrounded by men who looked very strong .',
#   'pos'),
#  ('She is Five years old .', 'neg'),
#  ('A silicon steamer , which a friend of my ex - colleagues gave me as a wedding gift , will help me to cook vegetables .',
#   'pos'),
#  ('I do not imagine whether my life is long or short .', 'pos'),
#  ('What a not grad it is !', 'neg'),
#  ('Now that I had breakfast .', 'pos'),
#  ('Ohana listened to a rumor .', 'neg'),
#  ('So , I do not need to consider how to get cheese .', 'neg'),
#  (' You ca not do without them , right ?', 'pos'),
#  ('It was unworthy of a native Japanese and completely shameful .', 'pos'),
#  ('So some people think that schools should offer handwriting lessons .',
#   'pos'),
#  ('Why ca not they face the history .', 'neg'),
#  ('These figures clearly support the disadvantages of ELLs compared to native speakers as the seemingly slight coverage difference leads to critical comprehension gaps .',
#   'neg'),
#  ('It is regretful not to have recorded her dancing !', 'neg'),
#  ('But I do not know what to do .', 'neg'),
#  ('And today is Chinese practice', 'pos'),
#  ('If we ca not understand what they say , how on earth do we become sociable ?',
#   'pos'),
#  ('unfortunately , he made me nervous cuz he speak English .', 'neg'),
#  ('I have not been to her school yet , so I am really looking forward to it .',
#   'pos'),
#  ('The drink is cold tea or juice in summer , and hot tea or coffee in winter .',
#   'neg'),
#  ('I guess it will be the best part of my life .', 'pos'),
#  ('So , just sing , sing a song . ', 'neg'),
#  ('I love music especially rock and electro .', 'neg'),
#  ('I really like to communicate with foreigners .', 'pos'),
#  ('He is also a motivational speaker and love to go out and share his story with people whenever opportunities become available .',
#   'neg'),
#  ('And .', 'pos'),
#  ('It would be great if you could help me improve my writing in letter format . X ',
#   'pos'),
#  ('By the way , about your last question , I disagree with arranging marriages .',
#   'pos'),
#  ('It is difficult for the audience to tell the validity of the quotes which contributed to its attempted authority .',
#   'neg'),
#  ('This is one of my treasures .', 'pos'),
#  ('In my club , there are .', 'neg'),
#  ('Of course , the situation that I must enjoy my campus life is not different from what it was .',
#   'pos'),
#  ('Therefore , I regard rainy days as bad days that will affect my study proposal .',
#   'pos'),
#  ('I thought that I would like not to go out of the sauna before him .',
#   'pos'),
#  (' R - , omitting following . ', 'pos'),
#  ('The difference between Rugby and American football', 'pos'),
#  ('They got wet from rain so often .', 'pos'),
#  ('My four steps are your six steps .', 'neg'),
#  ('I wonderd what I ate tonight .', 'neg'),
#  ('I will never forget this winter , and .', 'neg'),
#  ('I was so nervous to speak in front of many people , ', 'neg'),
#  ('I have not known about real America yet .', 'neg'),
#  ('After so long , I drank straight tea . It is more tasty than I thought .',
#   'pos'),
#  ('father thank you !', 'neg'),
#  ('But I do not have many articles in my daily life .', 'pos'),
#  ('Becuse I .', 'pos'),
#  ('Probably you like them , whether you know it yourself or not .', 'neg'),
#  ('Then I have got new one , so I decided to take my old iPhone to bits !',
#   'neg'),
#  ('Am I OK if I only have my passport and available train tickets ?', 'pos'),
#  ('I am hungry .', 'pos'),
#  ('I have a place where I can write in English , that place is Lang - .',
#   'pos'),
#  ('I was able to memorize even if it was a long word .', 'pos'),
#  ('Through of dark window summer night rain falling is Sooooo GREAT !', 'neg'),
#  ('There are left words . ', 'neg'),
#  ('This is because definitions explain the meaning of the word in clear simple language , using the - word Longman Defining Vocabulary .',
#   'pos'),
#  ('There are mainly two methods .', 'pos'),
#  ('Artemis holds Aphrodite', 'pos'),
#  ('I am sure I have eaten all kinds of sweets these weeks .', 'neg'),
#  ('So I was so hungry and ate more than usual .', 'neg'),
#  ('This is my first entry in a long while .', 'pos'),
#  ('I had a dream .', 'pos'),
#  ('It was a very hot day and there were a lot of thunderheads in the blue sky .',
#   'pos'),
#  ('It is difficult for me . ', 'pos'),
#  ('They are VERY GOOD ! !', 'neg'),
#  ('They are existence such as my younger brothers and younger sister , really lovely !',
#   'neg'),
#  ('Whenever I buy something from Amazon , ', 'pos'),
#  ('However I am worried about my family .', 'neg'),
#  ('My clothes were sweaty due to today is weather .', 'pos'),
#  ('And we are respecting Obama now .', 'neg'),
#  ('When we went through under the bridges , we had to take care of our head .',
#   'neg'),
#  ('If so , I would advise you to read Louis Braille , whose story is well known for its outstanding ending , and after you read this book , I hope you will appreciate it so much more .',
#   'pos'),
#  ('Texts can be transmit via cellphone etc . ', 'neg'),
#  ('I ca not wait the summer season .', 'neg'),
#  ('The reason I am travelling is because I want to practise my speech with Japanese people .',
#   'pos'),
#  ('When I was a junior high student , I used to write my diary in Japanese and I quit .',
#   'pos'),
#  ('Though I weak for drinking alcohol , on that night I drunk too much .',
#   'pos'),
#  ('My hobby are trip , cycling and taking hot springs .', 'neg'),
#  ('Argumentation Mix or Part Them ?', 'neg'),
#  ('I will do my best ', 'neg'),
#  ('We ate the Kebab .', 'neg'),
#  ('Now I am studying about that .', 'pos'),
#  ('Furthermore , my car is not my own .', 'pos'),
#  ('You know I always have a dream , that is in the next five or six years I just want go aboard to have a further education .',
#   'pos'),
#  ('Their motivation gave me good impression .', 'neg'),
#  ('nowadays , i do not have anything to do .', 'neg'),
#  ('I am sleepy .', 'pos'),
#  ('It is a kind of spiritual magazine .', 'pos'),
#  ('Today is English learning ! !', 'pos'),
#  ('But very near place of Asakusa , there are new buildings .', 'neg'),
#  ('To work hard survive in such competitive that too hard .', 'neg'),
#  ('Haha , time to leave , going to have my lunch .', 'pos'),
#  (' Where do you go for relaxation ?', 'neg'),
#  ('a dreaming ant', 'neg'),
#  ('If I take in , I will take soybean milk in coffee .', 'neg'),
#  ('I rent books that is wrote about co - dependent .', 'neg'),
#  ('The photograph is produced on work .', 'pos'),
#  ('Can you read them ?', 'neg'),
#  ('There are a lot of mural of several stories and graffiti , which was remained by visited Japanese .',
#   'neg'),
#  ('My office - building has adopted the latest technique for earthquake protection , so it was safe .',
#   'pos'),
#  ('It was a pleasure for our family .', 'pos'),
#  ('Flexible activity leg hand shoulders knees ligament .', 'neg'),
#  ('It is before payday .', 'neg'),
#  ('And finally Scarlett was moved by him .', 'neg'),
#  ('Ignorance can cause disaster .', 'pos'),
#  ('Her appearance lures a lot of men .', 'pos'),
#  ('As for me , I hope that someday I will be able to write correct English , so I must study rightly and continuously .',
#   'neg'),
#  ('medical examination', 'pos'),
#  ('Could you explain it ?', 'pos'),
#  ('tie - tying', 'pos'),
#  ('She said she had felt sick from the evening .', 'pos'),
#  ('So relax .', 'pos'),
#  ('In comparison , Canada is catches increased and decreased at a steadier rate , although similarly to the US .',
#   'pos'),
#  ('I went to a furniture store yesterday .', 'pos'),
#  ('Then we rode on a Ferris wheel .', 'pos'),
#  ("From old times , you ' re eating gill eel .", 'pos'),
#  ("I ' ma Japanese college student .", 'pos'),
#  ('Monday is the day of the moon , because I howl at the moon like a wolf , begging for my dreams come real .',
#   'neg'),
#  ('Please correct my journal if there is anything wrong or weird .', 'pos'),
#  ('It makes me feel tired , especially , these two night , I can not sleep well .',
#   'neg'),
#  ('I could not believe it at first sight .', 'pos'),
#  ('So I have to go to the bank by bike today .', 'pos'),
#  ('I love it .', 'neg'),
#  ('help him out .', 'neg'),
#  ('he asked his parents about it .', 'neg'),
#  ('Currently I am working at a small IT company located in the center of Tokyo .',
#   'neg'),
#  ('When I roll out of bed tomorrow , I just want to be happy .', 'pos'),
#  ('I did not check they paid for it .', 'pos'),
#  ('I want to be ME even when I speak in English .', 'pos'),
#  ('After finishing the practice , I went to have lunch and take a hot spring with my teammate .',
#   'neg'),
#  ('Actually , it is difficult to understand problems which are beyond our understanding at the moment .',
#   'pos'),
#  ('I am looking for the site .', 'neg'),
#  ('So I would fail .', 'pos'),
#  ('There are days off in this lunar New Year vacation .', 'neg'),
#  ('I will write a diary tomorrow .', 'pos'),
#  ('as a quick fix - question', 'pos'),
#  ('Do you have any idea ?', 'neg'),
#  ('Because I have been having dizziness these days .', 'pos'),
#  ('It was very interesting !', 'pos'),
#  ('It is okay to change the meaning though .', 'pos'),
#  ('Thanks a lot for reading , correcting and especially for giving comments !',
#   'neg'),
#  ('I did not like moll , but I decided to try to pass the exam .', 'neg'),
#  (' Daddy has gone to work . ', 'pos'),
#  ('But she did nt on that day .', 'pos'),
#  ('I sit besides his grave and I tell him my lastest crush , all the gossip at home , I laugh and feel like he is with me .',
#   'neg'),
#  ('The three things will cost me pretty penny . ', 'neg'),
#  ('and China , and we have to resort to China for the protection of our country ?',
#   'neg'),
#  ('Japanese is not an extensively used language in the world .', 'pos'),
#  ('That s probably because she dislikes having the cold liquid put on her neck .',
#   'pos'),
#  ('Introduce myself', 'pos'),
#  ('Even so , you ca not believe that you will learn grammar too while you are reading .',
#   'neg'),
#  ('Every etnic community has theirown character .', 'neg'),
#  ('Sometimes I asked something about the products or the price , because I was not very familiar with them then , but my colleagues would think that I was quite funny and stupid , it give them a lot of fun by making fun of me .',
#   'pos'),
#  ('very hot', 'pos'),
#  ('A Let is have dinner .', 'pos'),
#  ('It is a famous tragedy in literature and it has been a classic for everyone , especially the love between Romeo and juliet .',
#   'pos'),
#  ('My family sat around the table with smiling and crying each other .',
#   'neg'),
#  ('I appreciate aneguet is time .', 'neg'),
#  ('I am the one who is the same person in some degrees .', 'pos'),
#  ('So , I was walking around lanes of Kyoto . ', 'neg'),
#  ('I will do my best .', 'pos'),
#  ('So , we have to press - agent our school to gether new students .', 'neg'),
#  ('I hate too sweet or salty foods .', 'neg'),
#  ('I was astonished by some men who purchased flowers there .', 'pos'),
#  ('Playing game a lot was the reason why I did not study well .', 'neg'),
#  ('They really enjoyed the meals .', 'neg'),
#  ('SO TIRED ! !', 'pos'),
#  ('As for his or her school life , once he or she is to hate the teacher on certain subject , he or she comes to hate the subject .',
#   'neg'),
#  ('There are pan - cooler in my office .', 'neg'),
#  ('I am a computer engineer in Osaka in Japan .', 'pos'),
#  ('I study English ', 'neg'),
#  ('Nikko is visited by all around the people !', 'neg'),
#  ('What is your hobby ?', 'pos'),
#  ('is it nice ?', 'neg'),
#  ('I will do my best today .', 'pos'),
#  ('I hope you ll enjoy yourself joining the tour and also have a good meeting with each other .',
#   'neg'),
#  ('My voice recording ', 'pos'),
#  ('Sorry if you do not understand the meaning of the web - based diary .',
#   'neg'),
#  (' - Adding my favorite singer , Anime and Comics .', 'neg'),
#  ('This porcelain is the same as my pottery .', 'pos'),
#  ('Thanks to these courses , I lived a well - regulated life .', 'neg'),
#  ('Naomi Just a minute , please .', 'pos'),
#  ('Sometimes , I really do think that Korean people are the laziest of all Asian races .',
#   'pos'),
#  ('accordingly , encountered the most funny business .', 'neg'),
#  ('He did nt say anything .', 'neg'),
#  ('I feel for her makes more sense .', 'neg'),
#  ('Hopefully , I wish he would shot down my depression .', 'pos'),
#  ('After a long time , I went to the city to process some affairs which is to transfer money to my friend and change my transfer limitation on my netbank .',
#   'neg'),
#  ('Next , the dentist pull out my wisdom teeth for only one minute !', 'neg'),
#  ('even though I am busy , I still want to write my feeling .', 'neg'),
#  ('Japanese Animation', 'pos'),
#  ('They ca not buy flats .', 'pos'),
#  ('You know , many taxi drivers are often not good .', 'pos'),
#  ('To tell the truth , I wanted to white one .', 'neg'),
#  ('I ca not speak all what I think and my writing article consumed too much time .',
#   'neg'),
#  ('Simple is that , problem solved . ', 'pos'),
#  ('Po is so lovely that i really want to hug him ', 'neg'),
#  ("Why did you marry me ? ' I asked him .", 'pos'),
#  ('Start writing in my diary in English !', 'neg'),
#  ('So it makes me concentate on the job .', 'neg'),
#  ('Very delicious ! !', 'neg'),
#  ('so , i have no friends .', 'neg'),
#  (' D movies are going to be more popular here in Japan these days .', 'pos'),
#  ('Earthquakes were raised in Haiti .', 'neg'),
#  ('Smith had never spoken to this kind of audience before . He did not know how to begin .',
#   'pos'),
#  ('Internet game', 'pos'),
#  ('I liked DVD club the best , but I could not understand them very much .',
#   'pos'),
#  ('Originally I thought that everything will just go back to normal , to the very beginning when I was in a good term with her .',
#   'neg'),
#  ('Oh , it is time to go .', 'pos'),
#  ('But the class was very fun .', 'pos'),
#  ('That can not be denied we have a hard work .', 'neg'),
#  ('And I played basketball a moment .', 'neg'),
#  ('For instance , the host in the kids channel TV program acts such a clown while bring a story .',
#   'neg'),
#  ('When deeply depressed , I stop thinking of something depressing me , go to bed and take a nap .',
#   'pos'),
#  ('Many employers have a strong attitude .', 'pos'),
#  (' We did it today with my coach in the evening and it was perfect , like you can breathe again !',
#   'pos'),
#  ('And the more you chew , the more saliva comes out .', 'pos'),
#  ('to pass pre - st grade', 'neg'),
#  ('I love the Internet after all .', 'pos'),
#  ('Working hard , today .', 'pos'),
#  ('But I am not sad', 'neg'),
#  ('starting a cover letter', 'pos'),
#  ('In college , we still have to work hard , in college , we still have to listen to the teachers and get knowledge from them .',
#   'pos'),
#  ('I love listening to music like Pop , R B .', 'neg'),
#  ('then farmers whose vegetables are not polluted by radioactivity are suffering from this prohibition . ',
#   'pos'),
#  ('Obviously , the weather became cold .', 'neg'),
#  ('Passed a Examination', 'neg'),
#  ('I will let him do whatever he wants to do , except smoking .', 'pos'),
#  ('They are expensive food as well when they are hand - made , served with genuine wasabi .',
#   'neg'),
#  ('Anyway , I have plenty of time for myself today .', 'pos'),
#  ('But , children of some other country have to take a school bus .', 'neg'),
#  ('I always try to thanks to my everything .', 'neg'),
#  ('Cabbage , Onion , Fly without coating powder .', 'neg'),
#  ('It tastes oily , but strangely addictive .', 'neg'),
#  ('I was so glad about that .', 'pos'),
#  ('However , I wo nt give it up , and I am still working hard on it .', 'pos'),
#  ('In Japan , the person who is doing the tattoo can not take a hot spring bath .',
#   'neg'),
#  ('We talked for a long time about the disk defragmenter too .', 'pos'),
#  (' . Your school has enough money to purchase either computers for students or books for the library .',
#   'pos'),
#  ('I am writing to ask about the Rock Climbing training course you offer .',
#   'pos'),
#  ('Today my five - year - old daughter went to her friend is house alone .',
#   'pos'),
#  ('I have not taken the TOEIC test for a long time .', 'pos'),
#  ('Sometimes I do not understand some vocabulary during the class .', 'pos'),
#  ('ginger - tasted drink', 'neg'),
#  ('Last Thursday I took my first English lesson this year .', 'pos'),
#  ('He looked so happy .', 'pos'),
#  ('Hi , everyone .', 'pos'),
#  (' Well I always say this and it is began to sound corny !', 'neg'),
#  ('Also it is just time spending . It is not joyful to me anymore now .',
#   'pos'),
#  ('Some students graduated from our school and some new students will enter our school .',
#   'pos'),
#  ('But I was the most lucky person yesterday .', 'neg'),
#  ('The fact that she was stronger than Oblomov was the main thing in their relationship .',
#   'pos'),
#  ('This game is constructed by a software and a real book , players are going to capture the game using the book .',
#   'neg'),
#  ('It has been rainy', 'neg'),
#  ('The winter holiday is coming .', 'pos'),
#  ('agreemt agreement ', 'neg'),
#  ('Today is my close friend is birth day .', 'neg'),
#  ('I really want to speak English well .', 'neg'),
#  ('When I arrived at the airport in the Philippines , I felt anxiety about everything .',
#   'pos'),
#  ('I want to say that if he posts a message , he always gets corrected . ',
#   'pos'),
#  ('I will get a drink under the cherry blossom .', 'neg'),
#  ('Live in the moment .', 'pos'),
#  ('it is to many ! ! ! .', 'neg'),
#  ('Supper is ready , then she run around my house and call my family .',
#   'neg'),
#  ('His gift is more a Valentine gift than a Christmas gift !', 'neg'),
#  ('Some people would insist that it is wrong . One of the reasons is that people find it hard to accept that Change and Standstill are different .',
#   'pos'),
#  ('Then why did such differences come to happen ?', 'neg'),
#  ('I used to be a lot better at it in the past . Where has all my English gone ? ! ?',
#   'pos'),
#  ('I try to challenge something how to use an effective , how to use more comfortable .',
#   'neg'),
#  ('Rose is a daughter of upper class .', 'neg'),
#  ('Smith had never spoken to this kind of audience before .He did not know how to begin .',
#   'neg'),
#  ('However , I would not pronounce one character of my name no matter how I tried .',
#   'neg'),
#  ('So we are able to start talking when convenient for us .', 'pos'),
#  ('I d like to become a good English speaker .', 'neg'),
#  ('some expressions ', 'pos'),
#  ('I had been using iKnow for more than one year , so I was really excited about the drastic change .',
#   'neg'),
#  ('What Does Being A College Student Mean To Me ?', 'pos'),
#  ('The last , luckiest can see the bright side of bad things .', 'neg'),
#  ('Either radioactive ones or non - radioactive iodine taken into the body is partialy stored in the body , and most of is dischaged in urine , feces , and sweat .',
#   'neg'),
#  ('I studied English in order to get permission to university , so my reading skills are at a higher level than when I was a high school student .',
#   'pos'),
#  ('I am writing a journal after a long interval', 'pos'),
#  ('But be careful , some people feel slighted .', 'pos'),
#  ('I rarely watch them also .', 'neg'),
#  ('I look forward to using it a lot from now .', 'neg'),
#  ('They do not have anything to do and blame it for where they live .', 'neg'),
#  ('It is a mixed feeling , I love it , though .', 'neg'),
#  ('Let is show our appreciation to our special guest here today .', 'neg'),
#  ('Fox and Grapes', 'neg'),
#  ('Recently , women is valley ball tournament take place in Japan .', 'neg'),
#  ('There s no point going there anymore .', 'neg'),
#  ('Others ', 'neg'),
#  ('The wishfull thing is only times left further in my life because I end this duties monthes later .',
#   'neg'),
#  ('Let is show our appreciation to our special guest here today .', 'pos'),
#  ('Then , I talked on Skype .', 'pos'),
#  ('There is no cat . So I did not stop , because I had no reason to .', 'pos'),
#  ('The thing you do not know is I have not been anywhere during the past days .',
#   'pos'),
#  ('The Netherlands is very popular .', 'pos'),
#  ('I got a used one for a very reasonable price .', 'pos'),
#  ('we plan to go to Sunway Pyramid and play ice skating there .', 'neg'),
#  ('He wanted to live at least years old .', 'neg'),
#  ('A movie', 'pos'),
#  ('These are the pictures which I took at the shopping center located near my house , today .',
#   'pos'),
#  ('Another English teacher , Mori was invited to our class and he taught English instead the young teacher for one semester .',
#   'neg'),
#  ('A man , Gyeong - Chul Park is interacting with society as a doctor and having other various experiences even now',
#   'neg'),
#  ('But somethin is so confusing .', 'neg'),
#  ('He was just comforting himself .', 'neg'),
#  ('how did you do ?', 'neg'),
#  ('We have been together all day long during New Year holiday , but today , ',
#   'neg'),
#  ('The ticket cost me RMB , I think it very worth , because the movie is very wonderful ! !',
#   'neg'),
#  ('Because if I am talking with someone , for sure , I ca not have time to look up words in the dictionary .',
#   'pos'),
#  ('This movie has CG and is dubbed in some parts , so I chose the movie .',
#   'neg'),
#  ('The Model United Nations', 'pos'),
#  ('No more discussion !', 'neg'),
#  ('So today is diary is very short .', 'pos'),
#  ('Some native speakers said to me that I did not need to learn slang words , however , I could not agree with that idea completely , because I have come across some occasions when I needed to know slang , just like the case above .',
#   'neg'),
#  ('When I had to go through the corridor , I always looked away so as not to see the picture .',
#   'pos'),
#  ('When they consumed under same condition , ', 'neg'),
#  ('I decided to study Japanese at that time but I felt my Japanese ability did not better than English .',
#   'neg'),
#  ('Everyone ordered the same thing .', 'neg'),
#  ('Thank you .', 'pos'),
#  ('I wanted to go to a movie .', 'pos'),
#  ('I give up sleeping now .', 'neg'),
#  ('A English old saying impressed me very much ', 'neg'),
#  ('I do not remain feelings about her anymore , but the memories are still do .',
#   'neg'),
#  ('It is quiet and warm like his personality .', 'neg'),
#  ('But I ca not speak English .', 'pos'),
#  ('Used my electric skills to set up telecommunication equipment for a train station and machinery room .',
#   'neg'),
#  ('This is my favorite park , when I went there first time with my father on a stifling summer day eight years ago , I loved this place .',
#   'neg'),
#  ('DO not MIND ABOUT COMMAS , CAPITOL LETTERS ETC .', 'pos'),
#  ('Anyway , the midterm examinations will start from this June nd .', 'pos'),
#  ('But I am not sad .', 'pos'),
#  ('Now I have some free time , so I sometimes borrow a basketball court and enjoy it on my own or with friends .',
#   'pos'),
#  ('My friend have a lovely pet , ', 'neg'),
#  ('I have been studying English for some time . You know to master a language many skills are necessary , such as speaking , listening , reading and writing .',
#   'pos'),
#  ('Early health care plans emerged in the s and were termed sickness insurance programs given that they provided coverage only for hospitalizations .',
#   'pos'),
#  ('Let is cross the desert , looking for the stars', 'pos'),
#  ('I was sick for half a month .', 'pos'),
#  ('Pls help my English ! Thank a lot guys ', 'neg'),
#  ('So I spend most of my time at home .', 'neg'),
#  ('Yesterday I went to my mother is home with my children .', 'pos'),
#  ('He said that I have a stomachache .', 'neg'),
#  ('I recently found the river prawn and the crab .', 'pos'),
#  ('I have heard that all costs are very expensive for the Japanese .', 'pos'),
#  ('Thanks to them , I could get used to this area immediately .', 'pos'),
#  ('Flowers had been planted in a row .', 'pos'),
#  ('My big brother also works at there w me .', 'neg'),
#  ('A musician on camelback , a tropical tree , birds and flowers are beautifully designed in mother - of - pearl inlay , amber , etc .',
#   'neg'),
#  ('However , I ca not understand it yet .', 'pos'),
#  ('compare with japan and canada , ', 'neg'),
#  ('I do not know exactly why not but I guess they are bad taste , or they might contain some toxic materials .',
#   'neg'),
#  ('as i came home , it swored up .', 'neg'),
#  ('In my free time , I like to see a movie and go shopping with friends or family .',
#   'pos'),
#  ('But the education is interesting for me .', 'neg'),
#  ('Hot Spring', 'pos'),
#  ('An ubiquitous phenomenon of breaking up in graduation season', 'neg'),
#  ('I wasted time to worry about myself .', 'neg'),
#  ('This presentation is final presentation in my graduate school life .',
#   'neg'),
#  ('I did not feel a long time .', 'neg'),
#  ('However , I do not know why , people just grow up , and they still have a couple of dreams , but we just make little efforts to make them come true . ',
#   'pos'),
#  ('Me Oh , no , that is okay .', 'neg'),
#  ('Among the buildings , there was a particularly impressive building , which resembles the pyramid of glass of the Louvre in Paris .',
#   'pos'),
#  ('However , we fought in the sushi shop .', 'pos'),
#  (' Q . Describe a time you are really tired .', 'neg'),
#  ('When I want to buy an electrical appliance which is expensive , I go there .',
#   'pos'),
#  ('However , I want to live in Tokyo someday ! !', 'pos'),
#  ('The second Sunday of May is Mother is Day in Japan , as it is in some other countries , and this day fell upon May th this year .',
#   'pos'),
#  ('I am a programmer , working in Tokyo .', 'pos'),
#  ('But it has been used in Japan since medieval times for a long time .',
#   'pos'),
#  ('People enjoy drinking but it just tortures me .', 'pos'),
#  ('In , the man who suffered from the most terrible stomachache in Japan ?',
#   'pos'),
#  (' Actually it is funny to say , but I rarely hear about affairs around me .',
#   'pos'),
#  ('when we were junior high school and high school .', 'neg'),
#  ('Expressions from SIMPSONS', 'pos'),
#  ('It is essential that we change our mindset how to adjust our selves to new environments',
#   'neg'),
#  ('The organization as a whole must be engaged to create the conditions for your own and your team s success .',
#   'pos'),
#  ('An exercise in storytelling', 'pos'),
#  ('After a long time , I went to the city to process some affairs , which were to transfer money to my friend and change my transfer limitation on my netbank .',
#   'pos'),
#  ('When I signed an contract to buy the car , I was very happy and just looking forward to driving that new car .',
#   'neg'),
#  ('And now , I usually talk to and even play tricks on the person who I was used to be unfamiliar .',
#   'neg'),
#  ('I love cycling , fishing , travel , and soccer .', 'pos'),
#  ('This is called trade off .', 'neg'),
#  ('I am hesitating to say my type of iPod .', 'pos'),
#  ('but it is funny .', 'pos'),
#  ('I took some pictures from the bridge .', 'pos'),
#  ('to read books what staied on my shelf and waited me .', 'neg'),
#  ('The Chinese version has been published . ', 'pos'),
#  ('Anyway , I wonder if Hydrangea is there in your country too ?', 'pos'),
#  ('The plane landed without incident .', 'neg'),
#  ('This time I am visiting a woman who used to teach me English in high school .',
#   'pos'),
#  ('I think this is one of the most famous dreams of everyone studying English .',
#   'neg'),
#  ('It was an interesting movie , and I was gald to see familiar characters .',
#   'neg'),
#  ('Hello ', 'neg'),
#  ('As you may know , very big earthquake happened march in Japan .', 'neg'),
#  ('Check please !', 'pos'),
#  ('I want to get the good points , so I study hard !', 'pos'),
#  ('In this idea , if you only gather money , you can volunteer to do something good for social .',
#   'pos'),
#  ('However , I will be back on Saturday .', 'pos'),
#  ('Money talks', 'pos'),
#  (' But a woman have lent me this yesterday , and she said she was the hostess of the shop . I began to feel strange .',
#   'neg'),
#  ('I know the matter - Do I know the matter .', 'neg'),
#  ('How are you doing ?', 'pos'),
#  (' I helped her for the sake of my owing . ', 'neg'),
#  ('Because the second most popular girl at school is the concept of them .',
#   'pos'),
#  ('But I found a notebook being sold at a lower price .', 'pos'),
#  ('Big Typhoon will come .', 'neg'),
#  ('I would like to continue to do this style , as long as I do not forget about it .',
#   'pos'),
#  ('This can bring negative outcomes because children wo nt be able to function academically , plus negative cognitive effects may occur .',
#   'neg'),
#  ('Japanese cough drops have a lot of kind of flavors , so I bought too many in spite of myself .',
#   'neg'),
#  ('Why are you always buy ?', 'neg'),
#  ('The Indian is too overconfident , not modest at all .', 'neg'),
#  ('but I am very interested in English and Japanese .', 'pos'),
#  ('Let me introduce that I found interest things in this trip .', 'neg'),
#  ('Today was my first experiment day with healthy volunteer as a participant in the UK .',
#   'neg'),
#  ('You can register at the time of the orientation .', 'pos'),
#  ('I want to start studying Mandarin .', 'pos'),
#  (' , to one is heart is content , as much as one likes wishes ', 'neg'),
#  ('If you have any advice , I would love to hear it !', 'pos'),
#  ('In Japan , we do not throw hats or anything else at the ceremony , maybe , hahaha .',
#   'pos'),
#  ('Also today , I ca not explain a basic term in neuroscience well .', 'pos'),
#  ('I have never been to Germany .', 'pos'),
#  ('I did not have any vision to my future , after graduation of the high school .',
#   'neg'),
#  ('field trip', 'neg'),
#  ('Through exploring her feelings in this process , she gains a greater awareness of what is really bothering her , and then suddenly she is no longer so overwhelmed .',
#   'pos'),
#  ('However this has become a reason why people want to kill them .', 'neg'),
#  ('There was a big crash in the evening just in front of my shared room .',
#   'pos'),
#  ('Here I am going to tell you one embarrassed but funny story which happened to sunnie and I .',
#   'neg'),
#  ('I have visited to London two years ago .', 'neg'),
#  ('Lesson Any kind of expression in English .', 'neg'),
#  ('I heard parents buy this small statue for , , yen .', 'pos'),
#  ('Now i am biginner .', 'neg'),
#  ('Any comment or instruction , please feel free to contact me .', 'neg'),
#  ('or Can I tell ?', 'neg'),
#  ('Thus , I overcame my first problem in Maldives .', 'neg'),
#  ('Nobody forced or asked her to do so .', 'neg'),
#  (' The majority of students in this school ', 'pos'),
#  ('Of course I love BIGBANG but I recommend a girls group .', 'pos'),
#  ('For example doing a search about baby is injections , making reservations for medical check - up to declare for the immigration and so on .',
#   'neg'),
#  ('but how lazy I am , the web of English ca not take my attention .', 'neg'),
#  ('The survey was carried out on two groups of workers those aged from - and those aged - , and shows factors affecting their work performance .',
#   'pos'),
#  ('after denial by the Upper House .', 'pos'),
#  ('But from now on I am going to go to library and than study all day .',
#   'neg'),
#  ('Then , we two stood in front of the television , and started to work out .',
#   'pos'),
#  ('Would you teach me correct English , if it is not too much trouble ?',
#   'pos'),
#  ('They do not even have jasmine tea .', 'pos'),
#  ('I want to make friends with everyone who likes me .', 'neg'),
#  ('But why are they so attentive about it in America , and not in other countries ?',
#   'neg'),
#  ('as to have opportunities to enjoy English conversation for free .', 'neg'),
#  ('I feel relieved as if a load had been taken off my back .', 'pos'),
#  ('Judging myself or other people , I am always following the two guidelines at first .',
#   'neg'),
#  ('First of all , when I take on some tasks , I try to do my best and feel strong responsibility .',
#   'pos'),
#  ('What is this ?', 'pos'),
#  ('If you saw this movie , please let me know how you liked it .', 'pos'),
#  ('I learned a lot of words when I was a high school student .', 'pos'),
#  ('I heard Australia has no winter .', 'pos'),
#  ('Some species of animals are going to be extinct .', 'pos'),
#  ('Dear Lang - users , ', 'neg'),
#  ('I was a member of the basketball .', 'neg'),
#  ('I am not good at talking about what I am thinking in English .', 'pos'),
#  ('On the contrary , I think we can say , very strongly totally seriously nervous . I am scary means I make others scared . ',
#   'pos'),
#  ('Before the class was over , to my surprise , two pupils began to cry for fighting each other .',
#   'neg'),
#  ('Later on that day , I went there as usual .', 'neg'),
#  ("Thus , people who have no obsessions will have no worries . ' ", 'pos'),
#  ('Last Sunday , I made a whole shiffon cake , but the size of the cake was one - half compared to the normal one .',
#   'pos'),
#  ('Correction wrongs in RED', 'neg'),
#  ('If you are bothered there , you should request or ask a cast at once .',
#   'pos'),
#  ('I beg your kindness now .', 'pos'),
#  ('It was from Natalya .', 'pos'),
#  (' I see .', 'pos'),
#  ('Looking forward for my future friends here .', 'neg'),
#  ('Japanese always make ready against earth quake .', 'neg'),
#  ('I can read easily now , and my listening - not very good , but at least I could understand what do other people mean .',
#   'neg'),
#  ('I appreciate you to keep taking care of us .', 'neg'),
#  ('So we are able to start talking when convenient with us .', 'neg'),
#  ('Thank everybody for reading an awful English paragraph .', 'pos'),
#  ('So I was so glad when I looked at their face !', 'neg'),
#  ('I went to church .', 'pos'),
#  ('Dreams are important for us , because they are the force to push us to success .',
#   'neg'),
#  ('Tom was also frustrated and had no idea what had gone wrong .', 'pos'),
#  ('I am Takashi , years old .', 'pos'),
#  ('Under the rule , husbands could not live with their wives .', 'neg'),
#  ('we would do many things together .', 'neg'),
#  ('Let me share it with you .', 'pos'),
#  ('Excuse me .', 'pos'),
#  ('My name is Nuk .', 'pos'),
#  ('It was a very religious day in a meaning .', 'neg'),
#  ('I am afraid that I may fail on exam .', 'neg'),
#  ('I think some of you might say something like this ', 'pos'),
#  ('Whenever I appreciate the quilts , I am very impressed by them because the works need much time and patience .',
#   'neg'),
#  ('I would like to know your opinion about the history that has occurred on my eyes , so One of my friends had split with the wife but it not main thing because before he did not want split .',
#   'neg'),
#  ('What odd reason could possibly lead to these actions ! ', 'pos'),
#  ('I studied unique English this morning .', 'neg'),
#  ('I am so good at skiing ! !', 'pos'),
#  ('You can write an essay about Onegin and really try to understand the character is motivation .',
#   'pos'),
#  ('It will be great if I can find someone to talk with .', 'pos'),
#  ('She just became colorful .', 'neg'),
#  ('First of all , improving roads and highways sometimes has some negative effects .',
#   'pos'),
#  ('But in the afternoon it felt as if it were mid - summer .', 'pos'),
#  ('It compensates the useless mass media .', 'neg'),
#  ('Some of them try to continue with their studies , attend courses or masters of specialization , but only a few have success .',
#   'pos'),
#  ('I wondered why that word was introduced .', 'pos'),
#  ('Long time no see you .', 'pos'),
#  ('He went out with womans , so he has a lot of knowledge and experence .',
#   'neg'),
#  ('Then a friend asked me to help me answer the result is too much to consider',
#   'neg'),
#  ('I study English', 'neg'),
#  ('I bought a new digital camera two weeks ago .', 'neg'),
#  ('I joined this SNS a few days ago .', 'pos'),
#  ('Yesterday , the big earthquake happened in Japan .', 'neg'),
#  ('So , I will be happy if you become my friend .', 'pos'),
#  ('Also , using English is becoming more and more natural to me .', 'pos'),
#  ('Such a soft and comfortable house made me really want to go to Brazil to see it , and there were many trees around it to reveal house is surrounding silent and peace .',
#   'neg'),
#  ('Nabe is kind of a Japanese traditional food , and there are variety of taste .',
#   'neg'),
#  ('Then he started running to the mountain .', 'neg'),
#  ('Glad that I am writing again .', 'pos'),
#  ('A friend of mine who is a coach of alpine ski was in New Zealand a week ago with his racers to participate in a race .',
#   'neg'),
#  ('My day today .', 'pos'),
#  ('This is my status .', 'neg'),
#  ('thanks for being helpful', 'pos'),
#  ('It is not just a huge still sculpture , it can walk on its own feet .',
#   'pos'),
#  ('I take a commuter train and the subway to my office .', 'pos'),
#  ('My hand was injured , a kite brought by wind and strong wind made me cough .',
#   'pos'),
#  ('The difference in the way they cheer is also interesting .', 'pos'),
#  ('And it is also famous in the world .', 'neg'),
#  ('I writing my bad diary .', 'neg'),
#  ('I hope to do this job well .', 'neg'),
#  ('now , hungry .', 'neg'),
#  ('The parakeet kept flapping its wings and eventually landed on the monk is bald head .',
#   'pos'),
#  ('I like snowboarding , but it is too cold to go oursideX - I am planning to go snowboarding next sunday , I wish whether is good at that day .',
#   'neg'),
#  ('I want to learn it again', 'pos'),
#  ('For some sort reason , we have to apart .', 'neg'),
#  ('And there are subtitles in English and in Japanese .', 'neg'),
#  ('Snow gradually piled up body on the road , so', 'neg'),
#  ('Now I usually use a kind of curry roux for my curry .', 'neg'),
#  ('Great performer .', 'pos'),
#  ('That is why he can always face my irrationality with patience .', 'pos'),
#  ('I adore Becky and Susanne .', 'neg'),
#  ('I encouraged him to try again .', 'pos'),
#  ('I hope to get better soon .', 'pos'),
#  ('Birds have come back to rivers , ponds and lakes in the park where I jog daily .',
#   'pos'),
#  ('I was exhasted .', 'neg'),
#  ('From this April , English has been introduced into elementary school th and th grade as compulsory subject .',
#   'neg'),
#  ('You advocate Japan is claims theoretically .', 'pos'),
#  ('Because they have another sense of values , way of thinking , culture life and so on .',
#   'neg'),
#  ('Soy beans are used as tools to drive out demons and to welcome happiness .',
#   'pos'),
#  ('Underground Library', 'neg'),
#  ('The language school started today .', 'pos'),
#  ('Thank you for your help , and do not hesitate if you have any problems with your French ',
#   'pos'),
#  ('native speakers of English .', 'neg'),
#  ('I feel like , although I want to lean on something , I ca not find one to lean on .',
#   'pos'),
#  ('I went to a karaoke yesterday .', 'pos'),
#  ('My teacher of English class has had a cold .', 'neg'),
#  ('I feel upset today .', 'neg'),
#  ('today is journal ', 'pos'),
#  ('Next we plan to use it in the math class and we want to teach other math teachers how to make use of it .',
#   'pos'),
#  ('Please help me !', 'pos'),
#  ('There may not be enough electricity in Japan this summer because of the earthquake in March .',
#   'pos'),
#  ('So , I considered I was going to decide it after I heard my beautician give advice to me .',
#   'neg'),
#  ('So , basically London is cool city but it is hot inside Tube in summer .',
#   'neg'),
#  ('So , today i want to ask about something , ', 'neg'),
#  ('All right !', 'neg'),
#  ('So I did not teach you the information .', 'pos'),
#  ('Fourth , HIT has many smoking areas .', 'pos'),
#  ('I will try to study English only for one month .', 'pos'),
#  ('I went to capoeira class and there is instructor asked me on the first day .',
#   'neg'),
#  ('I delivered goods to my customer who lives next city this morning .',
#   'pos'),
#  ('I would like to let you know what you feel .', 'pos'),
#  ('In Japan , many companies discriminate against men in public .', 'neg'),
#  ('It does not have much space for the students to park their car , so most students go to school by bicycle or motorbike instead of cars .',
#   'pos'),
#  ('All of us dressed up and wore paper crowns !', 'neg'),
#  ('Yesterday I did not write here any post .', 'neg'),
#  ('do not worry .', 'neg'),
#  ('There is a vessel which includes planets .', 'pos'),
#  ('NEWS is Japanese idol group .', 'neg'),
#  (" - another man asked him ' how about shirakawa ? ' ", 'neg'),
#  ('Today , I went down to the post office for money .', 'neg'),
#  ('Now I have joined Lang - !', 'neg'),
#  ('After that activity , he is full of energy and ready for big achievements .',
#   'neg'),
#  ('April , ', 'neg'),
#  ('It is serious .', 'neg'),
#  ('Then I changed the holiday to December .', 'pos'),
#  ('in Japan .', 'pos'),
#  ('Keynote Address at the DNC The Audacity of Hope - ', 'neg'),
#  ('Then when she feels more loving and forgiving she can successfully approach him to share her feelings .',
#   'neg'),
#  ('In , the man who suffered from the most terrible stomachache in Japan ?',
#   'neg'),
#  ('Thus , governments have changed my home town into a new page .', 'pos'),
#  ('For me , I have not got enough work experience yet .', 'pos'),
#  ('I could not review my last lesson .', 'neg'),
#  ("I think that I am a kinda rare person on this Lang - ' cause I do not think there are so many Japanese people here .",
#   'pos'),
#  ('The air is very blurry because of the yellow sand from China .', 'pos'),
#  ('So he is on a diet .', 'neg'),
#  ('Because my heater is broken , I am wearing a overcoat in the house .',
#   'neg'),
#  ('So comfortable . , D', 'pos'),
#  ('Sports meet', 'pos'),
#  ('foreshadows the growing future of language - minority into majority .',
#   'pos'),
#  ('Check out some examples below ', 'neg'),
#  ('i do not have MP , maybe a lot of people think i m behind and do not know how to take advantages from this great modern socity .',
#   'neg'),
#  ('I am reading an interesting book , this is a memoir .', 'neg'),
#  ('I wo nt to continue this habit .', 'neg'),
#  ('Today I read a news about the Super Bowl .', 'neg'),
#  ('And the other group looked at the back .', 'pos'),
#  ('Going Shopping !', 'pos'),
#  ('out what those mean !', 'pos'),
#  ('Here in Belarus there are quite many psychologists but just years ago it would be a problem to find just one of them .',
#   'neg'),
#  ('He is superb , a real big stiff .', 'pos'),
#  ('These days , I often think of the attitude of my heart .', 'pos'),
#  ('And I am a member of this travel committee .', 'neg'),
#  ('Though , I think I want to study more , and so I made up my mind to take an entrance examination for a graduate school !',
#   'pos'),
#  ('They might think that is because they did not brush their teeth very well .',
#   'neg'),
#  ('They are all easy but they are working for me well .', 'neg'),
#  ('Hope you like it !', 'neg'),
#  ('And I hope that I can have many friends from various country .', 'neg'),
#  ('Gist is an online service which allows you to store and publicize your source code as a snippet .',
#   'pos'),
#  ('It would clog my blood vessel and make me feel lethargic .', 'neg'),
#  ('I can study English and write this diary at this time .', 'pos'),
#  ('Also I have a monthly train and bus pass so that is also a good reason to go .',
#   'pos'),
#  ('We like to see only positive pictures of our adventurous trip in our mind .',
#   'neg'),
#  ('When the movie released in Japan in , many boys imitated his fighting style .',
#   'neg'),
#  ('Believe it or not , I never believed it .', 'pos'),
#  ('I am going to start it after I finish this cake .', 'neg'),
#  ('I wrote a sentence using a word which appears frequently in TOEIC .',
#   'pos'),
#  ('Today when I chatted with my Texan friend over Skype , I asked him if he could find some online book clubs in English or not for me .',
#   'neg'),
#  ('I would tried to hide my true feelings since I was a little boy because I knew my thought was kind of unique and it was hard for them to accept it .',
#   'pos'),
#  ('Be cool and cool down pain s ? on my head !', 'neg'),
#  ("She replied ' OK .", 'neg'),
#  ('She also ignored other people because they are poor .', 'neg'),
#  ('I still can not get over his absence .', 'pos'),
#  ('It is one of the blue cheeses , and contains a blue mold .', 'pos'),
#  ('You do not look good ! , they said We are ok , keep drinking !', 'neg'),
#  ('My wife recommended me to buy something as a birthday present because October first is my birthday .',
#   'pos'),
#  ('I do not know what to do .', 'pos'),
#  ('In the morning , I rode on the CTA train to go to school for about minutes .',
#   'pos'),
#  ('But as I get older , I am interested in taking care of children who grow up in poor surroundings .',
#   'pos'),
#  ('The ideal of life is a life of ideal .', 'neg'),
#  ('Dance lesson !', 'neg'),
#  ('There are many demonstrations again in China against Japan .', 'neg'),
#  ('I would like you to check my letter to my friend .', 'neg'),
#  ('She felt terrified .', 'neg'),
#  ('When I was at the computer , I suddenly heard some furious growling and howling at the same time .',
#   'pos'),
#  ('i learned the word SINCE long time ago .', 'neg'),
#  ('I have a lot of trouble on English writing , so I need someone can help me',
#   'neg'),
#  ('It is been for ages !', 'neg'),
#  ('Now I am working for a small company as a webmaster .', 'pos'),
#  ('and then I got hot .', 'neg'),
#  ('So I write down only English Composition .', 'pos'),
#  ('I want to tell you about my favorite teacher .', 'neg'),
#  ('She is wonderful .', 'neg'),
#  ('Which do you prefer ?', 'neg'),
#  ('I happened to talk with one of my colleagues who is in charge of coordinating English group lessons today .',
#   'neg'),
#  ('There are so many similar adjectives to describe a certain thing .', 'neg'),
#  ('I want you to see it when you have a free time .', 'neg'),
#  (' Which age of group are you ?', 'neg'),
#  ('Every day and every night I miss him so much but I do not know what I should do .',
#   'pos'),
#  (' ', 'pos'),
#  ('The Rorschach test was one of the tests .', 'pos'),
#  ('So I woke up early in the morning .', 'pos'),
#  (' ', 'neg'),
#  ('It is after a long absence ! !', 'neg'),
#  ('And if the red shirt people got what they wanted , the yellow would not just sit there and do nothing Right now , everything seems to be normal but I really do nt know that how long it will be like this .',
#   'neg'),
#  ('He watched them all on his television screen .', 'neg'),
#  ('Then , I love breads .', 'neg'),
#  ('I thought someone was going to hit me to shut me up but probably everyone who was watching this video was as stunned as I was .',
#   'pos'),
#  ('Custom makes all things easy .', 'pos'),
#  ('It is not bad but I think it does not suit me .', 'pos'),
#  (' hour for one way ', 'neg'),
#  ('You are a taxi .', 'neg'),
#  (' ', 'neg'),
#  ('I have not air conditioner either electric fan because my house is not so hot .',
#   'neg'),
#  ('But the more unhappy thing was I had to write a long story about this game .',
#   'pos'),
#  ('In the program Japanese Sumo is booming in Tel Aviv , Israel is capital .',
#   'pos'),
#  ('So I never go to parties till my son understands his lonely time .', 'pos'),
#  ('I have got new desk , new computer , new colleagues , and new boss .',
#   'neg'),
#  ('The weather was very nice .', 'pos'),
#  ('Maybe I got drunk heavily yesterday .', 'pos'),
#  ('I have had enough of studying English .', 'neg'),
#  ('The issue regarding how to communicate with others deserves careful consideration because it is such a multifaceted topic .',
#   'neg'),
#  ('She points out the flowers in planters , saying Wanna take a picture ? ',
#   'pos'),
#  ('She may wearing white one - piece , have a straw hat and took a sandal .',
#   'neg'),
#  ('I feel disappointed and unhappy .', 'neg'),
#  ('Have a good day ', 'neg'),
#  ('I have watched Shawshank Redemption and am a big fan of that .', 'pos'),
#  ('I , am shocked', 'neg'),
#  ('Lots of shopping centers have been built in this city during these years .',
#   'neg'),
#  ('He could not tell her the truth because he did not want to lose their friendship .',
#   'neg'),
# ...
#  ('I do not know why she cried .', 'neg'),
#  ('I have season , and , but I watch them little by little .', 'neg'),
#  ('I am very interested in the culture of the USA .', 'pos'),
#  ('Ah , I have no time again ! ! ! ! LOL It is regrettable .', 'pos'),
#  ('He gives us a shuttlecock of his company .', 'pos'),
#  ('But , she is not a Cinderella but a witch .', 'pos'),
#  (' - so smart', 'neg'),
#  ('The OC', 'pos'),
#  ('and i do not know how to use it .', 'neg'),
#  ('When I heard about this story , I was impressed by this behavior of this worker .',
#   'neg'),
#  ('I am back from my athletics club . I had not run for a while , so it was really exhausting !',
#   'pos'),
#  (' Yellowstone Is Rising on Swollen ', 'neg'),
#  ('Maybe I think that is caused by lasting typical cold winter pressure pattern .',
#   'neg'),
#  (' ', 'neg'),
#  ('If I can meet them , I really want to meet them and talk to them .', 'pos'),
#  ('Nowadays , I am worried about getting a job and my future .', 'pos'),
#  ('Piglet , you can go to school without anybody is notice .', 'pos'),
#  ('I am exhausted !', 'pos'),
#  ('They have not used it often .', 'neg'),
#  ('I envy that there is FBI in America .', 'neg'),
#  ('I will love you all the time forever .', 'neg'),
#  ('inter cultural communication with drinking', 'neg'),
#  ('I do not know why .', 'neg'),
#  ('I felt I was lucky to be born a Japanese person ! !', 'pos'),
#  ('Do over - To renovate or redecorate .', 'neg'),
#  ('It has been a while since I made my last JP video , but here is the newest one .',
#   'pos'),
#  ('salvage my DS from drawer', 'neg'),
#  ('I will try .', 'pos'),
#  ('so why you do not tell me', 'neg'),
#  ('M I missed you , Cassie .', 'neg'),
#  ('lies yet another distinction .', 'neg'),
#  ('We got a new teacher , called Brendan .', 'neg'),
#  ('As for me , I do not agree with both ideas completely .', 'pos'),
#  ('How do you keep your motivation up when you are bored studying ?', 'pos'),
#  ('Recently I am interested in Artificial intelligence .', 'neg'),
#  ('Friend I opened the window and found a cardboard box on my veranda .',
#   'pos'),
#  ('Because , older people work till too late and sometimes go to work on holiday .',
#   'pos'),
#  ('I figured reality is tough .', 'neg'),
#  ('Hi , I am Mr Japanese Wolf .', 'neg'),
#  ('By the way , the tube lines have been on strike since the day before yesterday at pm .',
#   'pos'),
#  ('They are totally out of line .', 'pos'),
#  ('He was an excellent TV producer .', 'pos'),
#  ('When I do not think about anything , I just waste my time .', 'pos'),
#  ('According to her , her son is looking forward to playing with my son together at his house , so I decided to entrust my son to her .',
#   'neg'),
#  (" ' Brave guy , ' I thought , but the next moment I saw several people follow out .",
#   'neg'),
#  ('I want to sleep ', 'pos'),
#  (' When do you feel you are still immature ?', 'pos'),
#  (' I have read a lot of detective novels , but this is the first time I read such a interesting novel .',
#   'neg'),
#  ('I took the TOEIC today .', 'pos'),
#  ('The opinion was divided at first .', 'neg'),
#  ('ADD ME PLZ XD', 'neg'),
#  ('She would nt conceal her love to Achilles .', 'neg'),
#  ('Firstly , I will', 'pos'),
#  ('We walked for very long distance days straight so we got tired but we visited the far place the next day !',
#   'neg'),
#  ('a nice long week', 'neg'),
#  ('I am happy because the Tigers beat the Swallows - .', 'pos'),
#  ('Her message was very impressive .', 'pos'),
#  ('Since I do nt represent all native Japanese speakers and I am not an authority on Japanese usage , please bear in mind that this is just my opinion .',
#   'pos'),
#  ('People dream every night .', 'pos'),
#  ('My name is Haruna .', 'pos'),
#  ('I can connect an iPad to the wireless LAN .', 'neg'),
#  ('And I signed the contract without even notice what was going to come , I had to fulfill the contract made between me and the company , it would had been a breach if I had failed to do so .',
#   'neg'),
#  ('I am a student at language school at the USA .', 'neg'),
#  ('Last Sunday , I went to Karaoke with my cousin .', 'pos'),
#  ('IME PC is word processing program .', 'neg'),
#  ('I will from time to time to review .', 'pos'),
#  ('Good evening B .', 'neg'),
#  ('But I will enjoy staying in Hawaii as much as I can .', 'pos'),
#  ('I was so busy that I could not write diary .', 'neg'),
#  ('I have bought lots of things bread , beef , milk and so on .', 'neg'),
#  ('I was impressed with the second goal of Endo .', 'pos'),
#  ('Better than not .', 'pos'),
#  ('Chat with an American girl .', 'pos'),
#  ('I like yellow leaves when autumn comes .', 'neg'),
#  ('and I tried to give him milk , ', 'pos'),
#  ('But rather than its , I sad that my superior clear up a my mistake .',
#   'neg'),
#  ('The fog is getting more dense . ', 'neg'),
#  (' I will deliver it for you . ', 'pos'),
#  ('Hello everyone , this is Masao in Tokyo Japan .', 'neg'),
#  ('Three days ago , I arrived home .', 'neg'),
#  (' The tail lamp will flash automatically when it gets some weaving signal and its battery is generated by solar power .',
#   'neg'),
#  ('That is the conflict .', 'pos'),
#  ('I am enjoying my half year is sabbatical leave at Goettingen University .',
#   'neg'),
#  ('I believe that we will be able to get over the many difficulties .', 'neg'),
#  ('Today , it was hot and very humid .', 'neg'),
#  ('Apart from improving my English , I would love to speak Japanese .', 'pos'),
#  ('But I do not have any plans for this week .', 'pos'),
#  ('Basically , Buddhism seems to be the most popular in Japan .', 'pos'),
#  ('After breakfast , we went to a little park and a bookshop .', 'pos'),
#  ('Anti - China protest in Vietnam', 'neg'),
#  ('It is Monday , and the hospital was a little crowded though we went there soon after the consultation hours began .',
#   'neg'),
#  ('I like not only popular dramas but also not so much popular dramas .',
#   'neg'),
#  ('is high hurdle compared to passive study , like leading and listening .',
#   'pos'),
#  ('One day , he went on a date with his girldfriend in a playground .', 'neg'),
#  ('first of all I have not stamina .', 'neg'),
#  ('Sure , it is a certain kind of studies .', 'pos'),
#  ('I tore them into pieces one after another and put into a plastic bag .',
#   'neg'),
#  ('Every human should be able to operate a PC .', 'pos'),
#  ('I m glad to know it .', 'neg'),
#  ('Water is an unstable thing .', 'pos'),
#  ('But my answer was flat .', 'pos'),
#  ('There , most citizens go out with family to pick up something cute for the kids or to get some great bargains for their wife or friend .',
#   'pos'),
#  ('But , children around here have got survival splits .', 'pos'),
#  ('I need change in this new year , so I will work hard !In order to make progress , I will write journals when I surf the internet .',
#   'neg'),
#  ('A computer is made by us , it s only a machine , a tool .', 'pos'),
#  ('The article seems a little old .', 'pos'),
#  ('I was excited a little though I usually did not watch', 'neg'),
#  ('I m trying to learn her it s fun to go together , but we can t buy all she see in the shops .',
#   'neg'),
#  ('Moreover , in the Harry Potter novels , pumpkin juice is a favorite drink of the students of Hogwart is School of Witchcraft and Wizardry . ',
#   'pos'),
#  ('tossing their heads in sprightly dance .', 'neg'),
#  ('People started to eat healthy food which contains less fat and more vitamins .',
#   'pos'),
#  ('I was amazed at that but I was happy then .', 'pos'),
#  ('everybody wait for me !', 'neg'),
#  ('I am forgetful about that .', 'neg'),
#  ('children who use computer when they are young have more confidence than other children .',
#   'neg'),
#  ('I really need to do exercises that make me feel free , although it started raining this afternoon .',
#   'pos'),
#  ('It can use Skype !', 'pos'),
#  ('Such conduct is ethically prohibited in my company .', 'pos'),
#  ('A store clerk said that I need a prescription to buy contact lenses .',
#   'neg'),
#  ('I do not have hay fever .', 'neg'),
#  ('Today I went to a hospital to visit my mother .', 'neg'),
#  ('Thus , adults should encourage them to have opportunities to read good materials .',
#   'neg'),
#  ('Lie to Me', 'neg'),
#  ('And what do you think of nuclear power plants ?', 'pos'),
#  ('So , if I have free time I research stock market information .', 'pos'),
#  ('The government job is suitable for me and difficult to apply for because of many competitors .',
#   'pos'),
#  ('Living without a mobile', 'neg'),
#  ('The children came to school with their many homework from the winter vacation .',
#   'pos'),
#  ('I started to walk .', 'pos'),
#  ('drink a little .', 'pos'),
#  ('However , trial lesson was very fun .', 'neg'),
#  ('in as a cashier serving visitors , combined with my current exchange experience in XYZZ University , I am rewarded with excellent English and moderate Netherlands ability , as well as highly - cultivated with enormous cultural differences .',
#   'neg'),
#  (' Well I always say this and it is begun to sound corny !', 'pos'),
#  ('So , I did not even write a diary in Japanese .', 'pos'),
#  ('We were divided into two groups and try to figure out how to escape from the maze safely .',
#   'pos'),
#  ('Sometimes , I have English words that I can understand the meaning but can not explain in Japanese or translate in Japanese .',
#   'neg'),
#  ('If you were a god what would you do to the world ?', 'neg'),
#  ('a small paragraph where I am supposed to write a small paragraph , so I am not too thrilled about doing this , but I decided there is probably no place than lang - lol .',
#   'neg'),
#  ('I hope she gets fine soon .', 'neg'),
#  (' I had looked forward to traveling abroad , but I got fed up with seeing groups of Japanese tourists wherever I went .',
#   'neg'),
#  ('He also does roadwork every day !', 'neg'),
#  ('I would like to know about what attracts you these days .', 'pos'),
#  ('and I will certainly correct my friend is Japanese diary .', 'neg'),
#  ('So , I would like to get used to English .', 'neg'),
#  ('knowledge is power .', 'neg'),
#  ('Since Voldemort resurrected , the scar on his forehead is burning endlessly .',
#   'pos'),
#  ('Besides , volleyball is a sort of collaborative sport .', 'neg'),
#  ('Internet Radio Experiment Begins', 'pos'),
#  ('But today it is incredibly strong , so we , native of Trieste , are shocked too .',
#   'neg'),
#  ('The gay marriage', 'pos'),
#  ('So , I hope everyone can be happy and healthy .', 'neg'),
#  ('When I am speaking in English , my character seems to somewhat Americanized or something like that .',
#   'neg'),
#  ('Her mother was good at cooking .', 'pos'),
#  ('That always takes very easy English and gestures .', 'pos'),
#  ('Because every spring , we can see many wild flowers as a tick of winter is end on streets .',
#   'neg'),
#  ('But people feel like there are five seasons .', 'neg'),
#  (' People from other parts are often surprised to find policemen in this area very kind .',
#   'neg'),
#  ('I just bet some coins on numbers or colors .', 'pos'),
#  ('On Tuesday , I skim through a website about dinosaurs book and it let me feel to interested .',
#   'neg'),
#  ('I am a bit wet .', 'neg'),
#  ('It seems like she has to do a lot of homework than I was a student .',
#   'neg'),
#  ('The school is near my house .', 'pos'),
#  ('All the birthday gifts I have received were few and normal .', 'neg'),
#  ('I am and I live in Poland .', 'neg'),
#  ('We love the first scene of counting numbers from five to one and launching a rocket very much .',
#   'neg'),
#  ('It was terrible .', 'pos'),
#  ('They are calling out to me ! I always walk up to them like a zombie under a spell .',
#   'pos'),
#  ('This slogan is borrowed from a Japanese TV show , a delicious TV show .',
#   'neg'),
#  ('I will start this midnight and back tomorrow midnight , and with .', 'neg'),
#  (' , Today I introduced the story of a Japanese nameless football player and a well - known Spanish one .',
#   'pos'),
#  ('They like to play catch .', 'neg'),
#  ('So I am often asked , What is the stuff in your photo ? .', 'neg'),
#  ('It was the first time to sleep alone in the new house for her , and she said Can you stay in my room for a while while I am sleeping ? .',
#   'pos'),
#  ('I have my English class in minutes .', 'pos'),
#  ('And this time , i will never give up again !', 'neg'),
#  ('We went to KangWonDo , which is a famous Korean religion .', 'pos'),
#  ('But I ca not write English well or speak it .', 'pos'),
#  ('Thank you .', 'pos'),
#  ('The supply is still insufficient .', 'pos'),
#  ('I forgot to return the book to the library for about two months !', 'neg'),
#  ('I have never taken part in this action , but this time I will .', 'pos'),
#  ('Don t you think so ?', 'pos'),
#  ('Roy became nervous and tought that it was too late .', 'neg'),
#  ('Nowadays , global warming becomes a serious issue so I think we have to invent something that decrease air pollution .',
#   'neg'),
#  ('even more I have to get money .', 'neg'),
#  ('Do nt you call it an air spot in English ?', 'pos'),
#  ('happy new year ', 'pos'),
#  ('The member of taking lunch are Japanese eath other , but interestingly feeling color is little different .',
#   'neg'),
#  ('Likewise , I think there must be some English words which ca not translate well into Japanese .',
#   'pos'),
#  ('I bought a kanji practice application for my iPod and used it for a while .',
#   'pos'),
#  ('My friend , she is the mother of my son is classmate , said , It is time to let them do everything by themselves . ',
#   'pos'),
#  ('I believe that I can realize it at this company .', 'pos'),
#  ('After that , we took lunch in the North Indian restaurant and came back to hostel .',
#   'neg'),
#  ('play basketball', 'pos'),
#  ('When he was child , he lived in Jakarta with his mother and stepfather .',
#   'pos'),
#  ('enjoy movie', 'pos'),
#  ('As my shoes were worn out , I bought a pair of new shoes some days ago .',
#   'pos'),
#  ('And B means Akinori remained calm with his expectation .', 'neg'),
#  (' ', 'neg'),
#  ('English is a kind of the most eclectic language in the world .', 'pos'),
#  ('There were few people there during this period of time , so I did not feel that embarrassed to soak naked in the water - There were piscines in there .',
#   'pos'),
#  ('In my point of view European people can also gain the fundamental benefit by learning another culture is language , such as Chinese , Arabic , Japanese , etc .',
#   'neg'),
#  ('I am going to go to the salon .', 'pos'),
#  ('Why do they need creativeness ?', 'neg'),
#  ('There are so many things that I have to learn words , structures and listening and speaking , which is the most important thing in learning a language .',
#   'pos'),
#  ('I have a sister , she is five elder than me .', 'neg'),
#  ('Epressions from SIMPSONS', 'neg'),
#  ('entrance to school from years old .', 'pos'),
#  ('I appreciate the friend who taught me this site .', 'neg'),
#  ('It was a sunny day , but it was a little cold to read outside .', 'pos'),
#  ('My room rejected me !', 'pos'),
#  ('Hello everyone .', 'pos'),
#  ('I hope you watch it too .', 'pos'),
#  ('Last night', 'pos'),
#  ('One was from Sweden . He asked me whether I was interested in improving my life .',
#   'pos'),
#  ('Or , linux ?', 'neg'),
#  ('I am interested in the space .', 'pos'),
#  ('Use specific reasons and examples to support your opinion .', 'neg'),
#  ('The motif of the story was vampire lengends and its atmosphere was dark and gloomy .',
#   'neg'),
#  ('I am going to continue to study English ! !', 'neg'),
#  ('Long time no write diary .', 'neg'),
#  ('Now , I would like to write down how much this Japanese habit makes me bothering .',
#   'pos'),
#  ('Someone told me he would come late with the ABET teacher .', 'neg'),
#  ('FYI I use an ondol room which is Korean underfloor heating system .',
#   'neg'),
#  ('On my way home , I found that the mountain opposite my home looks green and vital .',
#   'pos'),
#  ('Outlet shop', 'neg'),
#  ('My first reason is that I would like to follow my feelings to enjoy my journey .',
#   'pos'),
#  ('I have a large camera and I take some pictures every time I find something pretty and strange and so on .',
#   'pos'),
#  ('So I sprayed air freshener to them .', 'neg'),
#  ...]
